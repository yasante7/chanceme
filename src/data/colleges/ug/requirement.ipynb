# %%
import json
import requests
from bs4 import BeautifulSoup
from collections import defaultdict

# %%
with open('requirement.txt', 'r') as file:
    site = file.read()

# %%
soup = BeautifulSoup(site, 'html.parser')

# %%
tab_id = "block-views-block-entry-requirements-block-1"  # WASSCE applicants
    # "block-views-block-entry-requirements-block-2",  # Other applicants
    # "block-views-block-entry-requirements-block-7",


all_programs = []
no_req_programs = []

tabs = soup.find_all(id=tab_id)
for tab in tabs:
    print(f"Processing tab: {tab} \n\n\n\n")
    for i, item in enumerate(tab.find_all(class_=["accordion-item", "views-row"])):
        program = defaultdict(lambda: defaultdict(lambda: defaultdict(dict)))

        # Extracting program name from content of button
        button = item.find(class_="accordion-button collapsed")
        if not button:
            print(f"Warning: Missing accordion-button for item #{i}")
            continue
        program_name = button.get_text(strip=True)
        print(f"\n>>> Processing Program: {program_name}")
        program["program"] = program_name
        program["filteringsubject"] = "Social Studies"
        program["alternatecore"] = "Integrated Science"
        
        program_reqs = item.find(class_="accordion-body")
        if not program_reqs:
            print(f"No requirements section found for {program_name}")
            no_req_programs.append(program_name)
            continue

        requirements = program_reqs.find_all("p")
        if not requirements:
            print(f"No <p> tags (requirements) found for {program_name}")
            no_req_programs.append(program_name)
            continue

        core = main = tracks = ""
        electives_found = False

        # Combine all <p> tags in the requirement section into a single string (HTML)
        full_html = "".join(str(p) for p in requirements)
        parsed_html = BeautifulSoup(full_html, "html.parser")

        # Find all strong tags and their associated text chunks
        strong_tags = parsed_html.find_all("strong")

        for j, tag in enumerate(strong_tags):
            label = tag.get_text(strip=True).lower()
            value = ""

            # Collect all text until the next <strong> or end
            current = tag.next_sibling
            while current and (not hasattr(current, "name") or current.name != "strong"):
                if hasattr(current, "get_text"):
                    value += current.get_text(" ", strip=True)
                else:
                    value += str(current)
                current = current.next_sibling

            value = BeautifulSoup(value, "html.parser").get_text(" ", strip=True)
            value = value.replace('\u00a0', ' ').strip(": ").strip()


            print(f"  [Label #{j}] {label} => {value}")

            if "core" in label:
                core = value.replace(" &", ",").replace("Credit passes in ", "")
            elif "elective" in label and not electives_found:
                electives_found = True
                electives = value.replace("Credit passes in ", "")
                if " and any " in electives:
                    parts = electives.split(" and any ", 1)
                    main = parts[0].strip()
                    tracks = parts[1].strip() if len(parts) > 1 else ""
                    print(f"    ↪ Main Elective: {main.strip()}")
                    print(f"    ↪ Track Options: {tracks.strip()}")
                else:
                    main = electives.strip()
                    tracks = ""
                    print(f"    ↪ All Electives: {main.strip()}")

                program["core subjects"] = core
                program["elective subjects"]["main"] = [main]
                track_list = []
                if tracks:
                    # crude way to guess it's a list: presence of ' or ', ' and ', or commas
                    if any(x in tracks for x in [",", " and ", " or "]):
                        track_list = [t.strip() for t in tracks.replace(" and ", ",").replace(" or ", ",").split(",") if t.strip()]
                    else:
                        # fallback — just keep it as-is (it's not a subject list)
                        print(f"⚠️  Track text not parsed as subject list: {tracks}")

                program["elective subjects"]["tracks"]["General"] = track_list

                program["special requirements / general information"] = None

                if requirements[1:]:
                    additional_reqs = []
                    for req in requirements[1:]:
                        req_text = req.get_text(strip=True)
                        if req_text:
                            additional_reqs.append(req_text)
                    if additional_reqs:
                        program["special requirements / general information"] = additional_reqs
                        print(f"  ➕ Additional Info: {additional_reqs}")

                # Find tables for concentrations
                tables = item.find_all("table")
                if tables:
                    print(f"  📋 Concentration table(s) found for {program_name}")
                    concentrations = []
                    for table in tables:
                        concentration = {}
                        rows = table.find_all("tr")
                        for row in rows:
                            cols = row.find_all("td")
                            if len(cols) == 2:
                                conc = cols[0].get_text(strip=True).lower()
                                required_subs = cols[1].get_text(strip=True)
                                concentration[conc] = required_subs
                                print(f"    - {conc}: {required_subs}")
                        program["concentrations"] = concentration
                print(f"  ✅ Update: {program}")
        all_programs.append(program)
# Out:
# Processing tab: <div aria-labelledby="tab-one" class="views-element-container tab-pane collapse active show mt-5 block block-views block-views-blockentry-requirements-block-1" id="block-views-block-entry-requirements-block-1" role="tabpanel">
# <div><div class="view view-entry-requirements view-id-entry_requirements view-display-id-block_1 js-view-dom-id-c6ca8d10f0522fe2a072e51502b9cd0b8d6b067c3b28ce51d518f0ddc3f92043" data-once="ajax-pager">
# <div class="view-header">
# <h4>Ghanaian Applicants with WASSCE/SSSCE Qualification</h4>
# <br/>
# <h5>A. General Entry Requirements into the Full-Time Degree Programmes</h5>
# <p>An applicant for admission to an undergraduate degree programme in the University of Ghana must have at least credits (A1 - C6 in WASSCE or A - D in SSSCE) in the following subjects: <br/>
# •	The Four Core Subjects: English, Core Mathematics, Integrated Science/Core Science, and Social Studies. <br/>
# •	Three elective subjects. <br/> <br/>
# </p><h5>B. Calculation of Aggregates for Admission </h5>
# The total aggregate of results, comprising six subjects (relevant core and electives), should not exceed: <br/>
# •	Aggregate 24 for Regular admissions. <br/>
# •	Aggregate 30 for Distance Education admissions. <br/>
# <strong> For Science-Related Disciplines:  </strong> <br/>
# •	Aggregate is calculated using English, Core Mathematics, Integrated Science/Core Science, and three elective subjects in the Sciences (refer to specific programme elective requirements below). <br/>
# •	Note: Social Studies credit is excluded in the calculation. <br/>
# <strong> For Non-Science Disciplines:  </strong> <br/>
# •	Aggregate is calculated using English, Core Mathematics, Social Studies/Life Skills, and three elective subjects in General Arts/Business (refer to specific programme elective requirements below). <br/>
# •	Note: Integrated Science/Core Science credit is excluded in the calculation. <br/>
# <br/>
# <br/>
# Search by keyword or college
#     </div>
# <div class="view-filters">
# <form accept-charset="UTF-8" action="/undergraduate/entry-requirements" class="views-exposed-form" data-drupal-selector="views-exposed-form-entry-requirements-block-1" data-once="exposed-form" id="views-exposed-form-entry-requirements-block-1" method="get">
# <div class="form--inline clearfix">
# <div class="js-form-item form-item js-form-type-textfield form-type-textfield js-form-item-title form-item-title">
# <label for="edit-title--47MISBjUOuM">Name of Programme</label>
# <input class="form-text" data-drupal-selector="edit-title" id="edit-title--47MISBjUOuM" maxlength="128" name="title" size="30" type="text" value=""/>
# </div>
# <div class="js-form-item form-item js-form-type-select form-type-select js-form-item-field-college-value form-item-field-college-value">
# <label for="edit-field-college-value--WjxEDBYxx1s">College</label>
# <select class="form-select" data-drupal-selector="edit-field-college-value" id="edit-field-college-value--WjxEDBYxx1s" name="field_college_value"><option value="All">- Any -</option><option selected="selected" value="College of Basic and Applied Sciences">College of Basic and Applied Sciences</option><option value="College of Education">College of Education</option><option value="College of Health Sciences">College of Health Sciences</option><option value="College of Humanities">College of Humanities</option></select>
# </div>
# <div class="form-actions js-form-wrapper form-wrapper" data-drupal-selector="edit-actions" id="edit-actions--_ZStszQ2P-s"><input class="button js-form-submit form-submit" data-drupal-selector="edit-submit-entry-requirements-zwq0b-cnnk" id="edit-submit-entry-requirements--_ZWq0b_CnNk" type="submit" value="Search"/>
# </div>
# </div>
# </form>
# </div>
# <div class="view-content">
# <div class="views-infinite-scroll-content-wrapper clearfix" data-drupal-views-infinite-scroll-content-wrapper=""> <div class="accordion-item views-row">
# <h2 class="accordion-header">
# <button aria-controls="BSc.ActuarialScience" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#BSc.ActuarialScience" data-bs-toggle="collapse" type="button">
#   BSc. Actuarial Science
#   </button>
# </h2>
# <div class="accordion-collapse collapse" data-bs-parent="#view-content" id="BSc.ActuarialScience">
# <div class="accordion-body">
# <h3> Entry Requirements</h3>
# <p><strong>Core</strong>: Credit passes in English, Core Mathematics, Integrated Science &amp; Social Studies<br/><strong>Electives</strong>: Credit passes in Elective Mathematics and any two subjects with at least a <strong>B3 in Elective Mathematics</strong></p>
# </div>
# </div>
# </div>
# <div class="accordion-item views-row">
# <h2 class="accordion-header">
# <button aria-controls="BSc.ComputerScience" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#BSc.ComputerScience" data-bs-toggle="collapse" type="button">
#   BSc. Computer Science
#   </button>
# </h2>
# <div class="accordion-collapse collapse" data-bs-parent="#view-content" id="BSc.ComputerScience">
# <div class="accordion-body">
# <h3> Entry Requirements</h3>
# <p><strong>Core</strong>: Credit passes in English, Core Mathematics, Integrated Science &amp; Social Studies<br/><strong>Electives</strong>: Credit passes in Elective Mathematics and any two subjects with at least a <strong>B3 in Elective Mathematics</strong></p>
# </div>
# </div>
# </div>
# <div class="accordion-item views-row">
# <h2 class="accordion-header">
# <button aria-controls="DoctorofVeterinaryMedicine" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#DoctorofVeterinaryMedicine" data-bs-toggle="collapse" type="button">
#   Doctor of Veterinary Medicine
#   </button>
# </h2>
# <div class="accordion-collapse collapse" data-bs-parent="#view-content" id="DoctorofVeterinaryMedicine">
# <div class="accordion-body">
# <h3> Entry Requirements</h3>
# <p><strong>Core</strong>: Credit passes in English, Core Mathematics, Integrated Science &amp; Social Studies<br/><strong>Electives</strong>: Credit passes in Biology, Chemistry, and either Physics or Elective Mathematics</p>
# </div>
# </div>
# </div>
# <div class="accordion-item views-row">
# <h2 class="accordion-header">
# <button aria-controls="BachelorofScienceinEngineeringSciences(MaterialsScience&amp;amp;EngineeringOption)" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#BachelorofScienceinEngineeringSciences(MaterialsScience&amp;amp;EngineeringOption)" data-bs-toggle="collapse" type="button">
#   Bachelor of Science in Engineering Sciences (Materials Science &amp; Engineering Option)
#   </button>
# </h2>
# <div class="accordion-collapse collapse" data-bs-parent="#view-content" id="BachelorofScienceinEngineeringSciences(MaterialsScience&amp;amp;EngineeringOption)">
# <div class="accordion-body">
# <h3> Entry Requirements</h3>
# <p><strong>Core</strong>: Credit passes in English, Core Mathematics, Integrated Science &amp; Social Studies<br/><strong>Electives</strong>: Credit passes in Physics, Chemistry, and Elective Mathematics, with at least a B3 in Elective Mathematics</p>
# </div>
# </div>
# </div>
# <div class="accordion-item views-row">
# <h2 class="accordion-header">
# <button aria-controls="BachelorofScienceinEngineeringSciences(FoodProcessEngineeringOption)" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#BachelorofScienceinEngineeringSciences(FoodProcessEngineeringOption)" data-bs-toggle="collapse" type="button">
#   Bachelor of Science in Engineering Sciences (Food Process Engineering Option)
#   </button>
# </h2>
# <div class="accordion-collapse collapse" data-bs-parent="#view-content" id="BachelorofScienceinEngineeringSciences(FoodProcessEngineeringOption)">
# <div class="accordion-body">
# <h3> Entry Requirements</h3>
# <p><strong>Core</strong>: Credit passes in English, Core Mathematics, Integrated Science &amp; Social Studies<br/><strong>Electives</strong>: Credit passes in Physics, Chemistry, and Elective Mathematics, with at least a B3 in Elective Mathematics</p>
# </div>
# </div>
# </div>
# <div class="accordion-item views-row">
# <h2 class="accordion-header">
# <button aria-controls="BachelorofScienceinEngineeringSciences(ComputerEngineeringOption)" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#BachelorofScienceinEngineeringSciences(ComputerEngineeringOption)" data-bs-toggle="collapse" type="button">
#   Bachelor of Science in Engineering Sciences (Computer Engineering Option)
#   </button>
# </h2>
# <div class="accordion-collapse collapse" data-bs-parent="#view-content" id="BachelorofScienceinEngineeringSciences(ComputerEngineeringOption)">
# <div class="accordion-body">
# <h3> Entry Requirements</h3>
# <p><strong>Core</strong>: Credit passes in English, Core Mathematics, Integrated Science &amp; Social Studies<br/><strong>Electives</strong>: Credit passes in Physics, Chemistry and Elective Mathematics, with at least a B3 in Elective Mathematics</p>
# </div>
# </div>
# </div>
# <div class="accordion-item views-row">
# <h2 class="accordion-header">
# <button aria-controls="BachelorofScienceinEngineeringSciences(BiomedicalEngineeringOption)" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#BachelorofScienceinEngineeringSciences(BiomedicalEngineeringOption)" data-bs-toggle="collapse" type="button">
#   Bachelor of Science in Engineering Sciences (Biomedical Engineering Option)
#   </button>
# </h2>
# <div class="accordion-collapse collapse" data-bs-parent="#view-content" id="BachelorofScienceinEngineeringSciences(BiomedicalEngineeringOption)">
# <div class="accordion-body">
# <h3> Entry Requirements</h3>
# <p><strong>Core</strong>: Credit passes in English, Core Mathematics, Integrated Science &amp; Social Studies<br/><strong>Electives</strong>: Credit passes in Physics, Chemistry and Elective Mathematics, with at least a B3 in Elective Mathematics</p>
# </div>
# </div>
# </div>
# <div class="accordion-item views-row">
# <h2 class="accordion-header">
# <button aria-controls="BachelorofScienceinEngineeringSciences(AgricultureEngineeringOption)" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#BachelorofScienceinEngineeringSciences(AgricultureEngineeringOption)" data-bs-toggle="collapse" type="button">
#   Bachelor of Science in Engineering Sciences (Agriculture Engineering Option)
#   </button>
# </h2>
# <div class="accordion-collapse collapse" data-bs-parent="#view-content" id="BachelorofScienceinEngineeringSciences(AgricultureEngineeringOption)">
# <div class="accordion-body">
# <h3> Entry Requirements</h3>
# <p><strong>Core</strong>: Credit passes in English, Core Mathematics, Integrated Science &amp; Social Studies<br/><strong>Electives</strong>: Credit passes in Physics, Chemistry, and Elective Mathematics, with at least a B3 in Elective Mathematics</p>
# </div>
# </div>
# </div>
# <div class="accordion-item views-row">
# <h2 class="accordion-header">
# <button aria-controls="BachelorofScienceinFamily&amp;amp;ConsumerSciences(FamilyandChildStudiesOption)" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#BachelorofScienceinFamily&amp;amp;ConsumerSciences(FamilyandChildStudiesOption)" data-bs-toggle="collapse" type="button">
#   Bachelor of Science in Family &amp; Consumer Sciences (Family and Child Studies Option)
#   </button>
# </h2>
# <div class="accordion-collapse collapse" data-bs-parent="#view-content" id="BachelorofScienceinFamily&amp;amp;ConsumerSciences(FamilyandChildStudiesOption)">
# <div class="accordion-body">
# <h3> Entry Requirements</h3>
# <p><strong>Core</strong>: Credit passes in English, Core Mathematics, Integrated Science &amp; Social Studies<br/><strong>Electives</strong>: Credit pass in Management in Living and any two of the following: Food and Nutrition, Textiles and Clothing, General Knowledge in Art, Biology or Chemistry.</p>
# </div>
# </div>
# </div>
# <div class="accordion-item views-row">
# <h2 class="accordion-header">
# <button aria-controls="BachelorofScienceinFamily&amp;amp;ConsumerSciences(FoodandClothingOption)" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#BachelorofScienceinFamily&amp;amp;ConsumerSciences(FoodandClothingOption)" data-bs-toggle="collapse" type="button">
#   Bachelor of Science in Family &amp; Consumer Sciences (Food and Clothing Option)
#   </button>
# </h2>
# <div class="accordion-collapse collapse" data-bs-parent="#view-content" id="BachelorofScienceinFamily&amp;amp;ConsumerSciences(FoodandClothingOption)">
# <div class="accordion-body">
# <h3> Entry Requirements</h3>
# <p><strong>Core</strong>: Credit passes in English, Core Mathematics, Integrated Science &amp; Social Studies<br/><strong>Electives</strong>:  <br/><em>Home Science Background</em>: Credit passes in Management in Living and Chemistry, and either Food and Nutrition or Textile and Clothing<br/><br/><em>Science Background</em>: Credit passes in Chemistry and any two Elective Subjects</p>
# </div>
# </div>
# </div>
# <div class="accordion-item views-row">
# <h2 class="accordion-header">
# <button aria-controls="BachelorofScienceinAgriculture" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#BachelorofScienceinAgriculture" data-bs-toggle="collapse" type="button">
#   Bachelor of Science in Agriculture
#   </button>
# </h2>
# <div class="accordion-collapse collapse" data-bs-parent="#view-content" id="BachelorofScienceinAgriculture">
# <div class="accordion-body">
# <h3> Entry Requirements</h3>
# <p><strong>Bachelor of Science in Agriculture</strong><br/><em>Animal Science, Crop Science, Soil Science, Agriculture Economics, Agribusiness, Agriculture Extension, Post-Harvest Technology.</em><br/> <br/><strong>Entry requirements:  </strong><br/><strong>Core</strong>: Credit passes in English, Core Mathematics, Integrated Science &amp; Social Studies<br/><strong>Electives</strong>: Credit passes in Chemistry and any two of Physics, Biology/Agriculture Science, Geography and Elective Mathematics</p>
# </div>
# </div>
# </div>
# <div class="accordion-item views-row">
# <h2 class="accordion-header">
# <button aria-controls="BachelorofScienceinPsychology" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#BachelorofScienceinPsychology" data-bs-toggle="collapse" type="button">
#   Bachelor of Science in Psychology
#   </button>
# </h2>
# <div class="accordion-collapse collapse" data-bs-parent="#view-content" id="BachelorofScienceinPsychology">
# <div class="accordion-body">
# <h3> Entry Requirements</h3>
# <p><strong>Core</strong>: Credit passes in English, Core Mathematics, Integrated Science &amp; Social Studies<br/><strong>Electives</strong>: Credit passes in Biology and Elective Mathematics and any one of Physics and Chemistry</p>
# </div>
# </div>
# </div>
# <div class="accordion-item views-row">
# <h2 class="accordion-header">
# <button aria-controls="BachelorofScienceinBiologicalSciences" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#BachelorofScienceinBiologicalSciences" data-bs-toggle="collapse" type="button">
#   Bachelor of Science in Biological Sciences
#   </button>
# </h2>
# <div class="accordion-collapse collapse" data-bs-parent="#view-content" id="BachelorofScienceinBiologicalSciences">
# <div class="accordion-body">
# <h3> Entry Requirements</h3>
# <p><strong>Bachelor of Science degree in any one of the following subjects:</strong><br/><em>Animal Biology and Conservation Science, Biochemistry Cell and Molecular Biology, Nutrition, Food Science, Plant and Environmental Biology, Marine Science, Fisheries Science, Psychology, Microbiology.</em><br/><em> </em><br/><strong>Entry requirements:  </strong><br/><strong>Core</strong>: Credit passes in English, Core Mathematics, Integrated Science &amp; Social Studies<br/><strong>Electives</strong>: Credit passes in Chemistry, Physics, and Biology  </p>
# </div>
# </div>
# </div>
# <div class="accordion-item views-row">
# <h2 class="accordion-header">
# <button aria-controls="BachelorofScienceinInformationTechnology" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#BachelorofScienceinInformationTechnology" data-bs-toggle="collapse" type="button">
#   Bachelor of Science in Information Technology
#   </button>
# </h2>
# <div class="accordion-collapse collapse" data-bs-parent="#view-content" id="BachelorofScienceinInformationTechnology">
# <div class="accordion-body">
# <h3> Entry Requirements</h3>
# <p><strong>Core</strong>: Credit passes in English, Core Mathematics, Integrated Science &amp; Social Studies<br/><strong>Electives</strong>: Credit passes in any three subjects, with at least a <strong>B3 in Core Mathematics</strong></p>
# </div>
# </div>
# </div>
# <div class="accordion-item views-row">
# <h2 class="accordion-header">
# <button aria-controls="BachelorofScienceinEarthSciences" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#BachelorofScienceinEarthSciences" data-bs-toggle="collapse" type="button">
#   Bachelor of Science in Earth Sciences
#   </button>
# </h2>
# <div class="accordion-collapse collapse" data-bs-parent="#view-content" id="BachelorofScienceinEarthSciences">
# <div class="accordion-body">
# <h3> Entry Requirements</h3>
# <p><strong>Bachelor of Science degree in any one of the following subjects:</strong></p><p><em>Geology, Applied Geology, Applied Geophysics   </em> <br/> <br/><strong>Entry requirements:  </strong><br/><strong>Core</strong>: Credit passes in English, Core Mathematics, Integrated Science &amp; Social Studies<br/><strong>Electives</strong>: Credit passes in Chemistry and any two of Physics, Biology/Geography and Elective Mathematics  </p>
# </div>
# </div>
# </div>
# <div class="accordion-item views-row">
# <h2 class="accordion-header">
# <button aria-controls="BachelorofScienceinMathematicalSciences" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#BachelorofScienceinMathematicalSciences" data-bs-toggle="collapse" type="button">
#   Bachelor of Science in Mathematical Sciences
#   </button>
# </h2>
# <div class="accordion-collapse collapse" data-bs-parent="#view-content" id="BachelorofScienceinMathematicalSciences">
# <div class="accordion-body">
# <h3> Entry Requirements</h3>
# <p><strong>Bachelor of Science degree in any ONE of the following subjects:</strong><br/><em>Mathematics, Statistics, Biomathematics, Physics</em></p><p>Or</p><p><strong>Bachelor of Science in any TWO of the following subjects:</strong><br/><em>Mathematics, Statistics, Computer Science, Physics</em></p><p><strong>Note</strong> I: Applicants who choose the Mathematical Sciences option cannot pursue a single major in Computer Science, but they may combine Computer Science with any of the other three subjects: Mathematics, Statistics, or Physics.<br/> <br/><strong>Entry requirements:  </strong><br/><strong>Core</strong>: Credit passes in English, Core Mathematics, Integrated Science &amp; Social Studies<br/><strong>Electives</strong>: Credit passes in Elective Mathematics and any two subjects with at least a <strong>B3 in Elective Mathematics</strong></p><p><strong>Note</strong> II: Applicants who choose the Mathematical Sciences option may ONLY pursue a single or combined major in Physics <strong>if</strong> they have credit passes in <strong>both Physics and Chemistry</strong>.</p><p> </p>
# </div>
# </div>
# </div>
# <div class="accordion-item views-row">
# <h2 class="accordion-header">
# <button aria-controls="BachelorofScienceinPhysicalSciences" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#BachelorofScienceinPhysicalSciences" data-bs-toggle="collapse" type="button">
#   Bachelor of Science in Physical Sciences
#   </button>
# </h2>
# <div class="accordion-collapse collapse" data-bs-parent="#view-content" id="BachelorofScienceinPhysicalSciences">
# <div class="accordion-body">
# <h3> Entry Requirements</h3>
# <p><strong>Bachelor of Science degree in any one of the following subjects:</strong><br/><em>Physics, Chemistry, Geophysics</em><br/> <br/><strong>Entry requirements:  </strong><br/><strong>Core</strong>: Credit passes in English, Core Mathematics, Integrated Science &amp; Social Studies<br/><strong>Electives</strong>: Credit passes in Physics, Chemistry, and Elective Mathematics, with at least a <strong>B3 in Core Mathematics</strong></p><p><strong>Note</strong> : Applicants who choose the Physical Sciences Option may ONLY pursue a  combined major with a Mathematical Sciences Subject <strong>if</strong> they have a B3 in Elective  Mathematics.</p><p> </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
#
#
#
#
#
# >>> Processing Program: BSc. Actuarial Science
#   [Label #0] core => Credit passes in English, Core Mathematics, Integrated Science & Social Studies
#   [Label #1] electives => Credit passes in Elective Mathematics and any two subjects with at least a
#     ↪ Main Elective: Elective Mathematics
#     ↪ Track Options: two subjects with at least a
# ⚠️  Track text not parsed as subject list: two subjects with at least a
#   ✅ Update: defaultdict(<function <lambda> at 0x000001C34FA0CDC0>, {'program': 'BSc. Actuarial Science', 'filteringsubject': 'Social Studies', 'alternatecore': 'Integrated Science', 'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies', 'elective subjects': defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001C3503CA0D0>, {'main': ['Elective Mathematics'], 'tracks': defaultdict(<class 'dict'>, {'General': []})}), 'special requirements / general information': None})
#   [Label #2] b3 in elective mathematics =>
#
# >>> Processing Program: BSc. Computer Science
#   [Label #0] core => Credit passes in English, Core Mathematics, Integrated Science & Social Studies
#   [Label #1] electives => Credit passes in Elective Mathematics and any two subjects with at least a
#     ↪ Main Elective: Elective Mathematics
#     ↪ Track Options: two subjects with at least a
# ⚠️  Track text not parsed as subject list: two subjects with at least a
#   ✅ Update: defaultdict(<function <lambda> at 0x000001C34FA0CEE0>, {'program': 'BSc. Computer Science', 'filteringsubject': 'Social Studies', 'alternatecore': 'Integrated Science', 'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies', 'elective subjects': defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001C3503CA310>, {'main': ['Elective Mathematics'], 'tracks': defaultdict(<class 'dict'>, {'General': []})}), 'special requirements / general information': None})
#   [Label #2] b3 in elective mathematics =>
#
# >>> Processing Program: Doctor of Veterinary Medicine
#   [Label #0] core => Credit passes in English, Core Mathematics, Integrated Science & Social Studies
#   [Label #1] electives => Credit passes in Biology, Chemistry, and either Physics or Elective Mathematics
#     ↪ All Electives: Biology, Chemistry, and either Physics or Elective Mathematics
#   ✅ Update: defaultdict(<function <lambda> at 0x000001C3503CA4C0>, {'program': 'Doctor of Veterinary Medicine', 'filteringsubject': 'Social Studies', 'alternatecore': 'Integrated Science', 'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies', 'elective subjects': defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001C3503CAAF0>, {'main': ['Biology, Chemistry, and either Physics or Elective Mathematics'], 'tracks': defaultdict(<class 'dict'>, {'General': []})}), 'special requirements / general information': None})
#
# >>> Processing Program: Bachelor of Science in Engineering Sciences (Materials Science & Engineering Option)
#   [Label #0] core => Credit passes in English, Core Mathematics, Integrated Science & Social Studies
#   [Label #1] electives => Credit passes in Physics, Chemistry, and Elective Mathematics, with at least a B3 in Elective Mathematics
#     ↪ All Electives: Physics, Chemistry, and Elective Mathematics, with at least a B3 in Elective Mathematics
#   ✅ Update: defaultdict(<function <lambda> at 0x000001C3503CA040>, {'program': 'Bachelor of Science in Engineering Sciences (Materials Science & Engineering Option)', 'filteringsubject': 'Social Studies', 'alternatecore': 'Integrated Science', 'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies', 'elective subjects': defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001C3503CA9D0>, {'main': ['Physics, Chemistry, and Elective Mathematics, with at least a B3 in Elective Mathematics'], 'tracks': defaultdict(<class 'dict'>, {'General': []})}), 'special requirements / general information': None})
#
# >>> Processing Program: Bachelor of Science in Engineering Sciences (Food Process Engineering Option)
#   [Label #0] core => Credit passes in English, Core Mathematics, Integrated Science & Social Studies
#   [Label #1] electives => Credit passes in Physics, Chemistry, and Elective Mathematics, with at least a B3 in Elective Mathematics
#     ↪ All Electives: Physics, Chemistry, and Elective Mathematics, with at least a B3 in Elective Mathematics
#   ✅ Update: defaultdict(<function <lambda> at 0x000001C3503CAA60>, {'program': 'Bachelor of Science in Engineering Sciences (Food Process Engineering Option)', 'filteringsubject': 'Social Studies', 'alternatecore': 'Integrated Science', 'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies', 'elective subjects': defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001C3503CAC10>, {'main': ['Physics, Chemistry, and Elective Mathematics, with at least a B3 in Elective Mathematics'], 'tracks': defaultdict(<class 'dict'>, {'General': []})}), 'special requirements / general information': None})
#
# >>> Processing Program: Bachelor of Science in Engineering Sciences (Computer Engineering Option)
#   [Label #0] core => Credit passes in English, Core Mathematics, Integrated Science & Social Studies
#   [Label #1] electives => Credit passes in Physics, Chemistry and Elective Mathematics, with at least a B3 in Elective Mathematics
#     ↪ All Electives: Physics, Chemistry and Elective Mathematics, with at least a B3 in Elective Mathematics
#   ✅ Update: defaultdict(<function <lambda> at 0x000001C3503CADC0>, {'program': 'Bachelor of Science in Engineering Sciences (Computer Engineering Option)', 'filteringsubject': 'Social Studies', 'alternatecore': 'Integrated Science', 'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies', 'elective subjects': defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001C3503CA430>, {'main': ['Physics, Chemistry and Elective Mathematics, with at least a B3 in Elective Mathematics'], 'tracks': defaultdict(<class 'dict'>, {'General': []})}), 'special requirements / general information': None})
#
# >>> Processing Program: Bachelor of Science in Engineering Sciences (Biomedical Engineering Option)
#   [Label #0] core => Credit passes in English, Core Mathematics, Integrated Science & Social Studies
#   [Label #1] electives => Credit passes in Physics, Chemistry and Elective Mathematics, with at least a B3 in Elective Mathematics
#     ↪ All Electives: Physics, Chemistry and Elective Mathematics, with at least a B3 in Elective Mathematics
#   ✅ Update: defaultdict(<function <lambda> at 0x000001C3503CA790>, {'program': 'Bachelor of Science in Engineering Sciences (Biomedical Engineering Option)', 'filteringsubject': 'Social Studies', 'alternatecore': 'Integrated Science', 'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies', 'elective subjects': defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001C3503CA700>, {'main': ['Physics, Chemistry and Elective Mathematics, with at least a B3 in Elective Mathematics'], 'tracks': defaultdict(<class 'dict'>, {'General': []})}), 'special requirements / general information': None})
#
# >>> Processing Program: Bachelor of Science in Engineering Sciences (Agriculture Engineering Option)
#   [Label #0] core => Credit passes in English, Core Mathematics, Integrated Science & Social Studies
#   [Label #1] electives => Credit passes in Physics, Chemistry, and Elective Mathematics, with at least a B3 in Elective Mathematics
#     ↪ All Electives: Physics, Chemistry, and Elective Mathematics, with at least a B3 in Elective Mathematics
#   ✅ Update: defaultdict(<function <lambda> at 0x000001C3503CA8B0>, {'program': 'Bachelor of Science in Engineering Sciences (Agriculture Engineering Option)', 'filteringsubject': 'Social Studies', 'alternatecore': 'Integrated Science', 'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies', 'elective subjects': defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001C3503CAF70>, {'main': ['Physics, Chemistry, and Elective Mathematics, with at least a B3 in Elective Mathematics'], 'tracks': defaultdict(<class 'dict'>, {'General': []})}), 'special requirements / general information': None})
#
# >>> Processing Program: Bachelor of Science in Family & Consumer Sciences (Family and Child Studies Option)
#   [Label #0] core => Credit passes in English, Core Mathematics, Integrated Science & Social Studies
#   [Label #1] electives => Credit pass in Management in Living and any two of the following: Food and Nutrition, Textiles and Clothing, General Knowledge in Art, Biology or Chemistry.
#     ↪ Main Elective: Credit pass in Management in Living
#     ↪ Track Options: two of the following: Food and Nutrition, Textiles and Clothing, General Knowledge in Art, Biology or Chemistry.
#   ✅ Update: defaultdict(<function <lambda> at 0x000001C3503CAD30>, {'program': 'Bachelor of Science in Family & Consumer Sciences (Family and Child Studies Option)', 'filteringsubject': 'Social Studies', 'alternatecore': 'Integrated Science', 'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies', 'elective subjects': defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001C34FA0C550>, {'main': ['Credit pass in Management in Living'], 'tracks': defaultdict(<class 'dict'>, {'General': ['two of the following: Food', 'Nutrition', 'Textiles', 'Clothing', 'General Knowledge in Art', 'Biology', 'Chemistry.']})}), 'special requirements / general information': None})
#
# >>> Processing Program: Bachelor of Science in Family & Consumer Sciences (Food and Clothing Option)
#   [Label #0] core => Credit passes in English, Core Mathematics, Integrated Science & Social Studies
#   [Label #1] electives => Home Science Background: Credit passes in Management in Living and Chemistry, and either Food and Nutrition or Textile and ClothingScience Background: Credit passes in Chemistry and any two Elective Subjects
#     ↪ Main Elective: Home Science Background: Management in Living and Chemistry, and either Food and Nutrition or Textile and ClothingScience Background: Chemistry
#     ↪ Track Options: two Elective Subjects
# ⚠️  Track text not parsed as subject list: two Elective Subjects
#   ✅ Update: defaultdict(<function <lambda> at 0x000001C35025EA60>, {'program': 'Bachelor of Science in Family & Consumer Sciences (Food and Clothing Option)', 'filteringsubject': 'Social Studies', 'alternatecore': 'Integrated Science', 'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies', 'elective subjects': defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001C3503CA160>, {'main': ['Home Science Background: Management in Living and Chemistry, and either Food and Nutrition or Textile and ClothingScience Background: Chemistry'], 'tracks': defaultdict(<class 'dict'>, {'General': []})}), 'special requirements / general information': None})
#
# >>> Processing Program: Bachelor of Science in Agriculture
#   [Label #0] bachelor of science in agriculture => Animal Science, Crop Science, Soil Science, Agriculture Economics, Agribusiness, Agriculture Extension, Post-Harvest Technology.
#   [Label #1] entry requirements: =>
#   [Label #2] core => Credit passes in English, Core Mathematics, Integrated Science & Social Studies
#   [Label #3] electives => Credit passes in Chemistry and any two of Physics, Biology/Agriculture Science, Geography and Elective Mathematics
#     ↪ Main Elective: Chemistry
#     ↪ Track Options: two of Physics, Biology/Agriculture Science, Geography and Elective Mathematics
#   ✅ Update: defaultdict(<function <lambda> at 0x000001C35025EDC0>, {'program': 'Bachelor of Science in Agriculture', 'filteringsubject': 'Social Studies', 'alternatecore': 'Integrated Science', 'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies', 'elective subjects': defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001C3503CA3A0>, {'main': ['Chemistry'], 'tracks': defaultdict(<class 'dict'>, {'General': ['two of Physics', 'Biology/Agriculture Science', 'Geography', 'Elective Mathematics']})}), 'special requirements / general information': None})
#
# >>> Processing Program: Bachelor of Science in Psychology
#   [Label #0] core => Credit passes in English, Core Mathematics, Integrated Science & Social Studies
#   [Label #1] electives => Credit passes in Biology and Elective Mathematics and any one of Physics and Chemistry
#     ↪ Main Elective: Biology and Elective Mathematics
#     ↪ Track Options: one of Physics and Chemistry
#   ✅ Update: defaultdict(<function <lambda> at 0x000001C35025E280>, {'program': 'Bachelor of Science in Psychology', 'filteringsubject': 'Social Studies', 'alternatecore': 'Integrated Science', 'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies', 'elective subjects': defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001C35025EEE0>, {'main': ['Biology and Elective Mathematics'], 'tracks': defaultdict(<class 'dict'>, {'General': ['one of Physics', 'Chemistry']})}), 'special requirements / general information': None})
#
# >>> Processing Program: Bachelor of Science in Biological Sciences
#   [Label #0] bachelor of science degree in any one of the following subjects: => Animal Biology and Conservation Science, Biochemistry Cell and Molecular Biology, Nutrition, Food Science, Plant and Environmental Biology, Marine Science, Fisheries Science, Psychology, Microbiology.
#   [Label #1] entry requirements: =>
#   [Label #2] core => Credit passes in English, Core Mathematics, Integrated Science & Social Studies
#   [Label #3] electives => Credit passes in Chemistry, Physics, and Biology
#     ↪ All Electives: Chemistry, Physics, and Biology
#   ✅ Update: defaultdict(<function <lambda> at 0x000001C35025E310>, {'program': 'Bachelor of Science in Biological Sciences', 'filteringsubject': 'Social Studies', 'alternatecore': 'Integrated Science', 'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies', 'elective subjects': defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001C35025EE50>, {'main': ['Chemistry, Physics, and Biology'], 'tracks': defaultdict(<class 'dict'>, {'General': []})}), 'special requirements / general information': None})
#
# >>> Processing Program: Bachelor of Science in Information Technology
#   [Label #0] core => Credit passes in English, Core Mathematics, Integrated Science & Social Studies
#   [Label #1] electives => Credit passes in any three subjects, with at least a
#     ↪ All Electives: any three subjects, with at least a
#   ✅ Update: defaultdict(<function <lambda> at 0x000001C3503CAE50>, {'program': 'Bachelor of Science in Information Technology', 'filteringsubject': 'Social Studies', 'alternatecore': 'Integrated Science', 'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies', 'elective subjects': defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001C35025EC10>, {'main': ['any three subjects, with at least a'], 'tracks': defaultdict(<class 'dict'>, {'General': []})}), 'special requirements / general information': None})
#   [Label #2] b3 in core mathematics =>
#
# >>> Processing Program: Bachelor of Science in Earth Sciences
#   [Label #0] bachelor of science degree in any one of the following subjects: =>
#   [Label #1] entry requirements: =>
#   [Label #2] core => Credit passes in English, Core Mathematics, Integrated Science & Social Studies
#   [Label #3] electives => Credit passes in Chemistry and any two of Physics, Biology/Geography and Elective Mathematics
#     ↪ Main Elective: Chemistry
#     ↪ Track Options: two of Physics, Biology/Geography and Elective Mathematics
#   ➕ Additional Info: ['Geology, Applied Geology, Applied GeophysicsEntry requirements:Core: Credit passes in English, Core Mathematics, Integrated Science & Social StudiesElectives: Credit passes in Chemistry and any two of Physics, Biology/Geography and Elective Mathematics']
#   ✅ Update: defaultdict(<function <lambda> at 0x000001C35025E0D0>, {'program': 'Bachelor of Science in Earth Sciences', 'filteringsubject': 'Social Studies', 'alternatecore': 'Integrated Science', 'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies', 'elective subjects': defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001C3503A8550>, {'main': ['Chemistry'], 'tracks': defaultdict(<class 'dict'>, {'General': ['two of Physics', 'Biology/Geography', 'Elective Mathematics']})}), 'special requirements / general information': ['Geology, Applied Geology, Applied GeophysicsEntry requirements:Core: Credit passes in English, Core Mathematics, Integrated Science & Social StudiesElectives: Credit passes in Chemistry and any two of Physics, Biology/Geography and Elective Mathematics']})
#
# >>> Processing Program: Bachelor of Science in Mathematical Sciences
#   [Label #0] bachelor of science degree in any one of the following subjects: => Mathematics, Statistics, Biomathematics, Physics
#   [Label #1] bachelor of science in any two of the following subjects: => Mathematics, Statistics, Computer Science, Physics
#   [Label #2] note => I: Applicants who choose the Mathematical Sciences option cannot pursue a single major in Computer Science, but they may combine Computer Science with any of the other three subjects: Mathematics, Statistics, or Physics.
#   [Label #3] entry requirements: =>
#   [Label #4] core => Credit passes in English, Core Mathematics, Integrated Science & Social Studies
#   [Label #5] electives => Credit passes in Elective Mathematics and any two subjects with at least a
#     ↪ Main Elective: Elective Mathematics
#     ↪ Track Options: two subjects with at least a
# ⚠️  Track text not parsed as subject list: two subjects with at least a
#   ➕ Additional Info: ['Or', 'Bachelor of Science in any TWO of the following subjects:Mathematics, Statistics, Computer Science, Physics', 'NoteI: Applicants who choose the Mathematical Sciences option cannot pursue a single major in Computer Science, but they may combine Computer Science with any of the other three subjects: Mathematics, Statistics, or Physics.Entry requirements:Core: Credit passes in English, Core Mathematics, Integrated Science & Social StudiesElectives: Credit passes in Elective Mathematics and any two subjects with at least aB3 in Elective Mathematics', 'NoteII:\xa0Applicants who choose the Mathematical Sciences option may ONLY pursue a single or combined major in Physicsifthey have credit passes inboth Physics and Chemistry.']
#   ✅ Update: defaultdict(<function <lambda> at 0x000001C3503A8DC0>, {'program': 'Bachelor of Science in Mathematical Sciences', 'filteringsubject': 'Social Studies', 'alternatecore': 'Integrated Science', 'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies', 'elective subjects': defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001C35025E4C0>, {'main': ['Elective Mathematics'], 'tracks': defaultdict(<class 'dict'>, {'General': []})}), 'special requirements / general information': ['Or', 'Bachelor of Science in any TWO of the following subjects:Mathematics, Statistics, Computer Science, Physics', 'NoteI: Applicants who choose the Mathematical Sciences option cannot pursue a single major in Computer Science, but they may combine Computer Science with any of the other three subjects: Mathematics, Statistics, or Physics.Entry requirements:Core: Credit passes in English, Core Mathematics, Integrated Science & Social StudiesElectives: Credit passes in Elective Mathematics and any two subjects with at least aB3 in Elective Mathematics', 'NoteII:\xa0Applicants who choose the Mathematical Sciences option may ONLY pursue a single or combined major in Physicsifthey have credit passes inboth Physics and Chemistry.']})
#   [Label #6] b3 in elective mathematics =>
#   [Label #7] note => II: Applicants who choose the Mathematical Sciences option may ONLY pursue a single or combined major in Physics
#   [Label #8] if => they have credit passes in
#   [Label #9] both physics and chemistry => .
#
# >>> Processing Program: Bachelor of Science in Physical Sciences
#   [Label #0] bachelor of science degree in any one of the following subjects: => Physics, Chemistry, Geophysics
#   [Label #1] entry requirements: =>
#   [Label #2] core => Credit passes in English, Core Mathematics, Integrated Science & Social Studies
#   [Label #3] electives => Credit passes in Physics, Chemistry, and Elective Mathematics, with at least a
#     ↪ All Electives: Physics, Chemistry, and Elective Mathematics, with at least a
#   ➕ Additional Info: ['Note:\xa0Applicants who choose the Physical Sciences Option may ONLY pursue a\xa0 combined major with a Mathematical Sciences Subjectifthey have a B3 in Elective\xa0 Mathematics.']
#   ✅ Update: defaultdict(<function <lambda> at 0x000001C35025EB80>, {'program': 'Bachelor of Science in Physical Sciences', 'filteringsubject': 'Social Studies', 'alternatecore': 'Integrated Science', 'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies', 'elective subjects': defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001C35025EF70>, {'main': ['Physics, Chemistry, and Elective Mathematics, with at least a'], 'tracks': defaultdict(<class 'dict'>, {'General': []})}), 'special requirements / general information': ['Note:\xa0Applicants who choose the Physical Sciences Option may ONLY pursue a\xa0 combined major with a Mathematical Sciences Subjectifthey have a B3 in Elective\xa0 Mathematics.']})
#   [Label #4] b3 in core mathematics =>
#   [Label #5] note => Applicants who choose the Physical Sciences Option may ONLY pursue a  combined major with a Mathematical Sciences Subject
#   [Label #6] if => they have a B3 in Elective  Mathematics.
# Processing tab: <div aria-labelledby="tab-one" class="views-element-container tab-pane collapse active show mt-5 block block-views block-views-blockentry-requirements-block-1" id="block-views-block-entry-requirements-block-1" role="tabpanel">
# <div><div class="view view-entry-requirements view-id-entry_requirements view-display-id-block_1 js-view-dom-id-c6ca8d10f0522fe2a072e51502b9cd0b8d6b067c3b28ce51d518f0ddc3f92043" data-once="ajax-pager">
# <div class="view-header">
# <h4>Ghanaian Applicants with WASSCE/SSSCE Qualification</h4>
# <br/>
# <h5>A. General Entry Requirements into the Full-Time Degree Programmes</h5>
# <p>An applicant for admission to an undergraduate degree programme in the University of Ghana must have at least credits (A1 - C6 in WASSCE or A - D in SSSCE) in the following subjects: <br/>
# •	The Four Core Subjects: English, Core Mathematics, Integrated Science/Core Science, and Social Studies. <br/>
# •	Three elective subjects. <br/> <br/>
# </p><h5>B. Calculation of Aggregates for Admission </h5>
# The total aggregate of results, comprising six subjects (relevant core and electives), should not exceed: <br/>
# •	Aggregate 24 for Regular admissions. <br/>
# •	Aggregate 30 for Distance Education admissions. <br/>
# <strong> For Science-Related Disciplines:  </strong> <br/>
# •	Aggregate is calculated using English, Core Mathematics, Integrated Science/Core Science, and three elective subjects in the Sciences (refer to specific programme elective requirements below). <br/>
# •	Note: Social Studies credit is excluded in the calculation. <br/>
# <strong> For Non-Science Disciplines:  </strong> <br/>
# •	Aggregate is calculated using English, Core Mathematics, Social Studies/Life Skills, and three elective subjects in General Arts/Business (refer to specific programme elective requirements below). <br/>
# •	Note: Integrated Science/Core Science credit is excluded in the calculation. <br/>
# <br/>
# <br/>
# Search by keyword or college
#     </div>
# <div class="view-filters">
# <form accept-charset="UTF-8" action="/undergraduate/entry-requirements" class="views-exposed-form" data-drupal-selector="views-exposed-form-entry-requirements-block-1" data-once="exposed-form" id="views-exposed-form-entry-requirements-block-1" method="get">
# <div class="form--inline clearfix">
# <div class="js-form-item form-item js-form-type-textfield form-type-textfield js-form-item-title form-item-title">
# <label for="edit-title--YJXvAFuV-xE">Name of Programme</label>
# <input class="form-text" data-drupal-selector="edit-title" id="edit-title--YJXvAFuV-xE" maxlength="128" name="title" size="30" type="text" value=""/>
# </div>
# <div class="js-form-item form-item js-form-type-select form-type-select js-form-item-field-college-value form-item-field-college-value">
# <label for="edit-field-college-value--xbyrCLxmfIU">College</label>
# <select class="form-select" data-drupal-selector="edit-field-college-value" id="edit-field-college-value--xbyrCLxmfIU" name="field_college_value"><option value="All">- Any -</option><option value="College of Basic and Applied Sciences">College of Basic and Applied Sciences</option><option selected="selected" value="College of Education">College of Education</option><option value="College of Health Sciences">College of Health Sciences</option><option value="College of Humanities">College of Humanities</option></select>
# </div>
# <div class="form-actions js-form-wrapper form-wrapper" data-drupal-selector="edit-actions" id="edit-actions--cVJdb9NnWcI"><input class="button js-form-submit form-submit" data-drupal-selector="edit-submit-entry-requirements-o8zuy47syce" id="edit-submit-entry-requirements--O8ZuY47sycE" type="submit" value="Search"/>
# </div>
# </div>
# </form>
# </div>
# <div class="view-content">
# <div class="views-infinite-scroll-content-wrapper clearfix" data-drupal-views-infinite-scroll-content-wrapper=""> <div class="accordion-item views-row">
# <h2 class="accordion-header">
# <button aria-controls="B.Sc.Education(Physics)" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#B.Sc.Education(Physics)" data-bs-toggle="collapse" type="button">
#   B.Sc. Education (Physics)
#   </button>
# </h2>
# <div class="accordion-collapse collapse" data-bs-parent="#view-content" id="B.Sc.Education(Physics)">
# <div class="accordion-body">
# <h3> Entry Requirements</h3>
# <p><strong>Core: </strong>Credit passes in English, Core Mathematics, Integrated Science &amp; Social Studies</p><p><strong>Electives:</strong> Credit passes in Physics and any other two elective subjects</p>
# </div>
# </div>
# </div>
# <div class="accordion-item views-row">
# <h2 class="accordion-header">
# <button aria-controls="B.Sc.Education(Chemistry)" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#B.Sc.Education(Chemistry)" data-bs-toggle="collapse" type="button">
#   B.Sc. Education (Chemistry)
#   </button>
# </h2>
# <div class="accordion-collapse collapse" data-bs-parent="#view-content" id="B.Sc.Education(Chemistry)">
# <div class="accordion-body">
# <h3> Entry Requirements</h3>
# <p><strong>Core: </strong>Credit passes in English, Core Mathematics, Integrated Science &amp; Social Studies</p><p><strong>Electives: </strong>Credit passes in Chemistry and any other two elective subjects</p>
# </div>
# </div>
# </div>
# <div class="accordion-item views-row">
# <h2 class="accordion-header">
# <button aria-controls="B.Sc.Education(Biology)" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#B.Sc.Education(Biology)" data-bs-toggle="collapse" type="button">
#   B.Sc. Education (Biology)
#   </button>
# </h2>
# <div class="accordion-collapse collapse" data-bs-parent="#view-content" id="B.Sc.Education(Biology)">
# <div class="accordion-body">
# <h3> Entry Requirements</h3>
# <p><strong>Core: </strong>Credit passes in English, Core Mathematics, Integrated Science &amp; Social Studies</p><p><strong>Electives:</strong> Credit passes in Biology and any other two elective subjects</p>
# </div>
# </div>
# </div>
# <div class="accordion-item views-row">
# <h2 class="accordion-header">
# ...
#   ✅ Update: defaultdict(<function <lambda> at 0x000001C3503EB160>, {'program': 'Bachelor of Science in Nursing', 'filteringsubject': 'Social Studies', 'alternatecore': 'Integrated Science', 'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies', 'elective subjects': defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001C3503EB4C0>, {'main': ['three electives from any of the combinations below:Chemistry, Physics, Biology or Elective MathematicsGeneral Agriculture, Physics & ChemistryThree General Arts ElectivesTwo General Arts Electives plus Food & NutritionAny three of the following Electives: Economics, Management in Living, Food & Nutrition, Chemistry, General Knowledge in Art and French.'], 'tracks': defaultdict(<class 'dict'>, {'General': []})}), 'special requirements / general information': ['Applicants are expected to select one (1) option', 'Entry RequirementsCore: Credit passes in English, Core Mathematics, Integrated Science & Social StudiesElectives: Credit passes in three electives from any of the combinations below:Chemistry, Physics, Biology or Elective MathematicsGeneral Agriculture, Physics & ChemistryThree General Arts ElectivesTwo General Arts Electives plus Food & NutritionAny three of the following Electives: Economics, Management in Living, Food & Nutrition, Chemistry, General Knowledge in Art and French.']})
#
# >>> Processing Program: Doctor of Pharmacy
#   [Label #0] core => Credit passes in English, Core Mathematics, Integrated Science & Social Studies
#   [Label #1] electives => Credit passes in Chemistry, Biology, and either Physics or Elective Mathematics
#     ↪ All Electives: Chemistry, Biology, and either Physics or Elective Mathematics
#   ✅ Update: defaultdict(<function <lambda> at 0x000001C3503A83A0>, {'program': 'Doctor of Pharmacy', 'filteringsubject': 'Social Studies', 'alternatecore': 'Integrated Science', 'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies', 'elective subjects': defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001C3503EB550>, {'main': ['Chemistry, Biology, and either Physics or Elective Mathematics'], 'tracks': defaultdict(<class 'dict'>, {'General': []})}), 'special requirements / general information': None})
#
# >>> Processing Program: Bachelor of Dental Surgery
#   [Label #0] core => Credit passes in English, Core Mathematics, Integrated Science & Social Studies
#   [Label #1] electives => Credit passes in Chemistry and any two from Physics, Biology and Elective Mathematics
#     ↪ Main Elective: Chemistry
#     ↪ Track Options: two from Physics, Biology and Elective Mathematics
#   ✅ Update: defaultdict(<function <lambda> at 0x000001C3503EB700>, {'program': 'Bachelor of Dental Surgery', 'filteringsubject': 'Social Studies', 'alternatecore': 'Integrated Science', 'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies', 'elective subjects': defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001C350803670>, {'main': ['Chemistry'], 'tracks': defaultdict(<class 'dict'>, {'General': ['two from Physics', 'Biology', 'Elective Mathematics']})}), 'special requirements / general information': None})
# Processing tab: <div aria-labelledby="tab-one" class="views-element-container tab-pane collapse active show mt-5 block block-views block-views-blockentry-requirements-block-1" id="block-views-block-entry-requirements-block-1" role="tabpanel">
# <div><div class="view view-entry-requirements view-id-entry_requirements view-display-id-block_1 js-view-dom-id-c6ca8d10f0522fe2a072e51502b9cd0b8d6b067c3b28ce51d518f0ddc3f92043" data-once="ajax-pager">
# <div class="view-header">
# <h4>Ghanaian Applicants with WASSCE/SSSCE Qualification</h4>
# <br/>
# <h5>A. General Entry Requirements into the Full-Time Degree Programmes</h5>
# <p>An applicant for admission to an undergraduate degree programme in the University of Ghana must have at least credits (A1 - C6 in WASSCE or A - D in SSSCE) in the following subjects: <br/>
# •	The Four Core Subjects: English, Core Mathematics, Integrated Science/Core Science, and Social Studies. <br/>
# •	Three elective subjects. <br/> <br/>
# </p><h5>B. Calculation of Aggregates for Admission </h5>
# The total aggregate of results, comprising six subjects (relevant core and electives), should not exceed: <br/>
# •	Aggregate 24 for Regular admissions. <br/>
# •	Aggregate 30 for Distance Education admissions. <br/>
# <strong> For Science-Related Disciplines:  </strong> <br/>
# •	Aggregate is calculated using English, Core Mathematics, Integrated Science/Core Science, and three elective subjects in the Sciences (refer to specific programme elective requirements below). <br/>
# •	Note: Social Studies credit is excluded in the calculation. <br/>
# <strong> For Non-Science Disciplines:  </strong> <br/>
# •	Aggregate is calculated using English, Core Mathematics, Social Studies/Life Skills, and three elective subjects in General Arts/Business (refer to specific programme elective requirements below). <br/>
# •	Note: Integrated Science/Core Science credit is excluded in the calculation. <br/>
# <br/>
# <br/>
# Search by keyword or college
#     </div>
# <div class="view-filters">
# <form accept-charset="UTF-8" action="/undergraduate/entry-requirements" class="views-exposed-form" data-drupal-selector="views-exposed-form-entry-requirements-block-1" data-once="exposed-form" id="views-exposed-form-entry-requirements-block-1" method="get">
# <div class="form--inline clearfix">
# <div class="js-form-item form-item js-form-type-textfield form-type-textfield js-form-item-title form-item-title">
# <label for="edit-title--xB967WRs9c8">Name of Programme</label>
# <input class="form-text" data-drupal-selector="edit-title" id="edit-title--xB967WRs9c8" maxlength="128" name="title" size="30" type="text" value=""/>
# </div>
# <div class="js-form-item form-item js-form-type-select form-type-select js-form-item-field-college-value form-item-field-college-value">
# <label for="edit-field-college-value--lFtu3pKq7HQ">College</label>
# <select class="form-select" data-drupal-selector="edit-field-college-value" id="edit-field-college-value--lFtu3pKq7HQ" name="field_college_value"><option value="All">- Any -</option><option value="College of Basic and Applied Sciences">College of Basic and Applied Sciences</option><option value="College of Education">College of Education</option><option value="College of Health Sciences">College of Health Sciences</option><option selected="selected" value="College of Humanities">College of Humanities</option></select>
# </div>
# <div class="form-actions js-form-wrapper form-wrapper" data-drupal-selector="edit-actions" id="edit-actions--8vqzqcnbFDs"><input class="button js-form-submit form-submit" data-drupal-selector="edit-submit-entry-requirements-mjwnz2nun4u" id="edit-submit-entry-requirements--Mjwnz2nUN4U" type="submit" value="Search"/>
# </div>
# </div>
# </form>
# </div>
# <div class="view-content">
# <div class="views-infinite-scroll-content-wrapper clearfix" data-drupal-views-infinite-scroll-content-wrapper=""> <div class="accordion-item views-row">
# <h2 class="accordion-header">
# <button aria-controls="BachelorofFineArts" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#BachelorofFineArts" data-bs-toggle="collapse" type="button">
#   Bachelor of Fine Arts
#   </button>
# </h2>
# <div class="accordion-collapse collapse" data-bs-parent="#view-content" id="BachelorofFineArts">
# <div class="accordion-body">
# <h3> Entry Requirements</h3>
# <p><strong>Core: </strong>Credit passes in English, Core Mathematics, Integrated Science &amp; Social Studies</p><p><strong>Electives: </strong>Credit passes in any three electives subjects.</p><p>The programme is open to applicants interested in the Performing Arts with aggregate 24 or better. They will be expected to attend an audition or interview.</p>
# </div>
# </div>
# </div>
# <div class="accordion-item views-row">
# <h2 class="accordion-header">
# <button aria-controls="BachelorofLaws(LLB)" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#BachelorofLaws(LLB)" data-bs-toggle="collapse" type="button">
#   Bachelor of Laws (LLB)
#   </button>
# </h2>
# <div class="accordion-collapse collapse" data-bs-parent="#view-content" id="BachelorofLaws(LLB)">
# <div class="accordion-body">
# <h3> Entry Requirements</h3>
# <p><strong>Core: </strong>Credit passes in English, Core Mathematics, Integrated Science &amp; Social Studies</p><p><strong>Electives: </strong>Credit passes in any three elective subjects</p>
# </div>
# </div>
# </div>
# <div class="accordion-item views-row">
# <h2 class="accordion-header">
# <button aria-controls="BachelorofScienceinBusinessAdministration" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#BachelorofScienceinBusinessAdministration" data-bs-toggle="collapse" type="button">
#   Bachelor of Science in Business Administration
#   </button>
# </h2>
# <div class="accordion-collapse collapse" data-bs-parent="#view-content" id="BachelorofScienceinBusinessAdministration">
# <div class="accordion-body">
# <h3> Entry Requirements</h3>
# <p><strong>Core: </strong>Credit passes in English, Core Mathematics, Integrated Science &amp; Social Studies</p><p><strong>Electives: </strong>Credit passes in any three elective subjects</p>
# </div>
# </div>
# </div>
# <div class="accordion-item views-row">
# <h2 class="accordion-header">
# <button aria-controls="BachelorofArts" aria-expanded="true" class="accordion-button collapsed" data-bs-target="#BachelorofArts" data-bs-toggle="collapse" type="button">
#   Bachelor of Arts
#   </button>
# </h2>
# <div class="accordion-collapse collapse" data-bs-parent="#view-content" id="BachelorofArts">
# <div class="accordion-body">
# <h3> Entry Requirements</h3>
# <p><strong>Core</strong>: Credit passes in English, Core Mathematics, Integrated Science &amp; Social Studies</p><p><strong>Electives</strong>: Credit passes in any three elective subjects</p><p> </p><p><strong>Applicants must have the following WASSCE subjects to qualify to read the under-listed courses:</strong></p><table><tbody><tr><td>Economics Mathematics or Statistics  </td><td>Elective Mathematics</td></tr><tr><td>Computer Science</td><td>Elective Mathematics</td></tr><tr><td>French</td><td>French</td></tr><tr><td>English</td><td>English Literature</td></tr><tr><td>Geography</td><td>Geography</td></tr><tr><td>Accounting</td><td>Accounting and Elective Mathematics or Accounting and Principles of Costing </td></tr></tbody></table><p><br/>  </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
#
#
#
#
#
# >>> Processing Program: Bachelor of Fine Arts
#   [Label #0] core: => Credit passes in English, Core Mathematics, Integrated Science & Social Studies
#   [Label #1] electives: => Credit passes in any three electives subjects.
#     ↪ All Electives: any three electives subjects.
#   ➕ Additional Info: ['Electives:Credit passes in any three electives subjects.', 'The programme is open to applicants interested in the Performing Arts with aggregate 24 or better. They will be expected to attend an audition or interview.']
#   ✅ Update: defaultdict(<function <lambda> at 0x000001C3503CA1F0>, {'program': 'Bachelor of Fine Arts', 'filteringsubject': 'Social Studies', 'alternatecore': 'Integrated Science', 'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies', 'elective subjects': defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001C3503A8CA0>, {'main': ['any three electives subjects.'], 'tracks': defaultdict(<class 'dict'>, {'General': []})}), 'special requirements / general information': ['Electives:Credit passes in any three electives subjects.', 'The programme is open to applicants interested in the Performing Arts with aggregate 24 or better. They will be expected to attend an audition or interview.']})
#
# >>> Processing Program: Bachelor of Laws (LLB)
#   [Label #0] core: => Credit passes in English, Core Mathematics, Integrated Science & Social Studies
#   [Label #1] electives: => Credit passes in any three elective subjects
#     ↪ All Electives: any three elective subjects
#   ➕ Additional Info: ['Electives:Credit passes in any three elective subjects']
#   ✅ Update: defaultdict(<function <lambda> at 0x000001C35025EAF0>, {'program': 'Bachelor of Laws (LLB)', 'filteringsubject': 'Social Studies', 'alternatecore': 'Integrated Science', 'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies', 'elective subjects': defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001C3503A8AF0>, {'main': ['any three elective subjects'], 'tracks': defaultdict(<class 'dict'>, {'General': []})}), 'special requirements / general information': ['Electives:Credit passes in any three elective subjects']})
#
# >>> Processing Program: Bachelor of Science in Business Administration
#   [Label #0] core: => Credit passes in English, Core Mathematics, Integrated Science & Social Studies
#   [Label #1] electives: => Credit passes in any three elective subjects
#     ↪ All Electives: any three elective subjects
#   ➕ Additional Info: ['Electives:Credit passes in any three elective subjects']
#   ✅ Update: defaultdict(<function <lambda> at 0x000001C35025E550>, {'program': 'Bachelor of Science in Business Administration', 'filteringsubject': 'Social Studies', 'alternatecore': 'Integrated Science', 'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies', 'elective subjects': defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001C3503A81F0>, {'main': ['any three elective subjects'], 'tracks': defaultdict(<class 'dict'>, {'General': []})}), 'special requirements / general information': ['Electives:Credit passes in any three elective subjects']})
#
# >>> Processing Program: Bachelor of Arts
#   [Label #0] core => Credit passes in English, Core Mathematics, Integrated Science & Social Studies
#   [Label #1] electives => Credit passes in any three elective subjects
#     ↪ All Electives: any three elective subjects
#   ➕ Additional Info: ['Electives: Credit passes in any three elective subjects', 'Applicants must have the following WASSCE subjects to qualify to read the under-listed courses:']
#   📋 Concentration table(s) found for Bachelor of Arts
#     - economics mathematics or statistics: Elective Mathematics
#     - computer science: Elective Mathematics
#     - french: French
#     - english: English Literature
#     - geography: Geography
#     - accounting: Accounting and Elective Mathematics or Accounting and Principles of Costing
#   ✅ Update: defaultdict(<function <lambda> at 0x000001C3503EB820>, {'program': 'Bachelor of Arts', 'filteringsubject': 'Social Studies', 'alternatecore': 'Integrated Science', 'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies', 'elective subjects': defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001C3503EB940>, {'main': ['any three elective subjects'], 'tracks': defaultdict(<class 'dict'>, {'General': []})}), 'special requirements / general information': ['Electives: Credit passes in any three elective subjects', 'Applicants must have the following WASSCE subjects to qualify to read the under-listed courses:'], 'concentrations': {'economics mathematics or statistics': 'Elective Mathematics', 'computer science': 'Elective Mathematics', 'french': 'French', 'english': 'English Literature', 'geography': 'Geography', 'accounting': 'Accounting and Elective Mathematics or Accounting and Principles of Costing'}})
#   [Label #2] applicants must have the following wassce subjects to qualify to read the under-listed courses: =>

# %%
all_programs
# Out:
# [defaultdict(<function __main__.<lambda>()>,
#              {'program': 'BSc. Actuarial Science',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['Elective Mathematics'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': None}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'BSc. Computer Science',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['Elective Mathematics'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': None}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'Doctor of Veterinary Medicine',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['Biology, Chemistry, and either Physics or Elective Mathematics'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': None}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'Bachelor of Science in Engineering Sciences (Materials Science & Engineering Option)',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['Physics, Chemistry, and Elective Mathematics, with at least a B3 in Elective Mathematics'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': None}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'Bachelor of Science in Engineering Sciences (Food Process Engineering Option)',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['Physics, Chemistry, and Elective Mathematics, with at least a B3 in Elective Mathematics'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': None}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'Bachelor of Science in Engineering Sciences (Computer Engineering Option)',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['Physics, Chemistry and Elective Mathematics, with at least a B3 in Elective Mathematics'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': None}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'Bachelor of Science in Engineering Sciences (Biomedical Engineering Option)',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['Physics, Chemistry and Elective Mathematics, with at least a B3 in Elective Mathematics'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': None}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'Bachelor of Science in Engineering Sciences (Agriculture Engineering Option)',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['Physics, Chemistry, and Elective Mathematics, with at least a B3 in Elective Mathematics'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': None}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'Bachelor of Science in Family & Consumer Sciences (Family and Child Studies Option)',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['Credit pass in Management in Living'],
#                            'tracks': defaultdict(dict,
#                                        {'General': ['two of the following: Food',
#                                          'Nutrition',
#                                          'Textiles',
#                                          'Clothing',
#                                          'General Knowledge in Art',
#                                          'Biology',
#                                          'Chemistry.']})}),
#               'special requirements / general information': None}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'Bachelor of Science in Family & Consumer Sciences (Food and Clothing Option)',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['Home Science Background: Management in Living and Chemistry, and either Food and Nutrition or Textile and ClothingScience Background: Chemistry'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': None}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'Bachelor of Science in Agriculture',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['Chemistry'],
#                            'tracks': defaultdict(dict,
#                                        {'General': ['two of Physics',
#                                          'Biology/Agriculture Science',
#                                          'Geography',
#                                          'Elective Mathematics']})}),
#               'special requirements / general information': None}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'Bachelor of Science in Psychology',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['Biology and Elective Mathematics'],
#                            'tracks': defaultdict(dict,
#                                        {'General': ['one of Physics',
#                                          'Chemistry']})}),
#               'special requirements / general information': None}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'Bachelor of Science in Biological Sciences',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['Chemistry, Physics, and Biology'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': None}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'Bachelor of Science in Information Technology',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['any three subjects, with at least a'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': None}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'Bachelor of Science in Earth Sciences',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['Chemistry'],
#                            'tracks': defaultdict(dict,
#                                        {'General': ['two of Physics',
#                                          'Biology/Geography',
#                                          'Elective Mathematics']})}),
#               'special requirements / general information': ['Geology, Applied Geology, Applied GeophysicsEntry requirements:Core: Credit passes in English, Core Mathematics, Integrated Science & Social StudiesElectives: Credit passes in Chemistry and any two of Physics, Biology/Geography and Elective Mathematics']}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'Bachelor of Science in Mathematical Sciences',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['Elective Mathematics'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': ['Or',
#                'Bachelor of Science in any TWO of the following subjects:Mathematics, Statistics, Computer Science, Physics',
#                'NoteI: Applicants who choose the Mathematical Sciences option cannot pursue a single major in Computer Science, but they may combine Computer Science with any of the other three subjects: Mathematics, Statistics, or Physics.Entry requirements:Core: Credit passes in English, Core Mathematics, Integrated Science & Social StudiesElectives: Credit passes in Elective Mathematics and any two subjects with at least aB3 in Elective Mathematics',
#                'NoteII:\xa0Applicants who choose the Mathematical Sciences option may ONLY pursue a single or combined major in Physicsifthey have credit passes inboth Physics and Chemistry.']}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'Bachelor of Science in Physical Sciences',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['Physics, Chemistry, and Elective Mathematics, with at least a'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': ['Note:\xa0Applicants who choose the Physical Sciences Option may ONLY pursue a\xa0 combined major with a Mathematical Sciences Subjectifthey have a B3 in Elective\xa0 Mathematics.']}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'B.Sc. Education (Physics)',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['Physics'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': ['Electives:Credit passes in Physics and any other two elective subjects']}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'B.Sc. Education (Chemistry)',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['Chemistry'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': ['Electives:Credit passes in Chemistry and any other two elective subjects']}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'B.Sc. Education (Biology)',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['Biology'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': ['Electives:Credit passes in Biology and any other two elective subjects']}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'B.Sc. Education (Mathematics)',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['Elective Mathematics'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': ['Electives:Credit passes in Elective Mathematics and any other two elective subjects']}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'BA Sport and Physical Culture Studies',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['any three elective subjects'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': ['Electives: Credit passes in any three elective subjects']}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'BA Education (Non-Teaching)',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['any three elective subjects.'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': ['Electives:Credit passes in any three elective subjects.']}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'BA Education (English)',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['any three elective subjects including English Literature.'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': ['Electives:Credit passes in any three elective subjects including English Literature.']}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'Bachelor of Medicine and Bachelor of Surgery',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['Chemistry'],
#                            'tracks': defaultdict(dict,
#                                        {'General': ['two from Physics',
#                                          'Biology',
#                                          'Elective Mathematics']})}),
#               'special requirements / general information': None}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'Bachelor of Public Health',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['three electives from any of the combinations below:Chemistry, Physics, Biology, or Elective MathematicsGeneral Agriculture, Physics & ChemistryThree General Arts ElectivesTwo General Arts Electives plus Food & NutritionAny three of the following Electives: Economics, Food & Nutrition, Chemistry, and French.'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': None}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'Bachelor of Science in Midwifery',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['three electives from any of the combinations below:Chemistry, Physics, Biology, or Elective MathematicsGeneral Agriculture, Physics & ChemistryThree General Arts ElectivesTwo General Arts Electives plus Food & NutritionAny three of the following Electives: Economics, Management in Living, Food & Nutrition, Chemistry, General Knowledge in Art and French.'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': None}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'School of Biomedical & Allied Health Sciences',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['Chemistry, Physics, and either Biology or Elective Mathematics'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': ['Bachelor of Science in Medical Laboratory',
#                'Bachelor of Science in Occupational Therapy',
#                'Bachelor of Science in Physiotherapy',
#                'Bachelor of Science in Radiography',
#                'Bachelor of Science in Respiratory Therapy',
#                'Entry requirements:Core: Credit passes in English, Core Mathematics, Integrated Science & Social StudiesElectives: Credit passes in Chemistry, Physics, and either Biology or Elective Mathematics']}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'Bachelor of Science in Nursing',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['three electives from any of the combinations below:Chemistry, Physics, Biology or Elective MathematicsGeneral Agriculture, Physics & ChemistryThree General Arts ElectivesTwo General Arts Electives plus Food & NutritionAny three of the following Electives: Economics, Management in Living, Food & Nutrition, Chemistry, General Knowledge in Art and French.'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': ['Applicants are expected to select one (1) option',
#                'Entry RequirementsCore: Credit passes in English, Core Mathematics, Integrated Science & Social StudiesElectives: Credit passes in three electives from any of the combinations below:Chemistry, Physics, Biology or Elective MathematicsGeneral Agriculture, Physics & ChemistryThree General Arts ElectivesTwo General Arts Electives plus Food & NutritionAny three of the following Electives: Economics, Management in Living, Food & Nutrition, Chemistry, General Knowledge in Art and French.']}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'Doctor of Pharmacy',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['Chemistry, Biology, and either Physics or Elective Mathematics'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': None}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'Bachelor of Dental Surgery',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['Chemistry'],
#                            'tracks': defaultdict(dict,
#                                        {'General': ['two from Physics',
#                                          'Biology',
#                                          'Elective Mathematics']})}),
#               'special requirements / general information': None}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'Bachelor of Fine Arts',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['any three electives subjects.'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': ['Electives:Credit passes in any three electives subjects.',
#                'The programme is open to applicants interested in the Performing Arts with aggregate 24 or better. They will be expected to attend an audition or interview.']}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'Bachelor of Laws (LLB)',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['any three elective subjects'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': ['Electives:Credit passes in any three elective subjects']}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'Bachelor of Science in Business Administration',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['any three elective subjects'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': ['Electives:Credit passes in any three elective subjects']}),
#  defaultdict(<function __main__.<lambda>()>,
#              {'program': 'Bachelor of Arts',
#               'filteringsubject': 'Social Studies',
#               'alternatecore': 'Integrated Science',
#               'core subjects': 'English, Core Mathematics, Integrated Science, Social Studies',
#               'elective subjects': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                           {'main': ['any three elective subjects'],
#                            'tracks': defaultdict(dict, {'General': []})}),
#               'special requirements / general information': ['Electives: Credit passes in any three elective subjects',
#                'Applicants must have the following WASSCE subjects to qualify to read the under-listed courses:'],
#               'concentrations': {'economics mathematics or statistics': 'Elective Mathematics',
#                'computer science': 'Elective Mathematics',
#                'french': 'French',
#                'english': 'English Literature',
#                'geography': 'Geography',
#                'accounting': 'Accounting and Elective Mathematics or Accounting and Principles of Costing'}})]

# %%
with open('ug_programs.json', 'w') as f:
    json.dump(all_programs, f, indent=4)

# %%
with open('ug_programs copy 2.json', 'r') as f:
    data = json.load(f)
# load the JSON file and print its content
with open('ug_cutoffPoints.json', 'r') as f:
    cutoffpoints = json.load(f)

# update the programs with cutoff points, college
def format_names(full_program):
    program = full_program["program"].replace("BSc. ", "").replace("B.Sc. ", '').replace("BA ", "").replace("BFA ", "").replace("BSc ", "").replace("BA ", "")
    program = program.replace("Bachelor of ", "").replace("Bachelor ", "").strip()
    return program

for program in data:
    program_name = format_names(program["program"])
    program["program"] = program_name
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_33036/1520001654.py in <module>
#      12
#      13 for program in data:
# ---> 14     program_name = format_names(program["program"])
#      15     program["program"] = program_name
#
# KeyError: 'program'

# %%
# update the programs with cutoff points, college
def format_names(full_program):
    program = full_program["program"].replace("BSc. ", "").replace("B.Sc. ", '').replace("BA ", "").replace("BFA ", "").replace("BSc ", "").replace("BA ", "")
    program = program.replace("Bachelor of ", "").replace("Bachelor ", "").strip()
    return program

for program in data:
    program_name = format_names(program["program"])
    program["program"] = program_name

# %%
# update cutoff points from list of programs dict in ug_cutoffPoints.json
for program in data:
    for cutoff in cutoffpoints:
        if program["program"].lower() == cutoff["program"].lower():
            program["cutoff points"] = cutoff["cutoff points"]
            program["college"] = cutoff["college"]
            print(f"Updated {program['program']} with cutoff points: {cutoff['cutoff points']} and college: {cutoff['college']}")
            break
    else:
        print(f"No cutoff points found for {program['program']}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4004/3387828416.py in <module>
#       1 # update cutoff points from list of programs dict in ug_cutoffPoints.json
# ----> 2 for program in data:
#       3     for cutoff in cutoffpoints:
#       4         if program["program"].lower() == cutoff["program"].lower():
#       5             program["cutoff points"] = cutoff["cutoff points"]
#
# NameError: name 'data' is not defined
