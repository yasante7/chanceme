# %%
import json
from bs4 import BeautifulSoup

# %%
# Read the HTML file
with open('html.html', 'r', encoding='utf-8') as f:
    html_content = f.read()

# Parse HTML
soup = BeautifulSoup(html_content, 'html.parser')

# Initialize the data structure
cutoff_data = []

# Find all college sections
college_sections = soup.find_all('div', class_="table-responsible-md")
college_names = [college.text.strip() for college in soup.find_all('h4')]

# %%
for i, section in enumerate(college_sections):
    # Get college name from h4 tag
    college_name = college_names[i]
    
    # Find the table
    table = section.find('table')
    if not table:
        continue
        
    # Get all rows except header
    rows = table.find_all('tr')[1:]  # Skip header row
    
    for row in rows:
        cells = row.find_all('td')
        if len(cells) >= 5:  # Ensure we have all required columns
            first_choiceNS, first_choiceSA = cells[1].text.strip().split('/') if '/' in cells[1].text.strip() else (None, cells[1].text.strip())
            program = {
                "program": cells[0].text.strip(),
                "college": college_name,
                "cutoff point": {
                    "firstChoiceSubjectArea": first_choiceSA,
                    "firstChoiceNonSubject": first_choiceNS,
                    "fullFeePaying": cells[2].text.strip() if cells[2].text.strip() != '-' else None,
                    "secondChoice": cells[3].text.strip() if cells[3].text.strip() != '-' else None,
                    "subjectRequirements": cells[4].text.strip() if cells[4].text.strip() != '-' else None
                    }
            }
            cutoff_data.append(program)

# %%
cutoff_data
# Out:
# [{'program': 'BSc. Agricultural Engineering',
#   'college': 'College of Basic & Applied Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '17',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': '19/20',
#    'secondChoice': None,
#    'subjectRequirements': 'B3 in Elective Maths'}},
#  {'program': 'BSc. Biomedical Engineering',
#   'college': 'College of Basic & Applied Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '7',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': '9',
#    'secondChoice': None,
#    'subjectRequirements': 'B3 in Elective Maths'}},
#  {'program': 'BSc. Computer Engineering',
#   'college': 'College of Basic & Applied Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '6',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': '7',
#    'secondChoice': None,
#    'subjectRequirements': 'B3 in Elective Maths'}},
#  {'program': 'BSc. Food Process Engineering',
#   'college': 'College of Basic & Applied Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '12',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': '15',
#    'secondChoice': None,
#    'subjectRequirements': 'B3 in Elective Maths'}},
#  {'program': 'BSc. Materials Science & Engineering',
#   'college': 'College of Basic & Applied Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '12',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': '14/15',
#    'secondChoice': None,
#    'subjectRequirements': 'B3 in Elective Maths'}},
#  {'program': 'BSc. Biological Sciences',
#   'college': 'College of Basic & Applied Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '14',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': '15/17',
#    'secondChoice': '12(13 for Full Fee Paying)',
#    'subjectRequirements': 'C6 in Chemistry, C6 Biology, C6 Physics'}},
#  {'program': 'BSc. Psychology',
#   'college': 'College of Basic & Applied Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '18',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': '20',
#    'secondChoice': None,
#    'subjectRequirements': None}},
#  {'program': 'Doctor of Veterinary Medicine',
#   'college': 'College of Basic & Applied Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '13',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': None}},
#  {'program': 'BSc. Actuarial Science',
#   'college': 'College of Basic & Applied Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '11',
#    'firstChoiceNonSubject': '10',
#    'fullFeePaying': '14',
#    'secondChoice': None,
#    'subjectRequirements': 'B3 in Elective Mathematics'}},
#  {'program': 'BSc. Computer Science',
#   'college': 'College of Basic & Applied Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '9',
#    'firstChoiceNonSubject': '7',
#    'fullFeePaying': '14',
#    'secondChoice': None,
#    'subjectRequirements': 'B3 in Elective Mathematics'}},
#  {'program': 'BSc. Information Technology',
#   'college': 'College of Basic & Applied Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '8',
#    'firstChoiceNonSubject': '7',
#    'fullFeePaying': '11',
#    'secondChoice': None,
#    'subjectRequirements': 'B2 in Core Maths'}},
#  {'program': 'BSc. Earth Sciences',
#   'college': 'College of Basic & Applied Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '18',
#    'firstChoiceNonSubject': '17',
#    'fullFeePaying': '20',
#    'secondChoice': None,
#    'subjectRequirements': 'C6 in Chemistry, C6 in Physics'}},
#  {'program': 'BSc. Physical Sciences',
#   'college': 'College of Basic & Applied Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '24',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': 'C6 in Chemistry, C6 in Physics'}},
#  {'program': 'BSc. Mathematical Sciences',
#   'college': 'College of Basic & Applied Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '12',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': '16',
#    'secondChoice': None,
#    'subjectRequirements': 'B3 in Elective Maths'}},
#  {'program': 'BSc. Agriculture',
#   'college': 'College of Basic & Applied Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '20',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': 'C6 in Chemistry'}},
#  {'program': 'BSc. Family & Child Studies',
#   'college': 'College of Basic & Applied Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '15',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': 'C6 in Management in Living'}},
#  {'program': 'BSc. Food & Clothing',
#   'college': 'College of Basic & Applied Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '15',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': 'C6 in Chemistry'}},
#  {'program': 'Bachelor of Medicine and Bachelor of Surgery',
#   'college': 'College of Health Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '7',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': None}},
#  {'program': 'Bachelor of Dental Surgery',
#   'college': 'College of Health Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '8',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': None}},
#  {'program': 'Doctor of Pharmacy',
#   'college': 'College of Health Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '8',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': None}},
#  {'program': 'BSc. Nursing',
#   'college': 'College of Health Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '9',
#    'firstChoiceNonSubject': '8',
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': '08 for Non Science / 09 for Science Background'}},
#  {'program': 'BSc. Midwifery',
#   'college': 'College of Health Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '9',
#    'firstChoiceNonSubject': '8',
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': '08 for Non Science / 09 for Science Background'}},
#  {'program': 'BSc. Medical Laboratory Sciences',
#   'college': 'College of Health Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '12',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': '11',
#    'subjectRequirements': None}},
#  {'program': 'BSc. Physiotherapy',
#   'college': 'College of Health Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '14',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': '12',
#    'subjectRequirements': None}},
#  {'program': 'BSc. Dietetics',
#   'college': 'College of Health Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '14',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': '12',
#    'subjectRequirements': None}},
#  {'program': 'BSc. Diagnostic Radiography',
#   'college': 'College of Health Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '13',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': '12',
#    'subjectRequirements': None}},
#  {'program': 'BSc. Occupational Therapy',
#   'college': 'College of Health Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '15',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': '14',
#    'subjectRequirements': None}},
#  {'program': 'BSc. Respiratory Therapy',
#   'college': 'College of Health Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '14',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': '13',
#    'subjectRequirements': None}},
#  {'program': 'Bachelor of Public Health',
#   'college': 'College of Health Sciences',
#   'cutoff point': {'firstChoiceSubjectArea': '12',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': None}},
#  {'program': 'Bachelor of Education in Social Studies',
#   'college': 'College of Education',
#   'cutoff point': {'firstChoiceSubjectArea': '20',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': None}},
#  {'program': 'Bachelor of Education in English',
#   'college': 'College of Education',
#   'cutoff point': {'firstChoiceSubjectArea': '18',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': 'C6 in English Literature'}},
#  {'program': 'Bachelor of Education in Mathematics',
#   'college': 'College of Education',
#   'cutoff point': {'firstChoiceSubjectArea': '24',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': 'C6 in Elective Mathematics'}},
#  {'program': 'Bachelor of Education in Science (Physics)',
#   'college': 'College of Education',
#   'cutoff point': {'firstChoiceSubjectArea': '24',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': 'C6 in Physics'}},
#  {'program': 'Bachelor of Education in Science (Chemistry)',
#   'college': 'College of Education',
#   'cutoff point': {'firstChoiceSubjectArea': '24',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': 'C6 in Chemistry'}},
#  {'program': 'Bachelor of Education in Science (Biology)',
#   'college': 'College of Education',
#   'cutoff point': {'firstChoiceSubjectArea': '24',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': 'C6 in Biology'}},
#  {'program': 'Bachelor of Education (Early Grade Specialism)',
#   'college': 'College of Education',
#   'cutoff point': {'firstChoiceSubjectArea': '24',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': '',
#    'secondChoice': '',
#    'subjectRequirements': ''}},
#  {'program': 'Bachelor of Education (JHS Specialism)',
#   'college': 'College of Education',
#   'cutoff point': {'firstChoiceSubjectArea': '21',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': None}},
#  {'program': 'Bachelor of Education (Upper Grade Specialism)',
#   'college': 'College of Education',
#   'cutoff point': {'firstChoiceSubjectArea': '22',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': '',
#    'secondChoice': '',
#    'subjectRequirements': ''}},
#  {'program': 'Bachelor of Arts in Sports and Physical Culture',
#   'college': 'College of Education',
#   'cutoff point': {'firstChoiceSubjectArea': '20',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': '',
#    'secondChoice': '',
#    'subjectRequirements': ''}},
#  {'program': 'BSc. Administration - (Kumasi and Takoradi City Campuses)',
#   'college': 'College of Education',
#   'cutoff point': {'firstChoiceSubjectArea': '24',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': '',
#    'secondChoice': '',
#    'subjectRequirements': ''}},
#  {'program': 'Bachelor of Arts',
#   'college': 'Distance Education',
#   'cutoff point': {'firstChoiceSubjectArea': '30',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': ''}},
#  {'program': 'B.Sc Administration',
#   'college': 'Distance Education',
#   'cutoff point': {'firstChoiceSubjectArea': '30',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': ''}},
#  {'program': 'B.Sc. Information Technology',
#   'college': 'Distance Education',
#   'cutoff point': {'firstChoiceSubjectArea': '24',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': ''}},
#  {'program': 'Bachelor of Education (Early Grade Specialism)',
#   'college': 'Distance Education',
#   'cutoff point': {'firstChoiceSubjectArea': '30',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': ''}},
#  {'program': 'Bachelor of Education (Upper Grade Specialism)',
#   'college': 'Distance Education',
#   'cutoff point': {'firstChoiceSubjectArea': '30',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': ''}},
#  {'program': 'Bachelor of Education (JHS Specialism)',
#   'college': 'Distance Education',
#   'cutoff point': {'firstChoiceSubjectArea': '30',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': ''}},
#  {'program': 'Bachelor of Laws',
#   'college': 'College of Humanities',
#   'cutoff point': {'firstChoiceSubjectArea': '6',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': '',
#    'secondChoice': '',
#    'subjectRequirements': ''}},
#  {'program': 'BSc. Administration',
#   'college': 'College of Humanities',
#   'cutoff point': {'firstChoiceSubjectArea': '7',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': ''}},
#  {'program': 'BSc. Administration - (Full-Fee Paying)',
#   'college': 'College of Humanities',
#   'cutoff point': {'firstChoiceSubjectArea': '14',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': '',
#    'secondChoice': '',
#    'subjectRequirements': ''}},
#  {'program': 'Bachelor of Arts (General Arts Background)',
#   'college': 'College of Humanities',
#   'cutoff point': {'firstChoiceSubjectArea': '14(15)',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': '',
#    'secondChoice': '',
#    'subjectRequirements': ''}},
#  {'program': 'Bachelor of Arts (Full-Fee Paying)',
#   'college': 'College of Humanities',
#   'cutoff point': {'firstChoiceSubjectArea': '17',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': '',
#    'subjectRequirements': ''}},
#  {'program': 'Bachelor of Arts (Bouquets with a Business Subject)',
#   'college': 'College of Humanities',
#   'cutoff point': {'firstChoiceSubjectArea': '10',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': ''}},
#  {'program': 'Bachelor of Arts (Bouquets with a Business Subject)(Full-Fee Paying',
#   'college': 'College of Humanities',
#   'cutoff point': {'firstChoiceSubjectArea': '17',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': None,
#    'secondChoice': None,
#    'subjectRequirements': ''}},
#  {'program': 'Bachelor of Arts (Business/Science/ Vocational Background)',
#   'college': 'College of Humanities',
#   'cutoff point': {'firstChoiceSubjectArea': '12',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': '',
#    'secondChoice': '',
#    'subjectRequirements': ''}},
#  {'program': 'Bachelor of Fine Arts',
#   'college': 'College of Humanities',
#   'cutoff point': {'firstChoiceSubjectArea': '22',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': '',
#    'secondChoice': '',
#    'subjectRequirements': ''}},
#  {'program': 'Bachelor of Arts',
#   'college': 'Accra City Campus',
#   'cutoff point': {'firstChoiceSubjectArea': '24',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': '',
#    'secondChoice': '',
#    'subjectRequirements': ''}},
#  {'program': 'BSc. Administration',
#   'college': 'Accra City Campus',
#   'cutoff point': {'firstChoiceSubjectArea': '24',
#    'firstChoiceNonSubject': None,
#    'fullFeePaying': '',
#    'secondChoice': '',
#    'subjectRequirements': ''}}]

# %%
# Save to JSON file
with open("ug_cutoffPointsnew.json", 'w', encoding='utf-8') as f:
    json.dump(cutoff_data, f, indent=2)

# %%
with open('updated_ug.json', 'r') as f:
    existing_data = json.load(f)

existing_data
# Out:
# [{'schoolname': 'University of Ghana'},
#  [{'program': 'BSc. Actuarial Science',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoice': '10/11',
#     'fullFeePaying': '14',
#     'secondChoice': '-',
#     'subjectRequirements': 'B3 in Elective Mathematics'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Elective Mathematics'],
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': 'at least a B3 in Elective Mathematics'},
#   {'program': 'BSc. Computer Science',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoice': '7/9',
#     'fullFeePaying': '14',
#     'secondChoice': '-',
#     'subjectRequirements': 'B3 in Elective Mathematics'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Elective Mathematics'],
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': 'at least a B3 in Elective Mathematics'},
#   {'program': 'Doctor of Veterinary Medicine',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoice': '13',
#     'fullFeePaying': '-',
#     'secondChoice': '-',
#     'subjectRequirements': '-'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General': ['Biology',
#       'Chemistry',
#       ['Physics', 'Elective Mathematics']]}},
#    'special requirements / general information': None},
#   {'program': 'BSc. Materials Science & Engineering',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoice': '12',
#     'fullFeePaying': '14/15',
#     'secondChoice': '-',
#     'subjectRequirements': 'B3 in Elective Maths'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General': ['Chemistry', 'Physics', 'Elective Mathematics']}},
#    'special requirements / general information': 'at least a B3 in Elective Mathematics'},
#   {'program': 'BSc. Food Process Engineering',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoice': '12',
#     'fullFeePaying': '15',
#     'secondChoice': '-',
#     'subjectRequirements': 'B3 in Elective Maths'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General': ['Chemistry', 'Physics', 'Elective Mathematics']}},
#    'special requirements / general information': 'at least a B3 in Elective Mathematics'},
#   {'program': 'BSc. Computer Engineering',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoice': '6',
#     'fullFeePaying': '7',
#     'secondChoice': '-',
#     'subjectRequirements': 'B3 in Elective Maths'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General': ['Chemistry', 'Physics', 'Elective Mathematics']}},
#    'special requirements / general information': 'at least a B3 in Elective Mathematics'},
#   {'program': 'BSc. Biomedical Engineering',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoice': '7',
#     'fullFeePaying': '9',
#     'secondChoice': '-',
#     'subjectRequirements': 'B3 in Elective Maths'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General': ['Chemistry', 'Physics', 'Elective Mathematics']}},
#    'special requirements / general information': 'at least a B3 in Elective Mathematics'},
#   {'program': 'BSc. Agricultural Engineering',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoice': '17',
#     'fullFeePaying': '19/20',
#     'secondChoice': '-',
#     'subjectRequirements': 'B3 in Elective Maths'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General': ['Chemistry', 'Physics', 'Elective Mathematics']}},
#    'special requirements / general information': 'at least a B3 in Elective Mathematics'},
#   {'program': 'Bachelor of Science in Family & Consumer Sciences (Family and Child Studies Option)',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Management in Living'],
#     'tracks': {'General': ['Food and Nutrition',
#       'Clothing and Textiles',
#       'General Knowledge in Art',
#       ['Biology', 'Chemistry']]}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Science in Family & Consumer Sciences (Food and Clothing Option)',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': [['Management in Living', 'Chemistry'],
#      ['Chemistry']],
#     'tracks': {'General': ['Food and Nutrition', 'Clothing and Textiles'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Biology',
#       'Elective ICT',
#       'Geography']}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Science in Agriculture',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoice': '20',
#     'fullFeePaying': '-',
#     'secondChoice': '-',
#     'subjectRequirements': 'C6 in Chemistry'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Chemistry'],
#     'tracks': {'General': ['Physics',
#       ['Biology', 'Agricultural Science'],
#       'Geography',
#       'Elective Mathematics']}},
#    'special requirements / general information': 'Bachelor of Science in Agriculture: Animal Science, Crop Science, Soil Science, Agriculture Economics, Agribusiness, Agriculture Extension, Post-Harvest Technology.'},
#   {'program': 'Bachelor of Science in Psychology',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoice': '18',
#     'fullFeePaying': '20',
#     'secondChoice': '-',
#     'subjectRequirements': '-'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Biology', 'Elective Mathematics'],
#     'tracks': {'General': ['Physics', 'Chemistry']}},
#    'special requirements / general information': None},
#   {'program': 'BSc. Biological Sciences',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoice': '14',
#     'fullFeePaying': '15/17',
#     'secondChoice': '12(13 for Full Fee Paying)',
#     'subjectRequirements': 'C6 in Chemistry, C6 Biology, C6 Physics'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Chemistry', 'Physics', 'Biology'],
#     'tracks': {}},
#    'special requirements / general information': 'Bachelor of Science degree in any one of the following subjects: Animal Biology and Conservation Science, Biochemistry Cell and Molecular Biology, Nutrition, Food Science, Plant and Environmental Biology, Marine Science, Fisheries Science, Psychology, Microbiology.'},
#   {'program': 'Bachelor of Science in Information Technology',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoice': '24',
#     'fullFeePaying': '-',
#     'secondChoice': '-',
#     'subjectRequirements': ''},
#    'campus': 'Main Campus (Legon)',
#    'college': 'Distance Education',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Crop Science',
#       'Chemistry',
#       'Physics']}},
#    'special requirements / general information': 'at least a B3 in Core Mathematics'},
#   {'program': 'Bachelor of Science in Earth Sciences',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoice': '17/18',
#     'fullFeePaying': '20',
#     'secondChoice': '-',
#     'subjectRequirements': 'C6 in Chemistry, C6 in Physics'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Chemistry'],
#     'tracks': {'General': ['Physics',
#       ['Biology', 'Geography'],
#       'Elective Mathematics']}},
#    'special requirements / general information': ['Geology, Applied Geology, Applied GeophysicsEntry requirements:Core: Credit passes in English, Core Mathematics, Integrated Science & Social StudiesElectives: Credit passes in Chemistry and any two of Physics, Biology/Geography and Elective Mathematics']},
#   {'program': 'Bachelor of Science in Mathematical Sciences',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoice': '12',
#     'fullFeePaying': '16',
#     'secondChoice': '-',
#     'subjectRequirements': 'B3 in Elective Maths'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Elective Mathematics'],
#     'tracks': {'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Crop Science',
#       'Chemistry',
#       'Physics']}},
#    'special requirements / general information': 'Bachelor of Science degree in any ONE of the following subjects: Mathematics, Statistics, Biomathematics, Physics. Or Bachelor of Science in any TWO of the following subjects: Mathematics, Statistics, Computer Science, Physics. Note I: Applicants who choose the Mathematical Sciences option cannot pursue a single major in Computer Science, but they may combine Computer Science with any of the other three subjects: Mathematics, Statistics, or Physics. Note II: Applicants who choose the Mathematical Sciences option may ONLY pursue a single or combined major in Physics if they have credit passes in both Physics and Chemistry.'},
#   {'program': 'Bachelor of Science in Physical Sciences',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoice': '24',
#     'fullFeePaying': '-',
#     'secondChoice': '-',
#     'subjectRequirements': 'C6 in Chemistry, C6 in Physics'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Physics',
#      'Chemistry',
#      'Elective Mathematics'],
#     'tracks': {}},
#    'special requirements / general information': 'Note: Applicants who choose the Physical Sciences Option may ONLY pursue a combined major with a Mathematical Sciences Subject if they have a B3 in Elective Mathematics.Applicants need at B3 in core maths'},
#   {'program': 'B.Sc. Education (Physics)',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Physics'],
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Chemistry'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': ['Electives:Credit passes in Physics and any other two elective subjects']},
#   {'program': 'B.Sc. Education (Chemistry)',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Chemistry'],
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Biology']}},
#    'special requirements / general information': ['Electives:Credit passes in Chemistry and any other two elective subjects']},
#   {'program': 'B.Sc. Education (Biology)',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Biology'],
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry']}},
#    'special requirements / general information': ['Electives:Credit passes in Biology and any other two elective subjects']},
#   {'program': 'B.Sc. Education (Mathematics)',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Elective Mathematics'],
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': ['Electives:Credit passes in Elective Mathematics and any other two elective subjects']},
#   {'program': 'BA Sport and Physical Culture Studies',
#    'filteringsubject': ['Social Studies', 'Integrated Science'],
#    'alternatecore': ['Integrated Science', 'Social Studies'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': ['Electives: Credit passes in any three elective subjects']},
#   {'program': 'BA Education (Non-Teaching)',
#    'filteringsubject': ['Social Studies', 'Integrated Science'],
#    'alternatecore': ['Integrated Science', 'Social Studies'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': ['Electives:Credit passes in any three elective subjects.']},
#   {'program': 'BA Education (English)',
#    'filteringsubject': ['Social Studies', 'Integrated Science'],
#    'alternatecore': ['Social Studies'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Literature in English'],
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': ['Electives:Credit passes in any three elective subjects including English Literature.']},
#   {'program': 'Bachelor of Medicine and Bachelor of Surgery',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Chemistry'],
#     'tracks': {'General': ['Physics', 'Biology', 'Elective Mathematics']}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Public Health',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoice': '12',
#     'fullFeePaying': '-',
#     'secondChoice': '-',
#     'subjectRequirements': '-'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Health Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General Science': ['Chemistry',
#       'Physics',
#       ['Biology', 'Elective Mathematics', 'General Agriculture']],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema',
#       'Food and Nutrition'],
#      'General': ['Economics', 'Food and Nutrition', 'Chemistry', 'French']}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Science in Midwifery',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoice': '8/9',
#     'fullFeePaying': '-',
#     'secondChoice': '-',
#     'subjectRequirements': '08 for Non Science / 09 for Science Background'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Health Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General Science': ['Chemistry',
#       'Physics',
#       ['Biology', 'Elective Mathematics', 'General Agriculture']],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema',
#       'Food and Nutrition'],
#      'General': ['Economics',
#       'Management in Living',
#       'Food and Nutrition',
#       'Chemistry',
#       'General Knowledge in Art',
#       'French']}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Science in Occupational Therapy',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoice': '15',
#     'fullFeePaying': '-',
#     'secondChoice': '14',
#     'subjectRequirements': '-'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Health Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General Science': ['Chemistry',
#       'Physics',
#       ['Biology', 'Elective Mathematics', 'General Agriculture']]}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Science in Dietetics',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoice': '14',
#     'fullFeePaying': '-',
#     'secondChoice': '12',
#     'subjectRequirements': '-'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Health Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General Science': ['Chemistry',
#       'Physics',
#       ['Biology', 'Elective Mathematics', 'General Agriculture']]}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Science in Medical Laboratory',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General Science': ['Chemistry',
#       'Physics',
#       ['Biology', 'Elective Mathematics', 'General Agriculture']]}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Science in Physiotherapy',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoice': '14',
#     'fullFeePaying': '-',
#     'secondChoice': '12',
#     'subjectRequirements': '-'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Health Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General Science': ['Chemistry',
#       'Physics',
#       ['Biology', 'Elective Mathematics', 'General Agriculture']]}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Science in Radiography',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General Science': ['Chemistry',
#       'Physics',
#       ['Biology', 'Elective Mathematics', 'General Agriculture']]}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Science in Respiratory Therapy',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoice': '14',
#     'fullFeePaying': '-',
#     'secondChoice': '13',
#     'subjectRequirements': '-'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Health Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General Science': ['Chemistry',
#       'Physics',
#       ['Biology', 'Elective Mathematics', 'General Agriculture']]}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Science in Nursing',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoice': '8/9',
#     'fullFeePaying': '-',
#     'secondChoice': '-',
#     'subjectRequirements': '08 for Non Science / 09 for Science Background'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Health Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General Science': ['Chemistry',
#       'Physics',
#       ['Biology', 'Elective Mathematics', 'General Agriculture']],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema',
#       'Food and Nutrition'],
#      'General': ['Economics',
#       'Management in Living',
#       'Food and Nutrition',
#       'Chemistry',
#       'General Knowledge in Art',
#       'French']}},
#    'special requirements / general information': 'Bachelor of Science in Nursing with options in: General Nursing, Public Health Nursing, Paediatric Nursing, Mental Health Nursing. Applicants are expected to select one (1) option'},
#   {'program': 'Doctor of Pharmacy',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoice': '8',
#     'fullFeePaying': '-',
#     'secondChoice': '-',
#     'subjectRequirements': '-'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Health Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Chemistry, Biology, and either Physics or Elective Mathematics'],
#     'tracks': {'General Science': ['Chemistry',
#       'Biology',
#       ['Physics', 'Elective Mathematics']]}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Dental Surgery',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoice': '8',
#     'fullFeePaying': '-',
#     'secondChoice': '-',
#     'subjectRequirements': '-'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Health Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Chemistry'],
#     'tracks': {'General': ['Physics', 'Biology', 'Elective Mathematics']}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Fine Arts',
#    'filteringsubject': ['Integrated Science'],
#    'alternatecore': ['Social Studies'],
#    'cutoff point': {'firstChoice': '22',
#     'fullFeePaying': '',
#     'secondChoice': '',
#     'subjectRequirements': ''},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Humanities',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': ['Electives:Credit passes in any three electives subjects.',
#     'The programme is open to applicants interested in the Performing Arts with aggregate 24 or better. They will be expected to attend an audition or interview.']},
#   {'program': 'Bachelor of Laws (LLB)',
#    'filteringsubject': ['Integrated Science'],
#    'alternatecore': ['Social Studies'],
#    'cutoff point': {'firstChoice': '6',
#     'fullFeePaying': '',
#     'secondChoice': '',
#     'subjectRequirements': ''},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Humanities',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': ['Electives:Credit passes in any three elective subjects']},
#   {'program': 'Bachelor of Science in Business Administration',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoice': '24',
#     'fullFeePaying': '',
#     'secondChoice': '',
#     'subjectRequirements': ''},
#    'campus': 'Main Campus (Legon)',
#    'college': 'Accra City Campus',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': ['Electives:Credit passes in any three elective subjects']},
#   {'program': 'Bachelor of Arts',
#    'filteringsubject': ['Integrated Science'],
#    'alternatecore': ['Social Studies'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': 'Electives: Credit passes in any three elective subjects',
#    'concentrations': {'economics mathematics or statistics': 'Elective Mathematics',
#     'computer science': 'Elective Mathematics',
#     'french': 'French',
#     'english': 'English Literature',
#     'geography': 'Geography',
#     'accounting': 'Accounting and Elective Mathematics or Accounting and Principles of Costing'}},
#   {'program': 'Bachelor of Arts (Economics/Mathematics or Economics/Statistics or Economics/Computer Science)',
#    'filteringsubject': ['Integrated Science'],
#    'alternatecore': ['Social Studies'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Elective Mathematics'],
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': 'Electives: Credit passes in any three elective subjects'},
#   {'program': 'Bachelor of Arts (French)',
#    'filteringsubject': ['Integrated Science'],
#    'alternatecore': ['Social Studies'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['French'],
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': 'Electives: Credit passes in any three elective subjects'},
#   {'program': 'Bachelor of Arts (English)',
#    'filteringsubject': ['Integrated Science'],
#    'alternatecore': ['Social Studies'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Literature in English'],
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': 'Electives: Credit passes in any three elective subjects'},
#   {'program': 'Bachelor of Arts (Geography)',
#    'filteringsubject': ['Integrated Science'],
#    'alternatecore': ['Social Studies'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Geography'],
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': 'Electives: Credit passes in any three elective subjects'},
#   {'program': 'Bachelor of Arts (Accounting)',
#    'filteringsubject': ['Integrated Science'],
#    'alternatecore': ['Social Studies'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Financial Accounting'],
#     'tracks': {'Agric': [['Elective Mathematics', 'Cost Accounting'],
#       ['General Agriculture',
#        'Animal Husbandry',
#        'Agricultural Economics',
#        'Crop Science',
#        'Chemistry',
#        'Physics']],
#      'GArts': [['Elective Mathematics', 'Cost Accounting'],
#       ['Economics',
#        'Government',
#        'History',
#        'Christian Religious Studies',
#        'Music',
#        'Elective ICT',
#        'Literature in English',
#        'French',
#        'Fante',
#        'Akuapem Twi',
#        'Asante Twi',
#        'Ga',
#        'Ewe',
#        'Arabic',
#        'Dagaare',
#        'Dagbani',
#        'Gonja',
#        'Kasem',
#        'Nzema']],
#      'Science': [['Elective Mathematics', 'Cost Accounting'],
#       ['Physics', 'Chemistry', 'Biology', 'Elective ICT']],
#      'Biz': [['Elective Mathematics', 'Cost Accounting'],
#       ['Business Management',
#        'Economics',
#        'Elective ICT',
#        'French',
#        'Clerical Office Duties']],
#      'Tech': [['Elective Mathematics', 'Cost Accounting'],
#       ['Technical Drawing',
#        'Building Construction',
#        'Woodwork',
#        'Metalwork',
#        'Auto Mechanics',
#        'Electronics',
#        'Applied Electricity',
#        'Automobile Engineering',
#        'Electrical Engineering']],
#      'Visual': [['Elective Mathematics', 'Cost Accounting'],
#       ['ICT',
#        'General Knowledge in Art',
#        'Textiles',
#        'Picture Making',
#        'Ceramics and Sculpture',
#        'Ceramics and Basketry',
#        'Graphic Design',
#        'Leather Work',
#        'Basketry',
#        'Sculpture',
#        'French']],
#      'Home Econs': [['Elective Mathematics', 'Cost Accounting'],
#       ['Economics',
#        'Food and Nutrition',
#        'Clothing and Textiles',
#        'Management in Living',
#        'Chemistry',
#        'Biology']]}},
#    'special requirements / general information': 'Electives: Credit passes in any three elective subjects'}]]

# %%
# update the programs with cutoff points, college
def format_names(full_program):
    program_name = full_program.replace("BSc. ", "").replace("B.Sc. ", '').replace("BA ", "").replace("BFA ", "").replace("BSc ", "").replace("BA ", "").replace("Bachelor of ", "").replace("Bachelor ", "").replace("Bachelor of Education in Science", "").strip()
    return program_name

for cutoff in cutoff_data:
    program_name = format_names(cutoff["program"])
    cutoff["program"] = program_name

# %%
# update cutoff points from list of programs dict in ug_cutoffPoints.json
matched_programs = []
for program in existing_data[1]:
    for cutoff in cutoff_data:
        if (cutoff["program"].lower() in program["program"].lower()) and cutoff['program'] not in matched_programs:
            program["cutoff point"] = cutoff["cutoff point"]
            matched_programs.append(cutoff['program'])
            print(f"Updated program: {program['program']} with cutoff: {cutoff['program']}")
            break
    else:
        print(f"No cutoff points found: PROGRAM: {program['program']} CUTOFF: {cutoff['program']}")
# Out:
# Updated program: BSc. Actuarial Science with cutoff: Actuarial Science
# Updated program: BSc. Computer Science with cutoff: Computer Science
# Updated program: Doctor of Veterinary Medicine with cutoff: Doctor of Veterinary Medicine
# Updated program: BSc. Materials Science & Engineering with cutoff: Materials Science & Engineering
# Updated program: BSc. Food Process Engineering with cutoff: Food Process Engineering
# Updated program: BSc. Computer Engineering with cutoff: Computer Engineering
# Updated program: BSc. Biomedical Engineering with cutoff: Biomedical Engineering
# Updated program: BSc. Agricultural Engineering with cutoff: Agricultural Engineering
# No cutoff points found: PROGRAM: Bachelor of Science in Family & Consumer Sciences (Family and Child Studies Option) CUTOFF: Administration
# No cutoff points found: PROGRAM: Bachelor of Science in Family & Consumer Sciences (Food and Clothing Option) CUTOFF: Administration
# Updated program: Bachelor of Science in Agriculture with cutoff: Agriculture
# Updated program: Bachelor of Science in Psychology with cutoff: Psychology
# Updated program: BSc. Biological Sciences with cutoff: Biological Sciences
# Updated program: Bachelor of Science in Information Technology with cutoff: Information Technology
# Updated program: Bachelor of Science in Earth Sciences with cutoff: Earth Sciences
# Updated program: Bachelor of Science in Mathematical Sciences with cutoff: Mathematical Sciences
# Updated program: Bachelor of Science in Physical Sciences with cutoff: Physical Sciences
# No cutoff points found: PROGRAM: B.Sc. Education (Physics) CUTOFF: Administration
# No cutoff points found: PROGRAM: B.Sc. Education (Chemistry) CUTOFF: Administration
# No cutoff points found: PROGRAM: B.Sc. Education (Biology) CUTOFF: Administration
# No cutoff points found: PROGRAM: B.Sc. Education (Mathematics) CUTOFF: Administration
# No cutoff points found: PROGRAM: BA Sport and Physical Culture Studies CUTOFF: Administration
# No cutoff points found: PROGRAM: BA Education (Non-Teaching) CUTOFF: Administration
# No cutoff points found: PROGRAM: BA Education (English) CUTOFF: Administration
# No cutoff points found: PROGRAM: Bachelor of Medicine and Bachelor of Surgery CUTOFF: Administration
# Updated program: Bachelor of Public Health with cutoff: Public Health
# Updated program: Bachelor of Science in Midwifery with cutoff: Midwifery
# Updated program: Bachelor of Science in Occupational Therapy with cutoff: Occupational Therapy
# Updated program: Bachelor of Science in Dietetics with cutoff: Dietetics
# No cutoff points found: PROGRAM: Bachelor of Science in Medical Laboratory CUTOFF: Administration
# Updated program: Bachelor of Science in Physiotherapy with cutoff: Physiotherapy
# No cutoff points found: PROGRAM: Bachelor of Science in Radiography CUTOFF: Administration
# Updated program: Bachelor of Science in Respiratory Therapy with cutoff: Respiratory Therapy
# Updated program: Bachelor of Science in Nursing with cutoff: Nursing
# Updated program: Doctor of Pharmacy with cutoff: Doctor of Pharmacy
# Updated program: Bachelor of Dental Surgery with cutoff: Dental Surgery
# Updated program: Bachelor of Fine Arts with cutoff: Arts
# Updated program: Bachelor of Laws (LLB) with cutoff: Laws
# Updated program: Bachelor of Science in Business Administration with cutoff: Administration
# No cutoff points found: PROGRAM: Bachelor of Arts CUTOFF: Administration
# No cutoff points found: PROGRAM: Bachelor of Arts (Economics/Mathematics or Economics/Statistics or Economics/Computer Science) CUTOFF: Administration
# No cutoff points found: PROGRAM: Bachelor of Arts (French) CUTOFF: Administration
# No cutoff points found: PROGRAM: Bachelor of Arts (English) CUTOFF: Administration
# No cutoff points found: PROGRAM: Bachelor of Arts (Geography) CUTOFF: Administration
# No cutoff points found: PROGRAM: Bachelor of Arts (Accounting) CUTOFF: Administration

# %%
matched_programs
# Out:
# ['Actuarial Science',
#  'Computer Science',
#  'Doctor of Veterinary Medicine',
#  'Materials Science & Engineering',
#  'Food Process Engineering',
#  'Computer Engineering',
#  'Biomedical Engineering',
#  'Agricultural Engineering',
#  'Agriculture',
#  'Psychology',
#  'Biological Sciences',
#  'Information Technology',
#  'Earth Sciences',
#  'Mathematical Sciences',
#  'Physical Sciences',
#  'Public Health',
#  'Midwifery',
#  'Occupational Therapy',
#  'Dietetics',
#  'Physiotherapy',
#  'Respiratory Therapy',
#  'Nursing',
#  'Doctor of Pharmacy',
#  'Dental Surgery',
#  'Arts',
#  'Laws',
#  'Administration']

# %%
existing_data
# Out:
# [{'schoolname': 'University of Ghana'},
#  [{'program': 'BSc. Actuarial Science',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoiceSubjectArea': '11',
#     'firstChoiceNonSubject': '10',
#     'fullFeePaying': '14',
#     'secondChoice': None,
#     'subjectRequirements': 'B3 in Elective Mathematics'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Elective Mathematics'],
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': 'at least a B3 in Elective Mathematics'},
#   {'program': 'BSc. Computer Science',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoiceSubjectArea': '9',
#     'firstChoiceNonSubject': '7',
#     'fullFeePaying': '14',
#     'secondChoice': None,
#     'subjectRequirements': 'B3 in Elective Mathematics'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Elective Mathematics'],
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': 'at least a B3 in Elective Mathematics'},
#   {'program': 'Doctor of Veterinary Medicine',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoiceSubjectArea': '13',
#     'firstChoiceNonSubject': None,
#     'fullFeePaying': None,
#     'secondChoice': None,
#     'subjectRequirements': None},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General': ['Biology',
#       'Chemistry',
#       ['Physics', 'Elective Mathematics']]}},
#    'special requirements / general information': None},
#   {'program': 'BSc. Materials Science & Engineering',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoiceSubjectArea': '12',
#     'firstChoiceNonSubject': None,
#     'fullFeePaying': '14/15',
#     'secondChoice': None,
#     'subjectRequirements': 'B3 in Elective Maths'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General': ['Chemistry', 'Physics', 'Elective Mathematics']}},
#    'special requirements / general information': 'at least a B3 in Elective Mathematics'},
#   {'program': 'BSc. Food Process Engineering',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoiceSubjectArea': '12',
#     'firstChoiceNonSubject': None,
#     'fullFeePaying': '15',
#     'secondChoice': None,
#     'subjectRequirements': 'B3 in Elective Maths'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General': ['Chemistry', 'Physics', 'Elective Mathematics']}},
#    'special requirements / general information': 'at least a B3 in Elective Mathematics'},
#   {'program': 'BSc. Computer Engineering',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoiceSubjectArea': '6',
#     'firstChoiceNonSubject': None,
#     'fullFeePaying': '7',
#     'secondChoice': None,
#     'subjectRequirements': 'B3 in Elective Maths'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General': ['Chemistry', 'Physics', 'Elective Mathematics']}},
#    'special requirements / general information': 'at least a B3 in Elective Mathematics'},
#   {'program': 'BSc. Biomedical Engineering',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoiceSubjectArea': '7',
#     'firstChoiceNonSubject': None,
#     'fullFeePaying': '9',
#     'secondChoice': None,
#     'subjectRequirements': 'B3 in Elective Maths'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General': ['Chemistry', 'Physics', 'Elective Mathematics']}},
#    'special requirements / general information': 'at least a B3 in Elective Mathematics'},
#   {'program': 'BSc. Agricultural Engineering',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoiceSubjectArea': '17',
#     'firstChoiceNonSubject': None,
#     'fullFeePaying': '19/20',
#     'secondChoice': None,
#     'subjectRequirements': 'B3 in Elective Maths'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General': ['Chemistry', 'Physics', 'Elective Mathematics']}},
#    'special requirements / general information': 'at least a B3 in Elective Mathematics'},
#   {'program': 'Bachelor of Science in Family & Consumer Sciences (Family and Child Studies Option)',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Management in Living'],
#     'tracks': {'General': ['Food and Nutrition',
#       'Clothing and Textiles',
#       'General Knowledge in Art',
#       ['Biology', 'Chemistry']]}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Science in Family & Consumer Sciences (Food and Clothing Option)',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': [['Management in Living', 'Chemistry'],
#      ['Chemistry']],
#     'tracks': {'General': ['Food and Nutrition', 'Clothing and Textiles'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Biology',
#       'Elective ICT',
#       'Geography']}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Science in Agriculture',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoiceSubjectArea': '20',
#     'firstChoiceNonSubject': None,
#     'fullFeePaying': None,
#     'secondChoice': None,
#     'subjectRequirements': 'C6 in Chemistry'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Chemistry'],
#     'tracks': {'General': ['Physics',
#       ['Biology', 'Agricultural Science'],
#       'Geography',
#       'Elective Mathematics']}},
#    'special requirements / general information': 'Bachelor of Science in Agriculture: Animal Science, Crop Science, Soil Science, Agriculture Economics, Agribusiness, Agriculture Extension, Post-Harvest Technology.'},
#   {'program': 'Bachelor of Science in Psychology',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoiceSubjectArea': '18',
#     'firstChoiceNonSubject': None,
#     'fullFeePaying': '20',
#     'secondChoice': None,
#     'subjectRequirements': None},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Biology', 'Elective Mathematics'],
#     'tracks': {'General': ['Physics', 'Chemistry']}},
#    'special requirements / general information': None},
#   {'program': 'BSc. Biological Sciences',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoiceSubjectArea': '14',
#     'firstChoiceNonSubject': None,
#     'fullFeePaying': '15/17',
#     'secondChoice': '12(13 for Full Fee Paying)',
#     'subjectRequirements': 'C6 in Chemistry, C6 Biology, C6 Physics'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Chemistry', 'Physics', 'Biology'],
#     'tracks': {}},
#    'special requirements / general information': 'Bachelor of Science degree in any one of the following subjects: Animal Biology and Conservation Science, Biochemistry Cell and Molecular Biology, Nutrition, Food Science, Plant and Environmental Biology, Marine Science, Fisheries Science, Psychology, Microbiology.'},
#   {'program': 'Bachelor of Science in Information Technology',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoiceSubjectArea': '8',
#     'firstChoiceNonSubject': '7',
#     'fullFeePaying': '11',
#     'secondChoice': None,
#     'subjectRequirements': 'B2 in Core Maths'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'Distance Education',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Crop Science',
#       'Chemistry',
#       'Physics']}},
#    'special requirements / general information': 'at least a B3 in Core Mathematics'},
#   {'program': 'Bachelor of Science in Earth Sciences',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoiceSubjectArea': '18',
#     'firstChoiceNonSubject': '17',
#     'fullFeePaying': '20',
#     'secondChoice': None,
#     'subjectRequirements': 'C6 in Chemistry, C6 in Physics'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Chemistry'],
#     'tracks': {'General': ['Physics',
#       ['Biology', 'Geography'],
#       'Elective Mathematics']}},
#    'special requirements / general information': ['Geology, Applied Geology, Applied GeophysicsEntry requirements:Core: Credit passes in English, Core Mathematics, Integrated Science & Social StudiesElectives: Credit passes in Chemistry and any two of Physics, Biology/Geography and Elective Mathematics']},
#   {'program': 'Bachelor of Science in Mathematical Sciences',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoiceSubjectArea': '12',
#     'firstChoiceNonSubject': None,
#     'fullFeePaying': '16',
#     'secondChoice': None,
#     'subjectRequirements': 'B3 in Elective Maths'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Elective Mathematics'],
#     'tracks': {'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Crop Science',
#       'Chemistry',
#       'Physics']}},
#    'special requirements / general information': 'Bachelor of Science degree in any ONE of the following subjects: Mathematics, Statistics, Biomathematics, Physics. Or Bachelor of Science in any TWO of the following subjects: Mathematics, Statistics, Computer Science, Physics. Note I: Applicants who choose the Mathematical Sciences option cannot pursue a single major in Computer Science, but they may combine Computer Science with any of the other three subjects: Mathematics, Statistics, or Physics. Note II: Applicants who choose the Mathematical Sciences option may ONLY pursue a single or combined major in Physics if they have credit passes in both Physics and Chemistry.'},
#   {'program': 'Bachelor of Science in Physical Sciences',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoiceSubjectArea': '24',
#     'firstChoiceNonSubject': None,
#     'fullFeePaying': None,
#     'secondChoice': None,
#     'subjectRequirements': 'C6 in Chemistry, C6 in Physics'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Basic & Applied Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Physics',
#      'Chemistry',
#      'Elective Mathematics'],
#     'tracks': {}},
#    'special requirements / general information': 'Note: Applicants who choose the Physical Sciences Option may ONLY pursue a combined major with a Mathematical Sciences Subject if they have a B3 in Elective Mathematics.Applicants need at B3 in core maths'},
#   {'program': 'B.Sc. Education (Physics)',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Physics'],
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Chemistry'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': ['Electives:Credit passes in Physics and any other two elective subjects']},
#   {'program': 'B.Sc. Education (Chemistry)',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Chemistry'],
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Biology']}},
#    'special requirements / general information': ['Electives:Credit passes in Chemistry and any other two elective subjects']},
#   {'program': 'B.Sc. Education (Biology)',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Biology'],
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry']}},
#    'special requirements / general information': ['Electives:Credit passes in Biology and any other two elective subjects']},
#   {'program': 'B.Sc. Education (Mathematics)',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Elective Mathematics'],
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': ['Electives:Credit passes in Elective Mathematics and any other two elective subjects']},
#   {'program': 'BA Sport and Physical Culture Studies',
#    'filteringsubject': ['Social Studies', 'Integrated Science'],
#    'alternatecore': ['Integrated Science', 'Social Studies'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': ['Electives: Credit passes in any three elective subjects']},
#   {'program': 'BA Education (Non-Teaching)',
#    'filteringsubject': ['Social Studies', 'Integrated Science'],
#    'alternatecore': ['Integrated Science', 'Social Studies'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': ['Electives:Credit passes in any three elective subjects.']},
#   {'program': 'BA Education (English)',
#    'filteringsubject': ['Social Studies', 'Integrated Science'],
#    'alternatecore': ['Social Studies'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Literature in English'],
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': ['Electives:Credit passes in any three elective subjects including English Literature.']},
#   {'program': 'Bachelor of Medicine and Bachelor of Surgery',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Chemistry'],
#     'tracks': {'General': ['Physics', 'Biology', 'Elective Mathematics']}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Public Health',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoiceSubjectArea': '12',
#     'firstChoiceNonSubject': None,
#     'fullFeePaying': None,
#     'secondChoice': None,
#     'subjectRequirements': None},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Health Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General Science': ['Chemistry',
#       'Physics',
#       ['Biology', 'Elective Mathematics', 'General Agriculture']],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema',
#       'Food and Nutrition'],
#      'General': ['Economics', 'Food and Nutrition', 'Chemistry', 'French']}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Science in Midwifery',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoiceSubjectArea': '9',
#     'firstChoiceNonSubject': '8',
#     'fullFeePaying': None,
#     'secondChoice': None,
#     'subjectRequirements': '08 for Non Science / 09 for Science Background'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Health Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General Science': ['Chemistry',
#       'Physics',
#       ['Biology', 'Elective Mathematics', 'General Agriculture']],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema',
#       'Food and Nutrition'],
#      'General': ['Economics',
#       'Management in Living',
#       'Food and Nutrition',
#       'Chemistry',
#       'General Knowledge in Art',
#       'French']}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Science in Occupational Therapy',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoiceSubjectArea': '15',
#     'firstChoiceNonSubject': None,
#     'fullFeePaying': None,
#     'secondChoice': '14',
#     'subjectRequirements': None},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Health Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General Science': ['Chemistry',
#       'Physics',
#       ['Biology', 'Elective Mathematics', 'General Agriculture']]}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Science in Dietetics',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoiceSubjectArea': '14',
#     'firstChoiceNonSubject': None,
#     'fullFeePaying': None,
#     'secondChoice': '12',
#     'subjectRequirements': None},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Health Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General Science': ['Chemistry',
#       'Physics',
#       ['Biology', 'Elective Mathematics', 'General Agriculture']]}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Science in Medical Laboratory',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General Science': ['Chemistry',
#       'Physics',
#       ['Biology', 'Elective Mathematics', 'General Agriculture']]}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Science in Physiotherapy',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoiceSubjectArea': '14',
#     'firstChoiceNonSubject': None,
#     'fullFeePaying': None,
#     'secondChoice': '12',
#     'subjectRequirements': None},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Health Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General Science': ['Chemistry',
#       'Physics',
#       ['Biology', 'Elective Mathematics', 'General Agriculture']]}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Science in Radiography',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General Science': ['Chemistry',
#       'Physics',
#       ['Biology', 'Elective Mathematics', 'General Agriculture']]}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Science in Respiratory Therapy',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoiceSubjectArea': '14',
#     'firstChoiceNonSubject': None,
#     'fullFeePaying': None,
#     'secondChoice': '13',
#     'subjectRequirements': None},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Health Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General Science': ['Chemistry',
#       'Physics',
#       ['Biology', 'Elective Mathematics', 'General Agriculture']]}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Science in Nursing',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoiceSubjectArea': '9',
#     'firstChoiceNonSubject': '8',
#     'fullFeePaying': None,
#     'secondChoice': None,
#     'subjectRequirements': '08 for Non Science / 09 for Science Background'},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Health Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'General Science': ['Chemistry',
#       'Physics',
#       ['Biology', 'Elective Mathematics', 'General Agriculture']],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema',
#       'Food and Nutrition'],
#      'General': ['Economics',
#       'Management in Living',
#       'Food and Nutrition',
#       'Chemistry',
#       'General Knowledge in Art',
#       'French']}},
#    'special requirements / general information': 'Bachelor of Science in Nursing with options in: General Nursing, Public Health Nursing, Paediatric Nursing, Mental Health Nursing. Applicants are expected to select one (1) option'},
#   {'program': 'Doctor of Pharmacy',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoiceSubjectArea': '8',
#     'firstChoiceNonSubject': None,
#     'fullFeePaying': None,
#     'secondChoice': None,
#     'subjectRequirements': None},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Health Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Chemistry, Biology, and either Physics or Elective Mathematics'],
#     'tracks': {'General Science': ['Chemistry',
#       'Biology',
#       ['Physics', 'Elective Mathematics']]}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Dental Surgery',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoiceSubjectArea': '8',
#     'firstChoiceNonSubject': None,
#     'fullFeePaying': None,
#     'secondChoice': None,
#     'subjectRequirements': None},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Health Sciences',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Chemistry'],
#     'tracks': {'General': ['Physics', 'Biology', 'Elective Mathematics']}},
#    'special requirements / general information': None},
#   {'program': 'Bachelor of Fine Arts',
#    'filteringsubject': ['Integrated Science'],
#    'alternatecore': ['Social Studies'],
#    'cutoff point': {'firstChoiceSubjectArea': '30',
#     'firstChoiceNonSubject': None,
#     'fullFeePaying': None,
#     'secondChoice': None,
#     'subjectRequirements': ''},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Humanities',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': ['Electives:Credit passes in any three electives subjects.',
#     'The programme is open to applicants interested in the Performing Arts with aggregate 24 or better. They will be expected to attend an audition or interview.']},
#   {'program': 'Bachelor of Laws (LLB)',
#    'filteringsubject': ['Integrated Science'],
#    'alternatecore': ['Social Studies'],
#    'cutoff point': {'firstChoiceSubjectArea': '6',
#     'firstChoiceNonSubject': None,
#     'fullFeePaying': '',
#     'secondChoice': '',
#     'subjectRequirements': ''},
#    'campus': 'Main Campus (Legon)',
#    'college': 'College of Humanities',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
# ...
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': ['Electives:Credit passes in any three elective subjects']},
#   {'program': 'Bachelor of Science in Business Administration',
#    'filteringsubject': ['Social Studies'],
#    'alternatecore': ['Integrated Science'],
#    'cutoff point': {'firstChoiceSubjectArea': '7',
#     'firstChoiceNonSubject': None,
#     'fullFeePaying': None,
#     'secondChoice': None,
#     'subjectRequirements': ''},
#    'campus': 'Main Campus (Legon)',
#    'college': 'Accra City Campus',
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': ['Electives:Credit passes in any three elective subjects']},
#   {'program': 'Bachelor of Arts',
#    'filteringsubject': ['Integrated Science'],
#    'alternatecore': ['Social Studies'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': None,
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': 'Electives: Credit passes in any three elective subjects',
#    'concentrations': {'economics mathematics or statistics': 'Elective Mathematics',
#     'computer science': 'Elective Mathematics',
#     'french': 'French',
#     'english': 'English Literature',
#     'geography': 'Geography',
#     'accounting': 'Accounting and Elective Mathematics or Accounting and Principles of Costing'}},
#   {'program': 'Bachelor of Arts (Economics/Mathematics or Economics/Statistics or Economics/Computer Science)',
#    'filteringsubject': ['Integrated Science'],
#    'alternatecore': ['Social Studies'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Elective Mathematics'],
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': 'Electives: Credit passes in any three elective subjects'},
#   {'program': 'Bachelor of Arts (French)',
#    'filteringsubject': ['Integrated Science'],
#    'alternatecore': ['Social Studies'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['French'],
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': 'Electives: Credit passes in any three elective subjects'},
#   {'program': 'Bachelor of Arts (English)',
#    'filteringsubject': ['Integrated Science'],
#    'alternatecore': ['Social Studies'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Literature in English'],
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Geography',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT',
#       'Geography'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': 'Electives: Credit passes in any three elective subjects'},
#   {'program': 'Bachelor of Arts (Geography)',
#    'filteringsubject': ['Integrated Science'],
#    'alternatecore': ['Social Studies'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Geography'],
#     'tracks': {'Agric': ['General Agriculture',
#       'Animal Husbandry',
#       'Agricultural Economics',
#       'Elective Mathematics',
#       'Crop Science',
#       'Chemistry',
#       'Physics'],
#      'GArts': ['Economics',
#       'Government',
#       'History',
#       'Elective Mathematics',
#       'Christian Religious Studies',
#       'Music',
#       'Elective ICT',
#       'Literature in English',
#       'French',
#       'Fante',
#       'Akuapem Twi',
#       'Asante Twi',
#       'Ga',
#       'Ewe',
#       'Arabic',
#       'Dagaare',
#       'Dagbani',
#       'Gonja',
#       'Kasem',
#       'Nzema'],
#      'Science': ['Elective Mathematics',
#       'Physics',
#       'Chemistry',
#       'Biology',
#       'Elective ICT'],
#      'Biz': ['Business Management',
#       'Financial Accounting',
#       'Economics',
#       'Cost Accounting',
#       'Elective Mathematics',
#       'Elective ICT',
#       'French',
#       'Clerical Office Duties'],
#      'Tech': ['Technical Drawing',
#       'Building Construction',
#       'Woodwork',
#       'Metalwork',
#       'Auto Mechanics',
#       'Electronics',
#       'Applied Electricity',
#       'Automobile Engineering',
#       'Electrical Engineering'],
#      'Visual': ['ICT',
#       'General Knowledge in Art',
#       'Textiles',
#       'Picture Making',
#       'Ceramics and Sculpture',
#       'Ceramics and Basketry',
#       'Graphic Design',
#       'Leather Work',
#       'Basketry',
#       'Sculpture',
#       'French'],
#      'Home Econs': ['Economics',
#       'Food and Nutrition',
#       'Clothing and Textiles',
#       'Management in Living',
#       'Chemistry',
#       'Biology']}},
#    'special requirements / general information': 'Electives: Credit passes in any three elective subjects'},
#   {'program': 'Bachelor of Arts (Accounting)',
#    'filteringsubject': ['Integrated Science'],
#    'alternatecore': ['Social Studies'],
#    'cutoff point': None,
#    'campus': 'Main Campus (Legon)',
#    'college': None,
#    'core subjects': ['English Language',
#     'Core Mathematics',
#     'Integrated Science',
#     'Social Studies'],
#    'elective subjects': {'main': ['Financial Accounting'],
#     'tracks': {'Agric': [['Elective Mathematics', 'Cost Accounting'],
#       ['General Agriculture',
#        'Animal Husbandry',
#        'Agricultural Economics',
#        'Crop Science',
#        'Chemistry',
#        'Physics']],
#      'GArts': [['Elective Mathematics', 'Cost Accounting'],
#       ['Economics',
#        'Government',
#        'History',
#        'Christian Religious Studies',
#        'Music',
#        'Elective ICT',
#        'Literature in English',
#        'French',
#        'Fante',
#        'Akuapem Twi',
#        'Asante Twi',
#        'Ga',
#        'Ewe',
#        'Arabic',
#        'Dagaare',
#        'Dagbani',
#        'Gonja',
#        'Kasem',
#        'Nzema']],
#      'Science': [['Elective Mathematics', 'Cost Accounting'],
#       ['Physics', 'Chemistry', 'Biology', 'Elective ICT']],
#      'Biz': [['Elective Mathematics', 'Cost Accounting'],
#       ['Business Management',
#        'Economics',
#        'Elective ICT',
#        'French',
#        'Clerical Office Duties']],
#      'Tech': [['Elective Mathematics', 'Cost Accounting'],
#       ['Technical Drawing',
#        'Building Construction',
#        'Woodwork',
#        'Metalwork',
#        'Auto Mechanics',
#        'Electronics',
#        'Applied Electricity',
#        'Automobile Engineering',
#        'Electrical Engineering']],
#      'Visual': [['Elective Mathematics', 'Cost Accounting'],
#       ['ICT',
#        'General Knowledge in Art',
#        'Textiles',
#        'Picture Making',
#        'Ceramics and Sculpture',
#        'Ceramics and Basketry',
#        'Graphic Design',
#        'Leather Work',
#        'Basketry',
#        'Sculpture',
#        'French']],
#      'Home Econs': [['Elective Mathematics', 'Cost Accounting'],
#       ['Economics',
#        'Food and Nutrition',
#        'Clothing and Textiles',
#        'Management in Living',
#        'Chemistry',
#        'Biology']]}},
#    'special requirements / general information': 'Electives: Credit passes in any three elective subjects'}]]

# %%
# Save to JSON file
with open("updated_ug_new1.json", 'w', encoding='utf-8') as f:
    json.dump(existing_data, f, indent=2)
