# %%
import json
from itertools import combinations
from typing import List, Dict, Any


def load_program_data(filepath: str) -> List[Dict[str, Any]]:
    print(f"\n📥 Loading programs from '{filepath}'...")
    with open(filepath, 'r', encoding='utf-8') as f:
        programs = json.load(f)
    print(f"✅ Loaded {len(programs)} programs.\n")
    return programs

def generate_valid_combinations(program: Dict[str, Any], student_electives_input: List[str]) -> List[List[str]]:
    print(f"\n🔍 Checking program: {program['program']}")
    
    if program["campus"] == "Obuasi Campus":
        print("❌ Skipping program at Obuasi Campus.")
        return []

    else:
        # Get the program's elective requirements
        elective_reqs = program.get("elective subjects", {})
        main = elective_reqs.get("main")
        tracks = elective_reqs.get("tracks", {})

        # Collect all the required subjects for the program
        all_required_subjects = set()

        print("🧑‍🏫 Processing elective requirements:")
        
        if main:
            if isinstance(main, list):
                all_required_subjects.update(main)
            else:
                all_required_subjects.add(main)
        print(f"   ➡ Main subject(s) added: {main}")

        for track_name, track in tracks.items():
            for group in track:
                if isinstance(group, list):
                    all_required_subjects.update(group)
                    print(f"   ➡ Track '{track_name}' - Adding mutually exclusive group: {group}")
                else:
                    all_required_subjects.add(group)
                    print(f"   ➡ Track '{track_name}' - Adding subject: {group}")
        
        print(f"📘 All required subjects: {sorted(all_required_subjects)}")
        print(f"🎓 Student electives input: {student_electives_input}")

        # Find matching electives between student input and program requirements
        matching_electives = [s for s in student_electives_input if s in all_required_subjects]
        print(f"🔎 Matching electives: {matching_electives}")

        if len(matching_electives) < 3:
            print("❌ Not enough matching electives to form 3-subject combinations.")
            return []

        # Check if the main subject is required and included
        if main:
            main_set = set(m.strip().lower() for m in main) if isinstance(main, list) else {main.strip().lower()} if main else set()
            print(f"🧪 Main subject(s) set for comparison: {main_set}")
        else:
            main_set = set()

        valid_combinations_set = set()

        # Generate all 3-subject combinations and check each one
        for combo in combinations(matching_electives, 3):
            combo_set = frozenset(combo)
            print(f"🔄 Checking combination: {combo_set}")

            # Check for mutually exclusive electives in the same combination
            mutually_exclusive_found = False
            for track_name, track in tracks.items():
                for group in track:
                    if isinstance(group, list):
                        # Check if two or more subjects from the same group are found in the combo
                        common_subjects = [item for item in group if item in combo_set]
                        if len(common_subjects) > 1:  # More than 1 subject from the same mutually exclusive group
                            mutually_exclusive_found = True
                            print(f"⛔ Mutually exclusive combination found in track '{track_name}': {combo} (Subjects: {common_subjects})")
                            break
                if mutually_exclusive_found:
                    break

            if mutually_exclusive_found:
                continue

            # Check if the combination includes the main subject (if required)
            if main and not any(sub.strip().lower() in main_set for sub in combo):
                print(f"⛔ Skipping combo (missing main subject): {combo}")
                continue
            
            valid_combinations_set.add(combo_set)
            print(f"✅ Valid combination: {combo}")

        # Convert to sorted list of lists
        valid_combinations = [sorted(list(combo)) for combo in valid_combinations_set]

        print(f"🎯 Total valid combinations: {len(valid_combinations)}")
        return valid_combinations

# %%
# === Run the checker ===
if __name__ == '__main__':
    student_electives = ["Chemistry", "Physics", "Elective Mathematics", "Biology", "General Agriculture", "Economics"]
    program_list = load_program_data('data/programdatan.json')

    for program in program_list:
        combos = generate_valid_combinations(program, student_electives)
        print(combos)
        if combos:
            print(f"\n✅ {program['program']} - QUALIFIED")
            for combo in combos:
                print("   →", combo)
        else:
            print(f"\n❌ {program['program']} - NOT QUALIFIED")
            print("   → No valid combinations found.")
    print("\n📊 All programs processed.\n")
# Out:
# 📥 Loading programs from 'data/programdatan.json'...
# ✅ Loaded 2 programs.
#
#
# 🔍 Checking program: BSc. Agribusiness Management
# 🧑‍🏫 Processing elective requirements:
#    ➡ Main subject(s) added: None
#    ➡ Track 'General Science' - Adding subject: Chemistry
#    ➡ Track 'General Science' - Adding mutually exclusive group: ['Physics', 'Elective Mathematics']
#    ➡ Track 'General Science' - Adding mutually exclusive group: ['Biology', 'General Agriculture']
#    ➡ Track 'Business' - Adding subject: Economics
#    ➡ Track 'Business' - Adding subject: Accounting
#    ➡ Track 'Business' - Adding subject: Business Management
#    ➡ Track 'Business' - Adding subject: Business Mathematics
#    ➡ Track 'Business' - Adding subject: Costing
#    ➡ Track 'Business' - Adding subject: Elective Mathematics
#    ➡ Track 'General Arts' - Adding subject: Economics
#    ➡ Track 'General Arts' - Adding subject: Geography
#    ➡ Track 'General Arts' - Adding subject: Elective Mathematics
#    ➡ Track 'General Agriculture' - Adding subject: Chemistry
#    ➡ Track 'General Agriculture' - Adding mutually exclusive group: ['Physics', 'Elective Mathematics']
#    ➡ Track 'General Agriculture' - Adding mutually exclusive group: ['Biology', 'General Agriculture', 'Crop Husbandry', 'Horticulture']
# 📘 All required subjects: ['Accounting', 'Biology', 'Business Management', 'Business Mathematics', 'Chemistry', 'Costing', 'Crop Husbandry', 'Economics', 'Elective Mathematics', 'General Agriculture', 'Geography', 'Horticulture', 'Physics']
# 🎓 Student electives input: ['Chemistry', 'Physics', 'Elective Mathematics', 'Biology', 'General Agriculture', 'Economics']
# 🔎 Matching electives: ['Chemistry', 'Physics', 'Elective Mathematics', 'Biology', 'General Agriculture', 'Economics']
# 🔄 Checking combination: frozenset({'Chemistry', 'Physics', 'Elective Mathematics'})
# ⛔ Mutually exclusive combination found in track 'General Science': ('Chemistry', 'Physics', 'Elective Mathematics') (Subjects: ['Physics', 'Elective Mathematics'])
# 🔄 Checking combination: frozenset({'Chemistry', 'Physics', 'Biology'})
# ✅ Valid combination: ('Chemistry', 'Physics', 'Biology')
# 🔄 Checking combination: frozenset({'Chemistry', 'Physics', 'General Agriculture'})
# ✅ Valid combination: ('Chemistry', 'Physics', 'General Agriculture')
# 🔄 Checking combination: frozenset({'Economics', 'Chemistry', 'Physics'})
# ✅ Valid combination: ('Chemistry', 'Physics', 'Economics')
# 🔄 Checking combination: frozenset({'Chemistry', 'Elective Mathematics', 'Biology'})
# ✅ Valid combination: ('Chemistry', 'Elective Mathematics', 'Biology')
# 🔄 Checking combination: frozenset({'Chemistry', 'Elective Mathematics', 'General Agriculture'})
# ✅ Valid combination: ('Chemistry', 'Elective Mathematics', 'General Agriculture')
# 🔄 Checking combination: frozenset({'Economics', 'Chemistry', 'Elective Mathematics'})
# ✅ Valid combination: ('Chemistry', 'Elective Mathematics', 'Economics')
# 🔄 Checking combination: frozenset({'Chemistry', 'General Agriculture', 'Biology'})
# ⛔ Mutually exclusive combination found in track 'General Science': ('Chemistry', 'Biology', 'General Agriculture') (Subjects: ['Biology', 'General Agriculture'])
# 🔄 Checking combination: frozenset({'Economics', 'Chemistry', 'Biology'})
# ✅ Valid combination: ('Chemistry', 'Biology', 'Economics')
# 🔄 Checking combination: frozenset({'Economics', 'Chemistry', 'General Agriculture'})
# ✅ Valid combination: ('Chemistry', 'General Agriculture', 'Economics')
# 🔄 Checking combination: frozenset({'Biology', 'Physics', 'Elective Mathematics'})
# ⛔ Mutually exclusive combination found in track 'General Science': ('Physics', 'Elective Mathematics', 'Biology') (Subjects: ['Physics', 'Elective Mathematics'])
# 🔄 Checking combination: frozenset({'General Agriculture', 'Physics', 'Elective Mathematics'})
# ⛔ Mutually exclusive combination found in track 'General Science': ('Physics', 'Elective Mathematics', 'General Agriculture') (Subjects: ['Physics', 'Elective Mathematics'])
# 🔄 Checking combination: frozenset({'Economics', 'Physics', 'Elective Mathematics'})
# ⛔ Mutually exclusive combination found in track 'General Science': ('Physics', 'Elective Mathematics', 'Economics') (Subjects: ['Physics', 'Elective Mathematics'])
# 🔄 Checking combination: frozenset({'General Agriculture', 'Physics', 'Biology'})
# ⛔ Mutually exclusive combination found in track 'General Science': ('Physics', 'Biology', 'General Agriculture') (Subjects: ['Biology', 'General Agriculture'])
# 🔄 Checking combination: frozenset({'Economics', 'Physics', 'Biology'})
# ✅ Valid combination: ('Physics', 'Biology', 'Economics')
# 🔄 Checking combination: frozenset({'Economics', 'Physics', 'General Agriculture'})
# ✅ Valid combination: ('Physics', 'General Agriculture', 'Economics')
# 🔄 Checking combination: frozenset({'General Agriculture', 'Elective Mathematics', 'Biology'})
# ⛔ Mutually exclusive combination found in track 'General Science': ('Elective Mathematics', 'Biology', 'General Agriculture') (Subjects: ['Biology', 'General Agriculture'])
# 🔄 Checking combination: frozenset({'Economics', 'Elective Mathematics', 'Biology'})
# ✅ Valid combination: ('Elective Mathematics', 'Biology', 'Economics')
# 🔄 Checking combination: frozenset({'Economics', 'Elective Mathematics', 'General Agriculture'})
# ✅ Valid combination: ('Elective Mathematics', 'General Agriculture', 'Economics')
# 🔄 Checking combination: frozenset({'Economics', 'General Agriculture', 'Biology'})
# ⛔ Mutually exclusive combination found in track 'General Science': ('Biology', 'General Agriculture', 'Economics') (Subjects: ['Biology', 'General Agriculture'])
# 🎯 Total valid combinations: 12
# [['Chemistry', 'Elective Mathematics', 'General Agriculture'], ['Economics', 'Elective Mathematics', 'General Agriculture'], ['Biology', 'Chemistry', 'Physics'], ['Chemistry', 'Economics', 'Elective Mathematics'], ['Biology', 'Economics', 'Physics'], ['Biology', 'Chemistry', 'Elective Mathematics'], ['Biology', 'Economics', 'Elective Mathematics'], ['Chemistry', 'General Agriculture', 'Physics'], ['Economics', 'General Agriculture', 'Physics'], ['Chemistry', 'Economics', 'General Agriculture'], ['Chemistry', 'Economics', 'Physics'], ['Biology', 'Chemistry', 'Economics']]
#
# ✅ BSc. Agribusiness Management - QUALIFIED
#    → ['Chemistry', 'Elective Mathematics', 'General Agriculture']
#    → ['Economics', 'Elective Mathematics', 'General Agriculture']
#    → ['Biology', 'Chemistry', 'Physics']
#    → ['Chemistry', 'Economics', 'Elective Mathematics']
#    → ['Biology', 'Economics', 'Physics']
#    → ['Biology', 'Chemistry', 'Elective Mathematics']
#    → ['Biology', 'Economics', 'Elective Mathematics']
#    → ['Chemistry', 'General Agriculture', 'Physics']
#    → ['Economics', 'General Agriculture', 'Physics']
#    → ['Chemistry', 'Economics', 'General Agriculture']
#    → ['Chemistry', 'Economics', 'Physics']
#    → ['Biology', 'Chemistry', 'Economics']
#
# 🔍 Checking program: BSc. Agricultural Biotechnology
# 🧑‍🏫 Processing elective requirements:
#    ➡ Main subject(s) added: None
#    ➡ Track 'General' - Adding mutually exclusive group: ['Physics', 'Elective Mathematics']
#    ➡ Track 'General' - Adding subject: Biology
#    ➡ Track 'General' - Adding subject: General Agriculture
#    ➡ Track 'General' - Adding subject: Animal Husbandry
#    ➡ Track 'General' - Adding subject: Crop Husbandry
#    ➡ Track 'General' - Adding subject: Horticulture
# 📘 All required subjects: ['Animal Husbandry', 'Biology', 'Crop Husbandry', 'Elective Mathematics', 'General Agriculture', 'Horticulture', 'Physics']
# 🎓 Student electives input: ['Chemistry', 'Physics', 'Elective Mathematics', 'Biology', 'General Agriculture', 'Economics']
# 🔎 Matching electives: ['Physics', 'Elective Mathematics', 'Biology', 'General Agriculture']
# 🔄 Checking combination: frozenset({'Biology', 'Physics', 'Elective Mathematics'})
# ⛔ Mutually exclusive combination found in track 'General': ('Physics', 'Elective Mathematics', 'Biology') (Subjects: ['Physics', 'Elective Mathematics'])
# 🔄 Checking combination: frozenset({'General Agriculture', 'Physics', 'Elective Mathematics'})
# ⛔ Mutually exclusive combination found in track 'General': ('Physics', 'Elective Mathematics', 'General Agriculture') (Subjects: ['Physics', 'Elective Mathematics'])
# 🔄 Checking combination: frozenset({'General Agriculture', 'Physics', 'Biology'})
# ✅ Valid combination: ('Physics', 'Biology', 'General Agriculture')
# 🔄 Checking combination: frozenset({'General Agriculture', 'Elective Mathematics', 'Biology'})
# ✅ Valid combination: ('Elective Mathematics', 'Biology', 'General Agriculture')
# 🎯 Total valid combinations: 2
# [['Biology', 'Elective Mathematics', 'General Agriculture'], ['Biology', 'General Agriculture', 'Physics']]
#
# ✅ BSc. Agricultural Biotechnology - QUALIFIED
#    → ['Biology', 'Elective Mathematics', 'General Agriculture']
#    → ['Biology', 'General Agriculture', 'Physics']
#
# 📊 All programs processed.

# %%
import json
import pandas as pd

# %%
with open('../src/data/obuasi.json', 'r', encoding='utf-8') as f:
    obuasi = json.load(f)
with open('../src/data/programdata.json', 'r', encoding='utf-8') as k:
    kumasi = json.load(k)

# %%
# Populate obuasi obuasi college, core subjects and elective subjects and applicant type fields with kumasi data if there have same program name
for program in obuasi:
    for kumasi_program in kumasi:
        if program['program'] == kumasi_program['program']:
            program['college'] = kumasi_program['college']
            program['core subjects'] = kumasi_program['core subjects']
            program['elective subjects'] = kumasi_program['elective subjects']
            program['applicant type'] = kumasi_program['applicant type']
            program["special requirements / general information"] = kumasi_program["special requirements / general information"]
            break

# %%
# Export the updated obuasi data to a new JSON file
with open('../src/data/obuasi_updated.json', 'w', encoding='utf-8') as f:
    json.dump(obuasi, f, indent=4)

# %%
obuasi_programs = dict()
# Create a dictionary with program names as keys and their respective cutoff points as values
for program in obuasi:
    obuasi_programs[program['program']] = program['cutoff point']

# %%
obuasi_programs
# Out:
# {'BSc. Civil Engineering': 11,
#  'BSc. Electrical & Electronic Engineering': 10,
#  'BSc. Geological Engineering': 14,
#  'BSc. Geomatic (Geodetic) Engineering': 15,
#  'BSc. Materials Engineering': 15,
#  'BSc. Mechanical Engineering': 12,
#  'BSc. Metallurgical Engineering': 16,
#  'BSc. Medical Laboratory Sciences': 9,
#  'BSc. Midwifery': 13,
#  'BSc. Nursing': 12,
#  'BSc. Business Administration (Human Resource Mgt./Management)': 15,
#  'BSc. Business Administration (Marketing/International Business)': 16,
#  'BSc. Business Administration (Accounting/Banking and Finance)': 12,
#  'BSc. Business Administration (Logistics and Supply Chain Mgt./Bus. Info. Tech.)': 15,
#  'BSc. Environmental Sciences': 19}

# %%
with open('../src/data/programdata.json', 'r', encoding='utf-8') as f:
    main = json.load(f)

# %%
main
# Out:
# [{'program': 'BSc. Agriculture',
#   'cutoff point': 20,
#   'college': 'COLLEGE OF AGRICULTURE AND NATURAL RESOURCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Chemistry'],
#    'tracks': {'General': [['Physics', 'Elective Mathematics'],
#      ['Biology',
#       'General Agriculture',
#       'Animal Husbandry',
#       'Crop Husbandry',
#       'Horticulture']]}},
#   'applicant type': 'WASSCE/SSSCE',
#   'special requirements / general information': None},
#  {'program': 'BSc. Agricultural Biotechnology',
#   'cutoff point': 17,
#   'college': 'COLLEGE OF AGRICULTURE AND NATURAL RESOURCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Chemistry'],
#    'tracks': {'General': [['Physics', 'Elective Mathematics'],
#      ['Biology',
#       'General Agriculture',
#       'Animal Husbandry',
#       'Crop Husbandry',
#       'Horticulture']]}},
#   'applicant type': 'WASSCE/SSSCE',
#   'special requirements / general information': None},
#  {'program': 'BSc. Agribusiness Management',
#   'cutoff point': 15,
#   'college': 'COLLEGE OF AGRICULTURE AND NATURAL RESOURCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'General Science': ['Chemistry',
#      ['Physics', 'Elective Mathematics'],
#      ['Biology', 'General Agriculture']],
#     'Business': ['Economics',
#      'Accounting',
#      'Business Management',
#      'Business Mathematics',
#      'Costing',
#      'Elective Mathematics'],
#     'General Arts': ['Economics', 'Geography', 'Elective Mathematics'],
#     'General Agriculture': ['Chemistry',
#      ['Physics', 'Elective Mathematics'],
#      ['Biology', 'General Agriculture', 'Crop Husbandry', 'Horticulture']]}},
#   'applicant type': 'WASSCE/SSSCE',
#   'special requirements / general information': 'Applicants with Business or General Arts electives must have a minimum of C (SSSCE) or B3 (WASSCE) in Integrated Science'},
#  {'program': 'BSc. Landscape Design and Management',
#   'cutoff point': 17,
#   'college': 'COLLEGE OF AGRICULTURE AND NATURAL RESOURCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'General Science': ['Chemistry',
#      ['Physics', 'Elective Mathematics'],
#      ['Crop Husbandry', 'Biology', 'General Agriculture']],
#     'General Arts': ['Economics',
#      'Geography',
#      'Elective Mathematics',
#      'Technical Drawing',
#      'General Knowledge in Art'],
#     'Visual Arts': ['General Knowledge in Art',
#      'Graphic Design',
#      'Picture Making',
#      'Painting',
#      'Sculpture',
#      'Chemistry']}},
#   'applicant type': 'WASSCE/SSSCE',
#   'special requirements / general information': None},
#  {'program': 'BSc. Natural Resources Management',
#   'cutoff point': 18,
#   'college': 'COLLEGE OF AGRICULTURE AND NATURAL RESOURCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'General Science': ['Chemistry',
#      ['Physics', 'Elective Mathematics'],
#      ['Biology', 'General Agriculture']]}},
#   'applicant type': 'WASSCE/SSSCE',
#   'special requirements / general information': None},
#  {'program': 'BSc. Forest Resources Technology',
#   'cutoff point': 24,
#   'college': 'COLLEGE OF AGRICULTURE AND NATURAL RESOURCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'General Science': ['Chemistry',
#      ['Physics', 'Elective Mathematics'],
#      ['Biology', 'General Agriculture']]}},
#   'applicant type': 'WASSCE/SSSCE',
#   'special requirements / general information': None},
#  {'program': 'BSc. Aquaculture and Water Resources Management',
#   'cutoff point': 20,
#   'college': 'COLLEGE OF AGRICULTURE AND NATURAL RESOURCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'General Science': ['Chemistry',
#      ['Physics', 'Elective Mathematics'],
#      ['Biology', 'General Agriculture']]}},
#   'applicant type': 'WASSCE/SSSCE',
#   'special requirements / general information': None},
#  {'program': 'BSc. Packaging Technology',
#   'cutoff point': 15,
#   'college': 'COLLEGE OF AGRICULTURE AND NATURAL RESOURCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['General Science',
#      'General Arts',
#      'Visual Arts',
#      'Home Economics',
#      'Technical']}},
#   'applicant type': 'WASSCE/SSSCE',
#   'special requirements / general information': None},
#  {'program': 'BSc. Architecture',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics'],
#    'tracks': {'Technical': [['Technical Drawing', 'Engineering Science'],
#      'Building Construction',
#      ['Woodwork', 'Metalwork']],
#     'General Science': ['Physics', 'Chemistry', 'Biology'],
#     'Visual Arts': ['General Knowledge in Art',
#      'Graphic Design',
#      'Picture Making'],
#     'General Arts': ['Economics', 'Geography', 'Government', 'History']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Mature applicants must show interest in architectural design and may need to pass an exam and interview.'},
#  {'program': 'BSc. Construction Technology and Management (Building Technology)',
#   'cutoff point': 9,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics'],
#    'tracks': {'Technical': [['Technical Drawing', 'Engineering Science'],
#      'Building Construction',
#      'Woodwork',
#      'Metalwork'],
#     'General Science': ['Physics', 'Chemistry'],
#     'General Arts': ['Economics', 'Geography']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Candidates may be required to pass a qualifying examination and interview.'},
#  {'program': 'BSc. Quantity Surveying and Construction Economics (Building Technology)',
#   'cutoff point': 9,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics'],
#    'tracks': {'General': ['Chemistry',
#      'Economics',
#      'Geography',
#      'Technical Drawing',
#      'Building Construction',
#      'Physics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Candidates may be required to pass a qualifying examination and interview.'},
#  {'program': 'BSc. Development Planning',
#   'cutoff point': 9,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'Group': ['Geography',
#      'Economics',
#      ['Government', 'History'],
#      'Elective Mathematics',
#      'General Knowledge in Art',
#      'Accounting',
#      'Business Management',
#      'Business Mathematics',
#      'Costing']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Human Settlement Planning',
#   'cutoff point': 10,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Geography'],
#    'tracks': {'Group A': ['Economics',
#      'Business Management',
#      'Government',
#      'Elective Mathematics',
#      'Financial Accounting',
#      'Cost Accounting',
#      'Graphic Design'],
#     'Group B': ['Economics',
#      'Business Management',
#      'Government',
#      'Elective Mathematics',
#      'Financial Accounting',
#      'Cost Accounting',
#      'Graphic Design',
#      ['Accounting',
#       'Technical Drawing',
#       'Graphic Design',
#       'Picture Making',
#       'Sculpture',
#       'Physics',
#       'Painting',
#       'History',
#       'Building Technology',
#       'Woodwork',
#       'Metalwork',
#       'General Knowledge in Art']]}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'THREE subjects in Group A or (2) from Group A and (1) from Group B. Candidates must pass an interview.'},
#  {'program': 'BSc. Land Economy',
#   'cutoff point': 8,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Economics'],
#    'tracks': {'General': ['Geography',
#      ['Accounting',
#       'Business Management',
#       'Government',
#       'Business Mathematics',
#       'French',
#       'Literature in English',
#       'History',
#       'Building Construction',
#       'Technical Drawing',
#       'Elective Mathematics']],
#     'other': ['Elective Mathematics',
#      'Geography',
#      'Accounting',
#      'Business Management',
#      'Business Mathematics',
#      'Government',
#      'French',
#      'Building Construction',
#      'Technical Drawing',
#      'General Knowledge in Art']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants, Diploma Holders',
#   'special requirements / general information': "Diploma/HND holders with CWA 70%+ can enter the second year; others require three years' experience and an interview."},
#  {'program': 'BSc. Real Estate',
#   'cutoff point': 9,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Economics'],
#    'tracks': {'General': ['Geography',
#      ['Accounting',
#       'Business Management',
#       'Government',
#       'Business Mathematics',
#       'French',
#       'Literature in English',
#       'History',
#       'Building Construction',
#       'Technical Drawing',
#       'Elective Mathematics']],
#     'other': ['Elective Mathematics',
#      'Geography',
#      'Accounting',
#      'Business Management',
#      'Business Mathematics',
#      'Government',
#      'French',
#      'Building Construction',
#      'Technical Drawing',
#      'General Knowledge in Art']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants, Diploma Holders',
#   'special requirements / general information': "Diploma/HND holders with CWA 70%+ can enter the second year; others require three years' experience and an interview."},
#  {'program': 'BFA. Fine Art & Curatorial Practice',
#   'cutoff point': 16,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['General Knowledge in Art'],
#    'tracks': {'All': ['General Science',
#      'General Arts',
#      'Visual Arts',
#      'Business',
#      'Technical',
#      'Home Economics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Applicants may need to pass an interview and practical examination.'},
#  {'program': 'BA. Communication Design (Graphic Design)',
#   'cutoff point': 11,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'Visual Arts': ['General Knowledge in Art',
#      'ICT',
#      'Picture Making',
#      'Sculpture',
#      'Textiles',
#      'Ceramics',
#      'Jewellery',
#      'Graphic Design']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Applicants may need to pass an interview and practical examination.'},
#  {'program': 'BA. Integrated Rural Art and Industry',
#   'cutoff point': 15,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'Visual Arts': ['Picture Making',
#      'Leatherwork',
#      'Graphic Design',
#      'Textiles',
#      'Jewellery',
#      'Basketry',
#      'Sculpture',
#      'Ceramics',
#      'General Knowledge in Art',
#      'Management in Living',
#      'Clothing & Textiles',
#      'Food and Nutrition',
#      'Physics',
#      'Chemistry',
#      'Mathematics',
#      'Biology',
#      'Religious Studies',
#      'Construction',
#      'Economics',
#      'History',
#      'Ghanaian Language',
#      'Geography',
#      'Literature in English',
#      'Business Management',
#      'Accounting',
#      'Costing',
#      'ICT'],
#     'Technical': ['Welding and Fabrication Technology',
#      'Digital Design Technology',
#      'Industrial Mechanics',
#      'Wood Construction Technology',
#      'Furniture Design and Construction',
#      'Creative Art Technology',
#      'Building Construction Technology',
#      'General Textiles',
#      'Fashion Design Technology',
#      'Visual Communication Technology']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants, Diploma Holders',
#   'special requirements / general information': 'Applicants must submit a portfolio of artworks for assessment.'},
#  {'program': 'BA. Publishing Studies',
#   'cutoff point': 12,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'Visual Arts': ['General Knowledge in Art',
#      'Picture Making',
#      'Graphic Design',
#      ['Textiles', 'Sculpture', 'Leatherwork']],
#     'General Arts': ['English Literature',
#      'French',
#      'History',
#      'Economics',
#      'Government'],
#     'Business': ['Business Management',
#      'Accounting',
#      'Costing',
#      'Economics',
#      'Elective Mathematics',
#      'Business Mathematics'],
#     'Vocational': ['General knowledge in Art',
#      'Management in Living',
#      ['Food and Nutrition', 'Clothing', 'Textiles']],
#     'General Science': ['Biology',
#      'Chemistry',
#      ['Physics', 'Elective Mathematics']]}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Applicants may be required to pass an interview.'},
#  {'program': 'BSc. Metal Product Design Technology',
#   'cutoff point': 16,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['General Science',
#      'Visual Arts',
#      'Home Economics',
#      'Technical']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Textile Design and Technology',
#   'cutoff point': 13,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['General Science',
#      'Visual Arts',
#      'Home Economics',
#      'Technical',
#      'General Arts',
#      'Business']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Fashion Design',
#   'cutoff point': 11,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['General Science',
#      'Visual Arts',
#      'Home Economics',
#      'Technical',
#      'General Arts',
#      'Business']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BFA. Ceramics',
#   'cutoff point': None,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['Visual Arts', 'Home Economics', 'General Arts']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants, HND/Diploma Holders',
#   'special requirements / general information': 'Applicants must pass an interview and practical examination.'},
#  {'program': 'BSc. Ceramic Technology',
#   'cutoff point': 23,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'Visual Arts': ['Ceramics',
#      'General Knowledge in Art',
#      ['Chemistry', 'Elective Mathematics', 'Physics']],
#     'General Science': ['Elective Mathematics',
#      'Chemistry',
#      ['Physics', 'Biology']],
#     'Technical': ['Technical Drawing',
#      'Building Construction',
#      'Applied Electricity',
#      'Auto Mechanics',
#      'Electronics',
#      'Physics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants, HND/Diploma Holders',
#   'special requirements / general information': 'Applicants must pass an interview and practical examination.'},
#  {'program': 'B.Ed. Junior High School Specialism',
#   'cutoff point': 15,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['General Science',
#      'Visual Arts',
#      'General Arts',
#      'General Agriculture']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Aerospace Engineering',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics', 'Elective Mathematics'],
#    'tracks': {'General Science': ['Chemistry',
#      'Metal Work',
#      'Technical Drawing',
#      'Building Construction',
#      'Woodwork',
#      'Basic Electricity',
#      'Auto Mechanics',
#      'Applied Electricity']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Agricultural Engineering',
#   'cutoff point': 13,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics', 'Elective Mathematics'],
#    'tracks': {'General Science': ['Chemistry',
#      ['Technical Drawing', 'Engineering Science'],
#      'General Agriculture',
#      'Biology',
#      'Metalwork',
#      'Auto Mechanics',
#      'Applied Electricity',
#      'Building Construction']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Applicants without Chemistry must obtain at least B3 in Integrated Science.'},
#  {'program': 'BSc. Automobile Engineering',
#   'cutoff point': 10,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics', 'Elective Mathematics'],
#    'tracks': {'General Science': ['Chemistry',
#      'Metal Work',
#      'Auto Mechanics',
#      'Applied Electricity',
#      'Technical Drawing',
#      'Building Construction',
#      'Woodwork']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Biomedical Engineering',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics', 'Elective Mathematics'],
#    'tracks': {'General Science': ['Chemistry',
#      'Electricity',
#      'Applied Electricity',
#      'Electronics',
#      'ICT',
#      'Biology']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants, HND Applicants',
#   'special requirements / general information': 'HND applicants require at least Second Class Honours in a Biomedical Engineering-related program.'},
#  {'program': 'BSc. Chemical Engineering',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics',
#     'Elective Mathematics',
#     'Chemistry'],
#    'tracks': {}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Civil Engineering',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics',
#     'Physics',
#     'Chemistry'],
#    'tracks': {}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Computer Engineering',
#   'cutoff point': 6,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics', 'Elective Mathematics'],
#    'tracks': {'General Science': ['Chemistry',
#      'Electricity',
#      'Applied Electricity',
#      'Electronics',
#      'ICT']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants, HND Applicants',
#   'special requirements / general information': 'HND applicants require at least Second Class Honours in a Computer Engineering-related program.'},
#  {'program': 'BSc. Electrical & Electronic Engineering',
#   'cutoff point': 6,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics', 'Elective Mathematics'],
#    'tracks': {'General Science': ['Applied Electricity',
#      'Chemistry',
#      'Basic Electricity',
#      'Basic Electronics',
#      'ICT']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Geological Engineering',
#   'cutoff point': 8,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics',
#     'Elective Mathematics',
#     'Chemistry'],
#    'tracks': {}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Geomatic (Geodetic) Engineering',
#   'cutoff point': 9,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics', 'Elective Mathematics'],
#    'tracks': {'General': ['Geography',
#      'Chemistry',
#      'Applied Electricity',
#      'Basic Electronics',
#      'Basic Electronics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Industrial Engineering',
#   'cutoff point': 10,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics', 'Elective Mathematics'],
#    'tracks': {'General Science': ['Chemistry',
#      'Metal Work',
#      'Auto Mechanics',
#      'Applied Electricity',
#      'Technical Drawing',
#      'Building Construction',
#      'Woodwork']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Marine Engineering',
#   'cutoff point': 9,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics', 'Elective Mathematics'],
#    'tracks': {'General Science': ['Chemistry',
#      'Metal Work',
#      'Auto Mechanics',
#      'Applied Electricity',
#      'Technical Drawing',
#      'Building Construction',
#      'Woodwork']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Materials Engineering',
#   'cutoff point': 10,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics',
#     'Elective Mathematics',
#     'Chemistry'],
#    'tracks': {}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Mechanical Engineering',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics',
#     'Elective Mathematics',
#     'Chemistry'],
#    'tracks': {}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Metallurgical Engineering',
#   'cutoff point': 11,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics',
#     'Physics',
#     'Chemistry'],
#    'tracks': {}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Petrochemical Engineering',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics',
#     'Elective Mathematics',
#     'Chemistry'],
#    'tracks': {}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Petroleum Engineering',
#   'cutoff point': 6,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics',
#     'Elective Mathematics',
#     'Chemistry'],
#    'tracks': {}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Telecommunication Engineering',
#   'cutoff point': 9,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics', 'Elective Mathematics'],
#    'tracks': {'General Science': ['Chemistry',
#      'Electricity',
#      'Applied Electricity',
#      'Electronics',
#      'ICT']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'Bachelor of Dental Surgery (BDS)',
#   'cutoff point': 6,
#   'college': 'COLLEGE OF HEALTH SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Chemistry'],
#    'tracks': {'General Science': ['Physics', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': 'Shortlisted applicants must pass an interview. Programme may be followed with a 3-year clinical programme.'},
#  {'program': 'Doctor of Veterinary Medicine (DVM)',
#   'cutoff point': 10,
#   'college': 'COLLEGE OF HEALTH SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Chemistry'],
#    'tracks': {'General Science': [['Physics', 'Elective Mathematics'],
#      ['Animal Husbandry', 'Biology']]}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Disability and Rehabilitation Studies',
#   'cutoff point': 13,
#   'college': 'COLLEGE OF HEALTH SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['General Arts',
#      'General Science',
#      'Business',
#      'Visual Arts',
#      'Home Economics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'Bachelor of Herbal Medicine (BHM)',
#   'cutoff point': 14,
#   'college': 'COLLEGE OF HEALTH SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Chemistry'],
#    'tracks': {'General Science': ['Physics', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': 'Registered Diagnostic Medical Sonographers with experience may apply.'},
#  {'program': 'BSc. Human Biology (Medicine)',
#   'cutoff point': 6,
#   'college': 'COLLEGE OF HEALTH SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Chemistry'],
#    'tracks': {'General Science': ['Physics', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': 'Shortlisted applicants must pass an interview. Programme may be followed with a 3-year clinical programme '},
#  {'program': 'BSc. Medical Laboratory Sciences',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF HEALTH SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Chemistry'],
#    'tracks': {'General Science': ['Physics', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': 'Shortlisted applicants must pass an interview. Programme may be followed with a 3-year clinical programme '},
#  {'program': 'BSc. Medical Imaging',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF HEALTH SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Chemistry'],
#    'tracks': {'General Science': ['Physics', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Nursing',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF HEALTH SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Chemistry'],
#    'tracks': {'General Science': ['Physics', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': 'Shortlisted applicants must pass an interview. Programme may be followed with a 3-year clinical programme '},
#  {'program': 'BSc. Midwifery',
#   'cutoff point': 8,
#   'college': 'COLLEGE OF HEALTH SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Chemistry'],
#    'tracks': {'General Science': ['Physics', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': 'Shortlisted applicants must pass an interview. Programme may be followed with a 3-year clinical programme '},
#  {'program': 'BSc. Physiotherapy and Sports Science',
#   'cutoff point': 12,
#   'college': 'COLLEGE OF HEALTH SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Chemistry'],
#    'tracks': {'General Science': ['Physics', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': 'Must pass a physical fitness test and interview.'},
#  {'program': 'Doctor of Pharmacy (Pharm D)',
#   'cutoff point': 6,
#   'college': 'COLLEGE OF HEALTH SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Chemistry'],
#    'tracks': {'General Science': ['Physics', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': 'Mature applicants must have a Degree in Pharmacy and pass an interview.'},
#  {'program': 'BA. Akan Language and Culture',
#   'cutoff point': 15,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': [['Asante Twi', 'Fante', 'Akuapem Twi']],
#    'tracks': {'Humanities': ['History',
#      'Geography',
#      'Literature in English',
#      'French',
#      'Economics',
#      ['Christian Religious Studies (CRS)', 'Islamic Religious Studies (IRS)'],
#      'Government',
#      'Business Management']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BA. Economics',
#   'cutoff point': 10,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics'],
#    'tracks': {'General Arts': ['Economics',
#      'Geography',
#      'Government',
#      'History',
#      'Literature in English',
#      'French',
#      'Christian Religious Studies (CRS)',
#      'ICT',
#      'Ghanaian Language'],
#     'Business': ['Economics',
#      'Accounting',
#      'Business Management',
#      'Costing',
#      'ICT'],
#     'General Science': ['Chemistry', 'Biology', 'Physics', 'Geography', 'ICT'],
#     'Technical': ['Applied Electricity',
#      'Auto Mechanics',
#      'Woodwork',
#      'Metalwork',
#      'ICT',
#      'Technical Drawing',
#      'Engineering Science'],
#     'Home Economics': ['Management in Living',
#      'Clothing and Textiles',
#      'Food and Nutrition',
#      'Textiles',
#      'French',
#      'General Knowledge in Arts',
#      'Biology',
#      'Chemistry'],
#     'Visual Arts': ['General Knowledge in Art',
#      'Literature in English',
#      'Graphic Design',
#      'Picture Making',
#      'Sculpture',
#      'Ceramics',
#      'Batik',
#      'Tie and Die']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BA. English',
#   'cutoff point': 13,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'Humanities': ['Literature in English',
#      'French',
#      'History',
#      'Government',
#      'Economics',
#      'Geography',
#      'Ghanaian Language',
#      ['Christian Religious Studies (CRS)',
#       'Islamic Religious Studies (IRS)']]}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Any other General Arts elective will be considered beside the mentioned requirements.'},
#  {'program': 'BA. French and Francophone Studies',
#   'cutoff point': 14,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['French'],
#    'tracks': {'Humanities': ['History',
#      ['Christian Religious Studies (CRS)', 'Islamic Religious Studies (IRS)'],
#      'Economics',
#      'Geography',
#      'Government',
#      'Literature in English',
#      'Business Management',
#      'Ghanaian Language']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'A1-B3 in French. Any other General Arts elective will be considered beside the mentioned requirements.'},
#  {'program': 'BA. Geography and Rural Development',
#   'cutoff point': 10,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Geography'],
#    'tracks': {'Humanities': ['Economics',
#      'Government',
#      'French',
#      'Literature in English',
#      ['Christian Religious Studies (CRS)', 'Islamic Religious Studies (IRS)'],
#      'History',
#      'Elective Mathematics',
#      'Ghanaian Language']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Any other General Arts elective will be considered beside the mentioned requirements.'},
#  {'program': 'BA. History',
#   'cutoff point': 15,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': [['History', 'Government']],
#    'tracks': {'Humanities': ['Economics',
#      'Geography',
#      'French',
#      'Elective Mathematics',
#      'Ghanaian Language',
#      'Literature in English',
#      ['Christian Religious Studies (CRS)',
#       'Islamic Religious Studies (IRS)']]}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Any other General Arts elective will be considered beside the mentioned requirements. A pass in Social Studies is required'},
#  {'program': 'BA. Linguistics',
#   'cutoff point': 15,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'Humanities': ['Literature in English',
#      'Ghanaian Language',
#      'French',
#      'Igbo',
#      'Wolof',
#      'Yoruba'],
#     'Group A': [['Literature in English',
#       'Ghanaian Language',
#       'French',
#       'Igbo',
#       'Wolof',
#       'Yoruba'],
#      'History',
#      'Geography',
#      'Economics',
#      'Christian Religious Studies (CRS)',
#      'Islamic Religious Studies (IRS)',
#      'Government',
#      'Business Management'],
#     'Group B': [['History',
#       'Geography',
#       'Economics',
#       'Christian Religious Studies (CRS)',
#       'Islamic Religious Studies (IRS)',
#       'Government',
#       'Business Management'],
#      'Literature in English',
#      'Ghanaian Language',
#      'French',
#      'Igbo',
#      'Wolof',
#      'Yoruba']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BA. Media and Communication Studies',
#   'cutoff point': 9,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'tracks': {'All': ['General Arts',
#       'General Science',
#       'Business',
#       'Visual Arts',
#       'Home Economics',
#       'General Agriculture',
#       'Technical']}}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants, Diploma Holders',
#   'special requirements / general information': 'Diploma holders in Communication Studies, Journalism, Archival Studies, International Relations can enter the second year.'},
#  {'program': 'BA. Political Studies',
#   'cutoff point': 9,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': [['History', 'Government']],
#    'tracks': {'Humanities': ['Economics',
#      'Geography',
#      'Elective Mathematics',
#      'French',
#      'Ghanaian Language',
#      'Literature in English',
#      ['Christian Religious Studies (CRS)',
#       'Islamic Religious Studies (IRS)']]}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BA. Religious Studies',
#   'cutoff point': 20,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': [['Christian Religious Studies (CRS)',
#      'Islamic Religious Studies (IRS)']],
#    'tracks': {'All': ['General Agriculture',
#      'General Arts',
#      'General Science',
#      'Business',
#      'Technical',
#      'Visual Arts',
#      'Home Economics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Diploma in Religious Studies or Theology holders can enter the second year.'},
#  {'program': 'BA. Sociology',
#   'cutoff point': 11,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'General': ['History',
#      'Geography',
#      'Literature in English',
#      'French',
#      'Ghanaian Language',
#      'Government',
#      'Business Management',
#      'Elective Mathematics',
#      'Economics',
#      'Physics',
#      'Chemistry',
#      'Biology',
#      'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Any other General Arts and Science electives will be considered beside the mentioned requirements.'},
#  {'program': 'BA. Social Work',
#   'cutoff point': 11,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'General': ['History',
#      'Geography',
#      'Literature in English',
#      'French',
#      'Ghanaian Language',
#      'Government',
#      'Business Management',
#      'Elective Mathematics',
#      'Economics',
#      'Physics',
#      'Chemistry',
#      'Biology',
#      'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Any other General Arts and Science electives will be considered beside the mentioned requirements. Diploma in Social Work/Social Administration holders enter second year.'},
#  {'program': 'BSc. Business Administration (Human Resource Mgt./Management)',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['General Arts',
#      'General Science',
#      'Business',
#      'Home Economics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Business Administration (Marketing/International Business)',
#   'cutoff point': 9,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['General Arts',
#      'General Science',
#      'Business',
#      'Home Economics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Business Administration (Accounting/Banking and Finance)',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['General Arts', 'General Science', 'Business']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Business Administration (Logistics and Supply Chain Mgt./Bus. Info. Tech.)',
#   'cutoff point': 8,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['General Arts', 'General Science', 'Business']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Hospitality and Tourism Management',
#   'cutoff point': 10,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['General Arts',
#      'General Science',
#      'Business',
#      'Home Economics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'LLB',
#   'cutoff point': 6,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['General Arts',
#      'General Science',
#      'Business',
#      'Visual Arts']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants, Degree Holders',
#   'special requirements / general information': 'Degree holders must pass an entrance exam and interview.'},
#  {'program': 'BSc. Biochemistry',
#   'cutoff point': 9,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Chemistry'],
#    'tracks': {'General Science': ['Physics', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': 'HND applicants with Second Class (Upper/Lower Division) may be admitted to the third or second year.'},
#  {'program': 'BSc. Food Science and Technology',
#   'cutoff point': 11,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Chemistry'],
#    'tracks': {'General Science': ['Physics', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Biological Sciences',
#   'cutoff point': 9,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Chemistry'],
#    'tracks': {'General Science': ['Physics', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Environmental Sciences',
#   'cutoff point': 12,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Chemistry'],
#    'tracks': {'General Science': [['Physics', 'Elective Mathematics'],
#      ['Biology', 'Agricultural Science']]}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': 'Agricultural Science is acceptable in place of Biology.'},
#  {'program': 'BSc. Chemistry',
#   'cutoff point': 15,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Chemistry', 'Physics'],
#    'tracks': {'General Science': ['Elective Mathematics', 'Biology']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Computer Science',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics', 'Physics'],
#    'tracks': {'General Science': ['Chemistry',
#      'Applied Electricity',
#      'Electronics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': 'Applicants with HND in Mathematics, Engineering, or related disciplines with Second Class Lower or better may be placed in Year 2 or 3.'},
#  {'program': 'BSc. Information Technology',
#   'cutoff point': None,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics'],
#    'tracks': {'All': ['General Arts',
#      'General Science',
#      'Business',
#      'Visual Arts',
#      'Technical',
#      'Home Economics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': 'Applicants with HND in Mathematics, Engineering, or related disciplines with Second Class Lower or better may be placed in Year 2 or 3.'},
#  {'program': 'BSc. Mathematics',
#   'cutoff point': 15,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics', 'Physics'],
#    'tracks': {'General Science': ['Chemistry', 'Biology']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Actuarial Science',
#   'cutoff point': 10,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics'],
#    'tracks': {'All': ['General Arts',
#      'General Science',
#      'Business',
#      'Visual Arts',
#      'Technical',
#      'General Agriculture',
#      'Home Economics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Statistics',
#   'cutoff point': 12,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics'],
#    'tracks': {'All': ['General Arts',
#      'General Science',
#      'Business',
#      'Visual Arts',
#      'Technical',
#      'General Agriculture',
#      'Home Economics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Physics',
#   'cutoff point': 16,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics', 'Physics'],
#    'tracks': {'General Science': ['Chemistry', 'Electronics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Meteorology and Climate Science',
#   'cutoff point': 17,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics', 'Physics'],
#    'tracks': {'General Science': ['Chemistry', 'Electronics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'Doctor of Optometry',
#   'cutoff point': 6,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Physics'],
#    'tracks': {'General Science': ['Chemistry', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Dietetics',
#   'cutoff point': None,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'General Science': ['Biology',
#      'Chemistry',
#      ['Elective Mathematics', 'Physics']],
#     'Group A': ['Food and Nutrition',
#      'Management in Living',
#      'Chemistry',
#      'Biology']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Human Nutrition',
#   'cutoff point': None,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'General Science': ['Biology',
#      'Chemistry',
#      ['Elective Mathematics', 'Physics']],
#     'Group A': ['Food and Nutrition',
#      'Management in Living',
#      'Chemistry',
#      'Biology']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None}]

# %%
# Replace tracks with names "All" with generic names
new_names = {
    "General Arts": "GArts", 
    "General Science":"Science", 
    "Business": "Biz", "Visual Arts": 
    "Visual", "Technical": "Tech", 
    "Home Economics": "Home Econs", 
    "General Agriculture": "Agric"
    }
# map new names to old names
'''
example:
 {'program': 'BSc. Packaging Technology',
  'cutoff point': 15,
  'college': 'COLLEGE OF AGRICULTURE AND NATURAL RESOURCES',
  'campus': 'Kumasi (Main) Campus',
  'core subjects': 'English Language, Mathematics, Integrated Science',
  'elective subjects': {'main': None,
   'tracks': {'All': ['General Science',
     'General Arts',
     'Visual Arts',
     'Home Economics',
     'Technical']}},
  'applicant type': 'WASSCE/SSSCE',
  'special requirements / general information': None},
'''
for program in main:
    trackswithall = program['elective subjects']['tracks'].keys()
    for track in trackswithall:
        if track == "All":

            # Map subjects to new names
            subjects = program['elective subjects']['tracks'][track]
            for i in range(len(subjects)):
                if subjects[i] in new_names:
                    subjects[i] = new_names[subjects[i]]

# save the updated data to a new JSON file
with open('../src/data/programdata_updated.json', 'w', encoding='utf-8') as f:
    json.dump(main, f, indent=4)

# %%
main
# Out:
# [{'program': 'BSc. Agriculture',
#   'cutoff point': 20,
#   'college': 'COLLEGE OF AGRICULTURE AND NATURAL RESOURCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Chemistry'],
#    'tracks': {'General': [['Physics', 'Elective Mathematics'],
#      ['Biology',
#       'General Agriculture',
#       'Animal Husbandry',
#       'Crop Husbandry',
#       'Horticulture']]}},
#   'applicant type': 'WASSCE/SSSCE',
#   'special requirements / general information': None},
#  {'program': 'BSc. Agricultural Biotechnology',
#   'cutoff point': 17,
#   'college': 'COLLEGE OF AGRICULTURE AND NATURAL RESOURCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Chemistry'],
#    'tracks': {'General': [['Physics', 'Elective Mathematics'],
#      ['Biology',
#       'General Agriculture',
#       'Animal Husbandry',
#       'Crop Husbandry',
#       'Horticulture']]}},
#   'applicant type': 'WASSCE/SSSCE',
#   'special requirements / general information': None},
#  {'program': 'BSc. Agribusiness Management',
#   'cutoff point': 15,
#   'college': 'COLLEGE OF AGRICULTURE AND NATURAL RESOURCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'General Science': ['Chemistry',
#      ['Physics', 'Elective Mathematics'],
#      ['Biology', 'General Agriculture']],
#     'Business': ['Economics',
#      'Accounting',
#      'Business Management',
#      'Business Mathematics',
#      'Costing',
#      'Elective Mathematics'],
#     'General Arts': ['Economics', 'Geography', 'Elective Mathematics'],
#     'General Agriculture': ['Chemistry',
#      ['Physics', 'Elective Mathematics'],
#      ['Biology', 'General Agriculture', 'Crop Husbandry', 'Horticulture']]}},
#   'applicant type': 'WASSCE/SSSCE',
#   'special requirements / general information': 'Applicants with Business or General Arts electives must have a minimum of C (SSSCE) or B3 (WASSCE) in Integrated Science'},
#  {'program': 'BSc. Landscape Design and Management',
#   'cutoff point': 17,
#   'college': 'COLLEGE OF AGRICULTURE AND NATURAL RESOURCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'General Science': ['Chemistry',
#      ['Physics', 'Elective Mathematics'],
#      ['Crop Husbandry', 'Biology', 'General Agriculture']],
#     'General Arts': ['Economics',
#      'Geography',
#      'Elective Mathematics',
#      'Technical Drawing',
#      'General Knowledge in Art'],
#     'Visual Arts': ['General Knowledge in Art',
#      'Graphic Design',
#      'Picture Making',
#      'Painting',
#      'Sculpture',
#      'Chemistry']}},
#   'applicant type': 'WASSCE/SSSCE',
#   'special requirements / general information': None},
#  {'program': 'BSc. Natural Resources Management',
#   'cutoff point': 18,
#   'college': 'COLLEGE OF AGRICULTURE AND NATURAL RESOURCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'General Science': ['Chemistry',
#      ['Physics', 'Elective Mathematics'],
#      ['Biology', 'General Agriculture']]}},
#   'applicant type': 'WASSCE/SSSCE',
#   'special requirements / general information': None},
#  {'program': 'BSc. Forest Resources Technology',
#   'cutoff point': 24,
#   'college': 'COLLEGE OF AGRICULTURE AND NATURAL RESOURCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'General Science': ['Chemistry',
#      ['Physics', 'Elective Mathematics'],
#      ['Biology', 'General Agriculture']]}},
#   'applicant type': 'WASSCE/SSSCE',
#   'special requirements / general information': None},
#  {'program': 'BSc. Aquaculture and Water Resources Management',
#   'cutoff point': 20,
#   'college': 'COLLEGE OF AGRICULTURE AND NATURAL RESOURCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'General Science': ['Chemistry',
#      ['Physics', 'Elective Mathematics'],
#      ['Biology', 'General Agriculture']]}},
#   'applicant type': 'WASSCE/SSSCE',
#   'special requirements / general information': None},
#  {'program': 'BSc. Packaging Technology',
#   'cutoff point': 15,
#   'college': 'COLLEGE OF AGRICULTURE AND NATURAL RESOURCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['Science', 'GArts', 'Visual', 'Home Econs', 'Tech']}},
#   'applicant type': 'WASSCE/SSSCE',
#   'special requirements / general information': None},
#  {'program': 'BSc. Architecture',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics'],
#    'tracks': {'Technical': [['Technical Drawing', 'Engineering Science'],
#      'Building Construction',
#      ['Woodwork', 'Metalwork']],
#     'General Science': ['Physics', 'Chemistry', 'Biology'],
#     'Visual Arts': ['General Knowledge in Art',
#      'Graphic Design',
#      'Picture Making'],
#     'General Arts': ['Economics', 'Geography', 'Government', 'History']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Mature applicants must show interest in architectural design and may need to pass an exam and interview.'},
#  {'program': 'BSc. Construction Technology and Management (Building Technology)',
#   'cutoff point': 9,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics'],
#    'tracks': {'Technical': [['Technical Drawing', 'Engineering Science'],
#      'Building Construction',
#      'Woodwork',
#      'Metalwork'],
#     'General Science': ['Physics', 'Chemistry'],
#     'General Arts': ['Economics', 'Geography']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Candidates may be required to pass a qualifying examination and interview.'},
#  {'program': 'BSc. Quantity Surveying and Construction Economics (Building Technology)',
#   'cutoff point': 9,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics'],
#    'tracks': {'General': ['Chemistry',
#      'Economics',
#      'Geography',
#      'Technical Drawing',
#      'Building Construction',
#      'Physics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Candidates may be required to pass a qualifying examination and interview.'},
#  {'program': 'BSc. Development Planning',
#   'cutoff point': 9,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'Group': ['Geography',
#      'Economics',
#      ['Government', 'History'],
#      'Elective Mathematics',
#      'General Knowledge in Art',
#      'Accounting',
#      'Business Management',
#      'Business Mathematics',
#      'Costing']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Human Settlement Planning',
#   'cutoff point': 10,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Geography'],
#    'tracks': {'Group A': ['Economics',
#      'Business Management',
#      'Government',
#      'Elective Mathematics',
#      'Financial Accounting',
#      'Cost Accounting',
#      'Graphic Design'],
#     'Group B': ['Economics',
#      'Business Management',
#      'Government',
#      'Elective Mathematics',
#      'Financial Accounting',
#      'Cost Accounting',
#      'Graphic Design',
#      ['Accounting',
#       'Technical Drawing',
#       'Graphic Design',
#       'Picture Making',
#       'Sculpture',
#       'Physics',
#       'Painting',
#       'History',
#       'Building Technology',
#       'Woodwork',
#       'Metalwork',
#       'General Knowledge in Art']]}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'THREE subjects in Group A or (2) from Group A and (1) from Group B. Candidates must pass an interview.'},
#  {'program': 'BSc. Land Economy',
#   'cutoff point': 8,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Economics'],
#    'tracks': {'General': ['Geography',
#      ['Accounting',
#       'Business Management',
#       'Government',
#       'Business Mathematics',
#       'French',
#       'Literature in English',
#       'History',
#       'Building Construction',
#       'Technical Drawing',
#       'Elective Mathematics']],
#     'other': ['Elective Mathematics',
#      'Geography',
#      'Accounting',
#      'Business Management',
#      'Business Mathematics',
#      'Government',
#      'French',
#      'Building Construction',
#      'Technical Drawing',
#      'General Knowledge in Art']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants, Diploma Holders',
#   'special requirements / general information': "Diploma/HND holders with CWA 70%+ can enter the second year; others require three years' experience and an interview."},
#  {'program': 'BSc. Real Estate',
#   'cutoff point': 9,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Economics'],
#    'tracks': {'General': ['Geography',
#      ['Accounting',
#       'Business Management',
#       'Government',
#       'Business Mathematics',
#       'French',
#       'Literature in English',
#       'History',
#       'Building Construction',
#       'Technical Drawing',
#       'Elective Mathematics']],
#     'other': ['Elective Mathematics',
#      'Geography',
#      'Accounting',
#      'Business Management',
#      'Business Mathematics',
#      'Government',
#      'French',
#      'Building Construction',
#      'Technical Drawing',
#      'General Knowledge in Art']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants, Diploma Holders',
#   'special requirements / general information': "Diploma/HND holders with CWA 70%+ can enter the second year; others require three years' experience and an interview."},
#  {'program': 'BFA. Fine Art & Curatorial Practice',
#   'cutoff point': 16,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['General Knowledge in Art'],
#    'tracks': {'All': ['Science',
#      'GArts',
#      'Visual',
#      'Biz',
#      'Tech',
#      'Home Econs']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Applicants may need to pass an interview and practical examination.'},
#  {'program': 'BA. Communication Design (Graphic Design)',
#   'cutoff point': 11,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'Visual Arts': ['General Knowledge in Art',
#      'ICT',
#      'Picture Making',
#      'Sculpture',
#      'Textiles',
#      'Ceramics',
#      'Jewellery',
#      'Graphic Design']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Applicants may need to pass an interview and practical examination.'},
#  {'program': 'BA. Integrated Rural Art and Industry',
#   'cutoff point': 15,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'Visual Arts': ['Picture Making',
#      'Leatherwork',
#      'Graphic Design',
#      'Textiles',
#      'Jewellery',
#      'Basketry',
#      'Sculpture',
#      'Ceramics',
#      'General Knowledge in Art',
#      'Management in Living',
#      'Clothing & Textiles',
#      'Food and Nutrition',
#      'Physics',
#      'Chemistry',
#      'Mathematics',
#      'Biology',
#      'Religious Studies',
#      'Construction',
#      'Economics',
#      'History',
#      'Ghanaian Language',
#      'Geography',
#      'Literature in English',
#      'Business Management',
#      'Accounting',
#      'Costing',
#      'ICT'],
#     'Technical': ['Welding and Fabrication Technology',
#      'Digital Design Technology',
#      'Industrial Mechanics',
#      'Wood Construction Technology',
#      'Furniture Design and Construction',
#      'Creative Art Technology',
#      'Building Construction Technology',
#      'General Textiles',
#      'Fashion Design Technology',
#      'Visual Communication Technology']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants, Diploma Holders',
#   'special requirements / general information': 'Applicants must submit a portfolio of artworks for assessment.'},
#  {'program': 'BA. Publishing Studies',
#   'cutoff point': 12,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'Visual Arts': ['General Knowledge in Art',
#      'Picture Making',
#      'Graphic Design',
#      ['Textiles', 'Sculpture', 'Leatherwork']],
#     'General Arts': ['English Literature',
#      'French',
#      'History',
#      'Economics',
#      'Government'],
#     'Business': ['Business Management',
#      'Accounting',
#      'Costing',
#      'Economics',
#      'Elective Mathematics',
#      'Business Mathematics'],
#     'Vocational': ['General knowledge in Art',
#      'Management in Living',
#      ['Food and Nutrition', 'Clothing', 'Textiles']],
#     'General Science': ['Biology',
#      'Chemistry',
#      ['Physics', 'Elective Mathematics']]}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Applicants may be required to pass an interview.'},
#  {'program': 'BSc. Metal Product Design Technology',
#   'cutoff point': 16,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['Science', 'Visual', 'Home Econs', 'Tech']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Textile Design and Technology',
#   'cutoff point': 13,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['Science',
#      'Visual',
#      'Home Econs',
#      'Tech',
#      'GArts',
#      'Biz']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Fashion Design',
#   'cutoff point': 11,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['Science',
#      'Visual',
#      'Home Econs',
#      'Tech',
#      'GArts',
#      'Biz']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BFA. Ceramics',
#   'cutoff point': None,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['Visual', 'Home Econs', 'GArts']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants, HND/Diploma Holders',
#   'special requirements / general information': 'Applicants must pass an interview and practical examination.'},
#  {'program': 'BSc. Ceramic Technology',
#   'cutoff point': 23,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'Visual Arts': ['Ceramics',
#      'General Knowledge in Art',
#      ['Chemistry', 'Elective Mathematics', 'Physics']],
#     'General Science': ['Elective Mathematics',
#      'Chemistry',
#      ['Physics', 'Biology']],
#     'Technical': ['Technical Drawing',
#      'Building Construction',
#      'Applied Electricity',
#      'Auto Mechanics',
#      'Electronics',
#      'Physics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants, HND/Diploma Holders',
#   'special requirements / general information': 'Applicants must pass an interview and practical examination.'},
#  {'program': 'B.Ed. Junior High School Specialism',
#   'cutoff point': 15,
#   'college': 'COLLEGE OF ART AND BUILT ENVIRONMENT',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['Science', 'Visual', 'GArts', 'Agric']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Aerospace Engineering',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics', 'Elective Mathematics'],
#    'tracks': {'General Science': ['Chemistry',
#      'Metal Work',
#      'Technical Drawing',
#      'Building Construction',
#      'Woodwork',
#      'Basic Electricity',
#      'Auto Mechanics',
#      'Applied Electricity']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Agricultural Engineering',
#   'cutoff point': 13,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics', 'Elective Mathematics'],
#    'tracks': {'General Science': ['Chemistry',
#      ['Technical Drawing', 'Engineering Science'],
#      'General Agriculture',
#      'Biology',
#      'Metalwork',
#      'Auto Mechanics',
#      'Applied Electricity',
#      'Building Construction']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Applicants without Chemistry must obtain at least B3 in Integrated Science.'},
#  {'program': 'BSc. Automobile Engineering',
#   'cutoff point': 10,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics', 'Elective Mathematics'],
#    'tracks': {'General Science': ['Chemistry',
#      'Metal Work',
#      'Auto Mechanics',
#      'Applied Electricity',
#      'Technical Drawing',
#      'Building Construction',
#      'Woodwork']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Biomedical Engineering',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics', 'Elective Mathematics'],
#    'tracks': {'General Science': ['Chemistry',
#      'Electricity',
#      'Applied Electricity',
#      'Electronics',
#      'ICT',
#      'Biology']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants, HND Applicants',
#   'special requirements / general information': 'HND applicants require at least Second Class Honours in a Biomedical Engineering-related program.'},
#  {'program': 'BSc. Chemical Engineering',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics',
#     'Elective Mathematics',
#     'Chemistry'],
#    'tracks': {}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Civil Engineering',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics',
#     'Physics',
#     'Chemistry'],
#    'tracks': {}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Computer Engineering',
#   'cutoff point': 6,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics', 'Elective Mathematics'],
#    'tracks': {'General Science': ['Chemistry',
#      'Electricity',
#      'Applied Electricity',
#      'Electronics',
#      'ICT']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants, HND Applicants',
#   'special requirements / general information': 'HND applicants require at least Second Class Honours in a Computer Engineering-related program.'},
#  {'program': 'BSc. Electrical & Electronic Engineering',
#   'cutoff point': 6,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics', 'Elective Mathematics'],
#    'tracks': {'General Science': ['Applied Electricity',
#      'Chemistry',
#      'Basic Electricity',
#      'Basic Electronics',
#      'ICT']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Geological Engineering',
#   'cutoff point': 8,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics',
#     'Elective Mathematics',
#     'Chemistry'],
#    'tracks': {}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Geomatic (Geodetic) Engineering',
#   'cutoff point': 9,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics', 'Elective Mathematics'],
#    'tracks': {'General': ['Geography',
#      'Chemistry',
#      'Applied Electricity',
#      'Basic Electronics',
#      'Basic Electronics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Industrial Engineering',
#   'cutoff point': 10,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics', 'Elective Mathematics'],
#    'tracks': {'General Science': ['Chemistry',
#      'Metal Work',
#      'Auto Mechanics',
#      'Applied Electricity',
#      'Technical Drawing',
#      'Building Construction',
#      'Woodwork']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Marine Engineering',
#   'cutoff point': 9,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics', 'Elective Mathematics'],
#    'tracks': {'General Science': ['Chemistry',
#      'Metal Work',
#      'Auto Mechanics',
#      'Applied Electricity',
#      'Technical Drawing',
#      'Building Construction',
#      'Woodwork']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Materials Engineering',
#   'cutoff point': 10,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics',
#     'Elective Mathematics',
#     'Chemistry'],
#    'tracks': {}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Mechanical Engineering',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics',
#     'Elective Mathematics',
#     'Chemistry'],
#    'tracks': {}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Metallurgical Engineering',
#   'cutoff point': 11,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics',
#     'Physics',
#     'Chemistry'],
#    'tracks': {}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Petrochemical Engineering',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics',
#     'Elective Mathematics',
#     'Chemistry'],
#    'tracks': {}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Petroleum Engineering',
#   'cutoff point': 6,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics',
#     'Elective Mathematics',
#     'Chemistry'],
#    'tracks': {}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Telecommunication Engineering',
#   'cutoff point': 9,
#   'college': 'COLLEGE OF ENGINEERING',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Physics', 'Elective Mathematics'],
#    'tracks': {'General Science': ['Chemistry',
#      'Electricity',
#      'Applied Electricity',
#      'Electronics',
#      'ICT']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'Bachelor of Dental Surgery (BDS)',
#   'cutoff point': 6,
#   'college': 'COLLEGE OF HEALTH SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Chemistry'],
#    'tracks': {'General Science': ['Physics', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': 'Shortlisted applicants must pass an interview. Programme may be followed with a 3-year clinical programme.'},
#  {'program': 'Doctor of Veterinary Medicine (DVM)',
#   'cutoff point': 10,
#   'college': 'COLLEGE OF HEALTH SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Chemistry'],
#    'tracks': {'General Science': [['Physics', 'Elective Mathematics'],
#      ['Animal Husbandry', 'Biology']]}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Disability and Rehabilitation Studies',
#   'cutoff point': 13,
#   'college': 'COLLEGE OF HEALTH SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['GArts', 'Science', 'Biz', 'Visual', 'Home Econs']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'Bachelor of Herbal Medicine (BHM)',
#   'cutoff point': 14,
#   'college': 'COLLEGE OF HEALTH SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Chemistry'],
#    'tracks': {'General Science': ['Physics', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': 'Registered Diagnostic Medical Sonographers with experience may apply.'},
#  {'program': 'BSc. Human Biology (Medicine)',
#   'cutoff point': 6,
#   'college': 'COLLEGE OF HEALTH SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Chemistry'],
#    'tracks': {'General Science': ['Physics', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': 'Shortlisted applicants must pass an interview. Programme may be followed with a 3-year clinical programme '},
#  {'program': 'BSc. Medical Laboratory Sciences',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF HEALTH SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Chemistry'],
#    'tracks': {'General Science': ['Physics', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': 'Shortlisted applicants must pass an interview. Programme may be followed with a 3-year clinical programme '},
#  {'program': 'BSc. Medical Imaging',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF HEALTH SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Chemistry'],
#    'tracks': {'General Science': ['Physics', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Nursing',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF HEALTH SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Chemistry'],
#    'tracks': {'General Science': ['Physics', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': 'Shortlisted applicants must pass an interview. Programme may be followed with a 3-year clinical programme '},
#  {'program': 'BSc. Midwifery',
#   'cutoff point': 8,
#   'college': 'COLLEGE OF HEALTH SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Chemistry'],
#    'tracks': {'General Science': ['Physics', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': 'Shortlisted applicants must pass an interview. Programme may be followed with a 3-year clinical programme '},
#  {'program': 'BSc. Physiotherapy and Sports Science',
#   'cutoff point': 12,
#   'college': 'COLLEGE OF HEALTH SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Chemistry'],
#    'tracks': {'General Science': ['Physics', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': 'Must pass a physical fitness test and interview.'},
#  {'program': 'Doctor of Pharmacy (Pharm D)',
#   'cutoff point': 6,
#   'college': 'COLLEGE OF HEALTH SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Chemistry'],
#    'tracks': {'General Science': ['Physics', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': 'Mature applicants must have a Degree in Pharmacy and pass an interview.'},
#  {'program': 'BA. Akan Language and Culture',
#   'cutoff point': 15,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': [['Asante Twi', 'Fante', 'Akuapem Twi']],
#    'tracks': {'Humanities': ['History',
#      'Geography',
#      'Literature in English',
#      'French',
#      'Economics',
#      ['Christian Religious Studies (CRS)', 'Islamic Religious Studies (IRS)'],
#      'Government',
#      'Business Management']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BA. Economics',
#   'cutoff point': 10,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics'],
#    'tracks': {'General Arts': ['Economics',
#      'Geography',
#      'Government',
#      'History',
#      'Literature in English',
#      'French',
#      'Christian Religious Studies (CRS)',
#      'ICT',
#      'Ghanaian Language'],
#     'Business': ['Economics',
#      'Accounting',
#      'Business Management',
#      'Costing',
#      'ICT'],
#     'General Science': ['Chemistry', 'Biology', 'Physics', 'Geography', 'ICT'],
#     'Technical': ['Applied Electricity',
#      'Auto Mechanics',
#      'Woodwork',
#      'Metalwork',
#      'ICT',
#      'Technical Drawing',
#      'Engineering Science'],
#     'Home Economics': ['Management in Living',
#      'Clothing and Textiles',
#      'Food and Nutrition',
#      'Textiles',
#      'French',
#      'General Knowledge in Arts',
#      'Biology',
#      'Chemistry'],
#     'Visual Arts': ['General Knowledge in Art',
#      'Literature in English',
#      'Graphic Design',
#      'Picture Making',
#      'Sculpture',
#      'Ceramics',
#      'Batik',
#      'Tie and Die']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BA. English',
#   'cutoff point': 13,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'Humanities': ['Literature in English',
#      'French',
#      'History',
#      'Government',
#      'Economics',
#      'Geography',
#      'Ghanaian Language',
#      ['Christian Religious Studies (CRS)',
#       'Islamic Religious Studies (IRS)']]}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Any other General Arts elective will be considered beside the mentioned requirements.'},
#  {'program': 'BA. French and Francophone Studies',
#   'cutoff point': 14,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['French'],
#    'tracks': {'Humanities': ['History',
#      ['Christian Religious Studies (CRS)', 'Islamic Religious Studies (IRS)'],
#      'Economics',
#      'Geography',
#      'Government',
#      'Literature in English',
#      'Business Management',
#      'Ghanaian Language']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'A1-B3 in French. Any other General Arts elective will be considered beside the mentioned requirements.'},
#  {'program': 'BA. Geography and Rural Development',
#   'cutoff point': 10,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Geography'],
#    'tracks': {'Humanities': ['Economics',
#      'Government',
#      'French',
#      'Literature in English',
#      ['Christian Religious Studies (CRS)', 'Islamic Religious Studies (IRS)'],
#      'History',
#      'Elective Mathematics',
#      'Ghanaian Language']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Any other General Arts elective will be considered beside the mentioned requirements.'},
#  {'program': 'BA. History',
#   'cutoff point': 15,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': [['History', 'Government']],
#    'tracks': {'Humanities': ['Economics',
#      'Geography',
#      'French',
#      'Elective Mathematics',
#      'Ghanaian Language',
#      'Literature in English',
#      ['Christian Religious Studies (CRS)',
#       'Islamic Religious Studies (IRS)']]}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Any other General Arts elective will be considered beside the mentioned requirements. A pass in Social Studies is required'},
#  {'program': 'BA. Linguistics',
#   'cutoff point': 15,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'Humanities': ['Literature in English',
#      'Ghanaian Language',
#      'French',
#      'Igbo',
#      'Wolof',
#      'Yoruba'],
#     'Group A': [['Literature in English',
#       'Ghanaian Language',
#       'French',
#       'Igbo',
#       'Wolof',
#       'Yoruba'],
#      'History',
#      'Geography',
#      'Economics',
#      'Christian Religious Studies (CRS)',
#      'Islamic Religious Studies (IRS)',
#      'Government',
#      'Business Management'],
#     'Group B': [['History',
#       'Geography',
#       'Economics',
#       'Christian Religious Studies (CRS)',
#       'Islamic Religious Studies (IRS)',
#       'Government',
#       'Business Management'],
#      'Literature in English',
#      'Ghanaian Language',
#      'French',
#      'Igbo',
#      'Wolof',
#      'Yoruba']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BA. Media and Communication Studies',
#   'cutoff point': 9,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'tracks': {'All': ['General Arts',
#       'General Science',
#       'Business',
#       'Visual Arts',
#       'Home Economics',
#       'General Agriculture',
#       'Technical']}}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants, Diploma Holders',
#   'special requirements / general information': 'Diploma holders in Communication Studies, Journalism, Archival Studies, International Relations can enter the second year.'},
#  {'program': 'BA. Political Studies',
#   'cutoff point': 9,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': [['History', 'Government']],
#    'tracks': {'Humanities': ['Economics',
#      'Geography',
#      'Elective Mathematics',
#      'French',
#      'Ghanaian Language',
#      'Literature in English',
#      ['Christian Religious Studies (CRS)',
#       'Islamic Religious Studies (IRS)']]}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BA. Religious Studies',
#   'cutoff point': 20,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': [['Christian Religious Studies (CRS)',
#      'Islamic Religious Studies (IRS)']],
#    'tracks': {'All': ['Agric',
#      'GArts',
#      'Science',
#      'Biz',
#      'Tech',
#      'Visual',
#      'Home Econs']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Diploma in Religious Studies or Theology holders can enter the second year.'},
#  {'program': 'BA. Sociology',
#   'cutoff point': 11,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'General': ['History',
#      'Geography',
#      'Literature in English',
#      'French',
#      'Ghanaian Language',
#      'Government',
#      'Business Management',
#      'Elective Mathematics',
#      'Economics',
#      'Physics',
#      'Chemistry',
#      'Biology',
#      'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Any other General Arts and Science electives will be considered beside the mentioned requirements.'},
#  {'program': 'BA. Social Work',
#   'cutoff point': 11,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'General': ['History',
#      'Geography',
#      'Literature in English',
#      'French',
#      'Ghanaian Language',
#      'Government',
#      'Business Management',
#      'Elective Mathematics',
#      'Economics',
#      'Physics',
#      'Chemistry',
#      'Biology',
#      'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': 'Any other General Arts and Science electives will be considered beside the mentioned requirements. Diploma in Social Work/Social Administration holders enter second year.'},
#  {'program': 'BSc. Business Administration (Human Resource Mgt./Management)',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['GArts', 'Science', 'Biz', 'Home Econs']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Business Administration (Marketing/International Business)',
#   'cutoff point': 9,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['GArts', 'Science', 'Biz', 'Home Econs']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Business Administration (Accounting/Banking and Finance)',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['GArts', 'Science', 'Biz']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Business Administration (Logistics and Supply Chain Mgt./Bus. Info. Tech.)',
#   'cutoff point': 8,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['GArts', 'Science', 'Biz']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'BSc. Hospitality and Tourism Management',
#   'cutoff point': 10,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['GArts', 'Science', 'Biz', 'Home Econs']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants',
#   'special requirements / general information': None},
#  {'program': 'LLB',
#   'cutoff point': 6,
#   'college': 'COLLEGE OF HUMANITIES AND SOCIAL SCIENCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'All': ['GArts', 'Science', 'Biz', 'Visual']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature Applicants, Degree Holders',
#   'special requirements / general information': 'Degree holders must pass an entrance exam and interview.'},
#  {'program': 'BSc. Biochemistry',
#   'cutoff point': 9,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Chemistry'],
#    'tracks': {'General Science': ['Physics', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': 'HND applicants with Second Class (Upper/Lower Division) may be admitted to the third or second year.'},
#  {'program': 'BSc. Food Science and Technology',
#   'cutoff point': 11,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Chemistry'],
#    'tracks': {'General Science': ['Physics', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Biological Sciences',
#   'cutoff point': 9,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Chemistry'],
#    'tracks': {'General Science': ['Physics', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Environmental Sciences',
#   'cutoff point': 12,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Chemistry'],
#    'tracks': {'General Science': [['Physics', 'Elective Mathematics'],
#      ['Biology', 'Agricultural Science']]}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': 'Agricultural Science is acceptable in place of Biology.'},
#  {'program': 'BSc. Chemistry',
#   'cutoff point': 15,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Chemistry', 'Physics'],
#    'tracks': {'General Science': ['Elective Mathematics', 'Biology']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Computer Science',
#   'cutoff point': 7,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics', 'Physics'],
#    'tracks': {'General Science': ['Chemistry',
#      'Applied Electricity',
#      'Electronics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': 'Applicants with HND in Mathematics, Engineering, or related disciplines with Second Class Lower or better may be placed in Year 2 or 3.'},
#  {'program': 'BSc. Information Technology',
#   'cutoff point': None,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics'],
#    'tracks': {'All': ['GArts',
#      'Science',
#      'Biz',
#      'Visual',
#      'Tech',
#      'Home Econs']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': 'Applicants with HND in Mathematics, Engineering, or related disciplines with Second Class Lower or better may be placed in Year 2 or 3.'},
#  {'program': 'BSc. Mathematics',
#   'cutoff point': 15,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics', 'Physics'],
#    'tracks': {'General Science': ['Chemistry', 'Biology']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Actuarial Science',
#   'cutoff point': 10,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics'],
#    'tracks': {'All': ['GArts',
#      'Science',
#      'Biz',
#      'Visual',
#      'Tech',
#      'Agric',
#      'Home Econs']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Statistics',
#   'cutoff point': 12,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics'],
#    'tracks': {'All': ['GArts',
#      'Science',
#      'Biz',
#      'Visual',
#      'Tech',
#      'Agric',
#      'Home Econs']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Physics',
#   'cutoff point': 16,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics', 'Physics'],
#    'tracks': {'General Science': ['Chemistry', 'Electronics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Meteorology and Climate Science',
#   'cutoff point': 17,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Elective Mathematics', 'Physics'],
#    'tracks': {'General Science': ['Chemistry', 'Electronics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'Doctor of Optometry',
#   'cutoff point': 6,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Biology', 'Physics'],
#    'tracks': {'General Science': ['Chemistry', 'Elective Mathematics']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Dietetics',
#   'cutoff point': None,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'General Science': ['Biology',
#      'Chemistry',
#      ['Elective Mathematics', 'Physics']],
#     'Group A': ['Food and Nutrition',
#      'Management in Living',
#      'Chemistry',
#      'Biology']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None},
#  {'program': 'BSc. Human Nutrition',
#   'cutoff point': None,
#   'college': 'COLLEGE OF SCIENCE',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': None,
#    'tracks': {'General Science': ['Biology',
#      'Chemistry',
#      ['Elective Mathematics', 'Physics']],
#     'Group A': ['Food and Nutrition',
#      'Management in Living',
#      'Chemistry',
#      'Biology']}},
#   'applicant type': 'WASSCE/SSSCE, A-Level, Mature',
#   'special requirements / general information': None}]
