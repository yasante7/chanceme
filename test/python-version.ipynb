# %%
import json
import pandas as pd

# %%
with open('../src/data/programdata.json', 'r', encoding='utf-8') as k:
    kumasi = json.load(k)

# %%
shorttracknames = {
    "GArts": "General Arts", 
    "Science": "General Science", 
    "Biz": "Business", 
    "Visual": "Visual Arts",
    "Home Econs": "Home Economics",
    "Agric": "Agricultural Science",
    "Tech": "Technical"
}


PROGRAM_SUBJECTS = {
  'General Science': [
    'Elective Mathematics',
    'Physics',
    'Chemistry',
    'Biology',
    'Elective ICT',
    'Geography'
  ],
  'General Arts': [
    'Economics',
    'Geography',
    'Government',
    'History',
    'Elective Mathematics',
    'Christian Religious Studies',
    'Music',
    'Elective ICT',
    'Literature in English',
    'French',
    'Fante',
    'Akuapem Twi',
    'Asante Twi',
    'Ga',
    'Ewe',
    'Arabic',
    'Dagaare',
    'Dagbani',
    'Gonja',
    'Kasem',
    'Nzema'
  ],
  'Business': [
    'Business Management',
    'Financial Accounting',
    'Economics',
    'Cost Accounting',
    'Elective Mathematics',
    'Elective ICT',
    'French',
    'Clerical Office Duties'
  ],
  'Visual Arts': [
    'ICT',
    'General Knowledge in Art',
    'Textiles',
    'Picture Making',
    'Ceramics and Sculpture',
    'Ceramics and Basketry',
    'Graphic Design',
    'Leather Work',
    'Basketry',
    'Sculpture',
    'French'
  ],
  'Home Economics': [
    'Economics',
    'Food and Nutrition',
    'Clothing and Textiles',
    'Management in Living',
    'Chemistry',
    'Biology'
  ],
  'Agricultural Science': [
    'General Agriculture',
    'Animal Husbandry',
    'Agricultural Economics',
    'Elective Mathematics',
    'Crop Science',
    'Chemistry',
    'Physics'
  ],
  'Technical': [
    'Technical Drawing',
    'Building Construction',
    'Woodwork',
    'Metalwork',
    'Auto Mechanics',
    'Electronics',
    'Applied Electricity',
    'Automobile Engineering',
    'Electrical Engineering'
  ]
}

languages = [
  'Fante',
  'Akuapem Twi',
  'Asante Twi',
  'Ga',
  'Ewe',
  'Arabic',
  'Dagaare',
  'Dagbani',
  'Gonja',
  'Kasem',
  'Nzema'
]
originaltracknames = PROGRAM_SUBJECTS.keys()

# %%
for program in kumasi:
    tracks = program['elective subjects']['tracks']
    for trackkey, trackvalues in tracks.items():
        # Expand shorthand track names
        if trackkey in shorttracknames:
            tracks[trackkey] = PROGRAM_SUBJECTS[shorttracknames[trackkey]]
            trackvalues = tracks[trackkey]  # update reference

        # Replace "Ghanaian Language" (even if inside lists)
        for i, subject in enumerate(trackvalues):
            if isinstance(subject, str):
                if subject == "Ghanaian Language":
                    print("Replacing in:", program['program'])
                    trackvalues[i] = languages
            elif isinstance(subject, list):
                for j, value in enumerate(subject):
                    if value == "Ghanaian Language":
                        print("Replacing in nested list:", program['program'])
                        subject[j] = languages
# Out:
# Replacing in: BA. Integrated Rural Art and Industry
# Replacing in: BA. Economics
# Replacing in: BA. English
# Replacing in: BA. French and Francophone Studies
# Replacing in: BA. Geography and Rural Development
# Replacing in: BA. History
# Replacing in: BA. Linguistics
# Replacing in nested list: BA. Linguistics
# Replacing in: BA. Linguistics
# Replacing in: BA. Political Studies
# Replacing in: BA. Sociology
# Replacing in: BA. Social Work

# %%
kumasi
# Out:
# [{'program': 'BSc. Agriculture',
#   'cutoff point': 20,
#   'college': 'COLLEGE OF AGRICULTURE AND NATURAL RESOURCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Chemistry'],
#    'tracks': {'Group A': [['Physics', 'Elective Mathematics'],
#      ['Biology',
#       'General Agriculture',
#       'Animal Husbandry',
#       'Crop Husbandry',
#       'Horticulture']]}},
#   'applicant type': 'WASSCE/SSSCE',
#   'special requirements / general information': None},
#  {'program': 'BSc. Agricultural Biotechnology',
#   'cutoff point': 17,
#   'college': 'COLLEGE OF AGRICULTURE AND NATURAL RESOURCES',
#   'campus': 'Kumasi (Main) Campus',
#   'core subjects': 'English Language, Mathematics, Integrated Science',
#   'elective subjects': {'main': ['Chemistry'],
#    'tracks': {'Group A': [['Physics', 'Elective Mathematics'],
#      ['Biology',
#       'General Agriculture',
# ...

# %%
# Export the updated obuasi data to a new JSON file
with open('../src/data/programsdata_updated.json', 'w', encoding='utf-8') as f:
    json.dump(kumasi, f, indent=4)
