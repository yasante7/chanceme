# %%
import requests
from bs4 import BeautifulSoup
import json
import sys
import os

# %%
page = requests.get('https://edurank.org/geo/gh/')
soup = BeautifulSoup(page.text, 'html.parser')

# %%
# Find all university blocks
universities = soup.findAll('div', {'class': 'block-cont pt-4 mb-4'})

all_schools = []

for block in universities:
    try:
        # University name and URL
        name_tag = block.find("h2").find("a")
        university_name = name_tag.text.strip().split(maxsplit=1)[-1]  # Remove "1."
        university_url = name_tag["href"]

        # Location
        location = block.find("div", class_="uni-card__geo").get_text(strip=True)

        # Rankings
        ranks = block.find_all("div", class_="uni-card__rank")
        rank_africa = ranks[0].get_text(strip=True).split('in')[0] if len(ranks) > 0 else None
        rank_world = ranks[1].get_text(strip=True).split('in')[0] if len(ranks) > 1 else None

        # Logo URL
        logo_tag = block.find("img")
        logo_url = logo_tag["src"] if logo_tag else None

        # Stats
        info_items = block.select("dl.uni-card__info-list > div")
        stats = {item.dt.text.strip(): item.dd.text.strip() for item in info_items}

        # Extra links
        extra_links = block.select("a.block-cont__double-link")
        stats_link = extra_links[0]["href"] if len(extra_links) > 0 else None
        rankings_link = extra_links[1]["href"] if len(extra_links) > 1 else None

        # Output all data
        data = {
            "university_name": university_name,
            "university_url": university_url,
            "location": location,
            "rank_africa": rank_africa,
            "rank_world": rank_world,
            "logo_url": logo_url,
            "acceptance_rate": stats.get("Acceptance Rate"),
            "enrollment": stats.get("Enrollment"),
            "male_female_ratio": stats.get("Male:Female"),
            "founded": stats.get("Founded"),
            "statistics_link": stats_link,
            "rankings_link": rankings_link
        }

        all_schools.append(data)

    except Exception as e:
        print("Error parsing a university block:", e)

# Output
all_schools
# Out:
# [{'university_name': 'University of Ghana',
#   'university_url': 'https://edurank.org/uni/university-of-ghana/',
#   'location': 'Legon',
#   'rank_africa': '#11',
#   'rank_world': '#932',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/university-of-ghana-logo.png',
#   'acceptance_rate': '18%',
#   'enrollment': '67,914',
#   'male_female_ratio': '51:49',
#   'founded': '1948',
#   'statistics_link': 'https://edurank.org/uni/university-of-ghana/',
#   'rankings_link': 'https://edurank.org/uni/university-of-ghana/rankings/'},
#  {'university_name': 'Kwame Nkrumah University of Science and Technology',
#   'university_url': 'https://edurank.org/uni/kwame-nkrumah-university-of-science-and-technology/',
#   'location': 'Kumasi',
#   'rank_africa': '#20',
#   'rank_world': '#1302',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/kwame-nkrumah-university-of-science-and-technology-logo.png',
#   'acceptance_rate': '54%',
#   'enrollment': '85,000',
#   'male_female_ratio': None,
#   'founded': '1951',
#   'statistics_link': 'https://edurank.org/uni/kwame-nkrumah-university-of-science-and-technology/',
#   'rankings_link': 'https://edurank.org/uni/kwame-nkrumah-university-of-science-and-technology/rankings/'},
#  {'university_name': 'University of Cape Coast',
#   'university_url': 'https://edurank.org/uni/university-of-cape-coast/',
#   'location': 'Cape Coast',
#   'rank_africa': '#45',
#   'rank_world': '#2505',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/university-of-cape-coast-logo.png',
#   'acceptance_rate': '60%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1962',
#   'statistics_link': 'https://edurank.org/uni/university-of-cape-coast/',
#   'rankings_link': 'https://edurank.org/uni/university-of-cape-coast/rankings/'},
#  {'university_name': 'University of Education, Winneba',
#   'university_url': 'https://edurank.org/uni/university-of-education-winneba/',
#   'location': 'Winneba',
#   'rank_africa': '#97',
#   'rank_world': '#3697',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/university-of-education-winneba-logo.jpg',
#   'acceptance_rate': '79%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1992',
#   'statistics_link': 'https://edurank.org/uni/university-of-education-winneba/',
#   'rankings_link': 'https://edurank.org/uni/university-of-education-winneba/rankings/'},
#  {'university_name': 'University for Development Studies',
#   'university_url': 'https://edurank.org/uni/university-for-development-studies/',
#   'location': 'Tamale',
#   'rank_africa': '#120',
#   'rank_world': '#4002',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/university-for-development-studies-logo.jpg',
#   'acceptance_rate': '16%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1992',
#   'statistics_link': 'https://edurank.org/uni/university-for-development-studies/',
#   'rankings_link': 'https://edurank.org/uni/university-for-development-studies/rankings/'},
#  {'university_name': 'Ghana Technology University College',
#   'university_url': 'https://edurank.org/uni/ghana-technology-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#173',
#   'rank_world': '#5077',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/ghana-technology-university-college-logo.png',
#   'acceptance_rate': '77%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2006',
#   'statistics_link': 'https://edurank.org/uni/ghana-technology-university-college/',
#   'rankings_link': 'https://edurank.org/uni/ghana-technology-university-college/rankings/'},
#  {'university_name': 'Ghana Institute of Management and Public Administration',
#   'university_url': 'https://edurank.org/uni/ghana-institute-of-management-and-public-administration/',
#   'location': 'Accra',
#   'rank_africa': '#183',
#   'rank_world': '#5241',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/ghana-institute-of-management-and-public-administration-logo.jpg',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1961',
#   'statistics_link': 'https://edurank.org/uni/ghana-institute-of-management-and-public-administration/',
#   'rankings_link': 'https://edurank.org/uni/ghana-institute-of-management-and-public-administration/rankings/'},
#  {'university_name': 'University of Health and Allied Sciences',
#   'university_url': 'https://edurank.org/uni/university-of-health-and-allied-sciences/',
#   'location': 'Ho',
#   'rank_africa': '#208',
#   'rank_world': '#5715',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/university-of-health-and-allied-sciences-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2011',
#   'statistics_link': 'https://edurank.org/uni/university-of-health-and-allied-sciences/',
#   'rankings_link': 'https://edurank.org/uni/university-of-health-and-allied-sciences/rankings/'},
#  {'university_name': 'Ho Technical University',
#   'university_url': 'https://edurank.org/uni/ho-technical-university/',
#   'location': 'Ho',
#   'rank_africa': '#221',
#   'rank_world': '#5908',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/ho-technical-university-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1968',
#   'statistics_link': 'https://edurank.org/uni/ho-technical-university/',
#   'rankings_link': 'https://edurank.org/uni/ho-technical-university/rankings/'},
#  {'university_name': 'University of Mines and Technology',
#   'university_url': 'https://edurank.org/uni/university-of-mines-and-technology/',
#   'location': 'Tarkwa',
#   'rank_africa': '#225',
#   'rank_world': '#5991',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/university-of-mines-and-technology-logo.jpg',
#   'acceptance_rate': '19%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2004',
#   'statistics_link': 'https://edurank.org/uni/university-of-mines-and-technology/',
#   'rankings_link': 'https://edurank.org/uni/university-of-mines-and-technology/rankings/'},
#  {'university_name': 'University of Professional Studies, Accra',
#   'university_url': 'https://edurank.org/uni/university-of-professional-studies-accra/',
#   'location': 'Accra',
#   'rank_africa': '#226',
#   'rank_world': '#6006',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/university-of-professional-studies-accra-logo.png',
#   'acceptance_rate': '60%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1965',
#   'statistics_link': 'https://edurank.org/uni/university-of-professional-studies-accra/',
#   'rankings_link': 'https://edurank.org/uni/university-of-professional-studies-accra/rankings/'},
#  {'university_name': 'Central University',
#   'university_url': 'https://edurank.org/uni/central-university/',
#   'location': 'Tema',
#   'rank_africa': '#250',
#   'rank_world': '#6288',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/central-university-logo.png',
#   'acceptance_rate': '45%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1997',
#   'statistics_link': 'https://edurank.org/uni/central-university/',
#   'rankings_link': 'https://edurank.org/uni/central-university/rankings/'},
#  {'university_name': 'Kumasi Technical University',
#   'university_url': 'https://edurank.org/uni/kumasi-technical-university/',
#   'location': 'Kumasi',
#   'rank_africa': '#257',
#   'rank_world': '#6381',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/kumasi-technical-university-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1954',
#   'statistics_link': 'https://edurank.org/uni/kumasi-technical-university/',
#   'rankings_link': 'https://edurank.org/uni/kumasi-technical-university/rankings/'},
#  {'university_name': 'University of Energy and Natural Resources',
#   'university_url': 'https://edurank.org/uni/university-of-energy-and-natural-resources/',
#   'location': 'Sunyani',
#   'rank_africa': '#260',
#   'rank_world': '#6452',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/university-of-energy-and-natural-resources-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2011',
#   'statistics_link': 'https://edurank.org/uni/university-of-energy-and-natural-resources/',
#   'rankings_link': 'https://edurank.org/uni/university-of-energy-and-natural-resources/rankings/'},
#  {'university_name': 'Ashesi University',
#   'university_url': 'https://edurank.org/uni/ashesi-university/',
#   'location': 'Berekuso',
#   'rank_africa': '#263',
#   'rank_world': '#6494',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/ashesi-university-logo.png',
#   'acceptance_rate': '16%',
#   'enrollment': '1,505',
#   'male_female_ratio': None,
#   'founded': '2002',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Accra Technical University',
#   'university_url': 'https://edurank.org/uni/accra-technical-university/',
#   'location': 'Accra',
#   'rank_africa': '#283',
#   'rank_world': '#6766',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/accra-technical-university-logo.png',
#   'acceptance_rate': '100%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1949',
#   'statistics_link': 'https://edurank.org/uni/accra-technical-university/',
#   'rankings_link': 'https://edurank.org/uni/accra-technical-university/rankings/'},
#  {'university_name': 'Pentecost University College',
#   'university_url': 'https://edurank.org/uni/pentecost-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#289',
#   'rank_world': '#6910',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/pentecost-university-college-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2003',
#   'statistics_link': 'https://edurank.org/uni/pentecost-university-college/',
#   'rankings_link': 'https://edurank.org/uni/pentecost-university-college/rankings/'},
#  {'university_name': 'Methodist University College',
#   'university_url': 'https://edurank.org/uni/methodist-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#317',
#   'rank_world': '#7148',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/methodist-university-college-logo.png',
#   'acceptance_rate': None,
#   'enrollment': '4,000',
#   'male_female_ratio': None,
#   'founded': '2000',
#   'statistics_link': 'https://edurank.org/uni/methodist-university-college/',
#   'rankings_link': 'https://edurank.org/uni/methodist-university-college/rankings/'},
#  {'university_name': 'Catholic University College of Ghana',
#   'university_url': 'https://edurank.org/uni/catholic-university-college-of-ghana/',
#   'location': 'Sunyani',
#   'rank_africa': '#325',
#   'rank_world': '#7182',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/catholic-university-college-of-ghana-logo.png',
#   'acceptance_rate': '50%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2003',
#   'statistics_link': 'https://edurank.org/uni/catholic-university-college-of-ghana/',
#   'rankings_link': 'https://edurank.org/uni/catholic-university-college-of-ghana/rankings/'},
#  {'university_name': 'Advanced Business College',
#   'university_url': 'https://edurank.org/uni/advanced-business-college/',
#   'location': 'Accra',
#   'rank_africa': '#332',
#   'rank_world': '#7242',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/advanced-business-college-logo.png',
#   'acceptance_rate': '94%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2005',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Takoradi Technical University',
#   'university_url': 'https://edurank.org/uni/takoradi-technical-university/',
#   'location': 'Takoradi',
#   'rank_africa': '#335',
#   'rank_world': '#7273',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/takoradi-technical-university-logo.png',
#   'acceptance_rate': '60%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1954',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Islamic University College, Ghana',
#   'university_url': 'https://edurank.org/uni/islamic-university-college-ghana/',
#   'location': 'Accra',
#   'rank_africa': '#341',
#   'rank_world': '#7329',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/islamic-university-college-ghana-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1988',
#   'statistics_link': 'https://edurank.org/uni/islamic-university-college-ghana/',
#   'rankings_link': 'https://edurank.org/uni/islamic-university-college-ghana/rankings/'},
#  {'university_name': 'Presbyterian University College',
#   'university_url': 'https://edurank.org/uni/presbyterian-university-college/',
#   'location': 'Abetifi',
#   'rank_africa': '#343',
#   'rank_world': '#7352',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/presbyterian-university-college-logo.jpg',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2003',
#   'statistics_link': 'https://edurank.org/uni/presbyterian-university-college/',
#   'rankings_link': 'https://edurank.org/uni/presbyterian-university-college/rankings/'},
#  {'university_name': 'Cape Coast Technical University',
#   'university_url': 'https://edurank.org/uni/cape-coast-technical-university/',
#   'location': 'Cape Coast',
#   'rank_africa': '#344',
#   'rank_world': '#7353',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/cape-coast-technical-university-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1986',
#   'statistics_link': 'https://edurank.org/uni/cape-coast-technical-university/',
#   'rankings_link': 'https://edurank.org/uni/cape-coast-technical-university/rankings/'},
#  {'university_name': 'Christian Service University College',
#   'university_url': 'https://edurank.org/uni/christian-service-university-college/',
#   'location': 'Santasi-Kumasi',
#   'rank_africa': '#346',
#   'rank_world': '#7380',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/christian-service-university-college-logo.jpg',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1974',
#   'statistics_link': 'https://edurank.org/uni/christian-service-university-college/',
#   'rankings_link': 'https://edurank.org/uni/christian-service-university-college/rankings/'},
#  {'university_name': 'Garden City University College',
#   'university_url': 'https://edurank.org/uni/garden-city-university-college/',
#   'location': 'Kumasi',
#   'rank_africa': '#362',
#   'rank_world': '#7612',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/garden-city-university-college-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2001',
#   'statistics_link': 'https://edurank.org/uni/garden-city-university-college/',
#   'rankings_link': 'https://edurank.org/uni/garden-city-university-college/rankings/'},
#  {'university_name': 'All Nations University College',
#   'university_url': 'https://edurank.org/uni/all-nations-university-college/',
#   'location': 'Koforidua',
#   'rank_africa': '#368',
#   'rank_world': '#7768',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/all-nations-university-college-logo.png',
#   'acceptance_rate': '84%',
#   'enrollment': '3,291',
#   'male_female_ratio': '66:34',
#   'founded': '1996',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'African University College of Communications',
#   'university_url': 'https://edurank.org/uni/african-university-college-of-communications/',
#   'location': 'Accra',
#   'rank_africa': '#370',
#   'rank_world': '#7816',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/african-university-college-of-communications-logo.jpg',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2001',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Data Link Institute',
#   'university_url': 'https://edurank.org/uni/data-link-institute/',
#   'location': 'Tema',
#   'rank_africa': '#391',
#   'rank_world': '#8253',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/data-link-institute-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1993',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Radford University College',
#   'university_url': 'https://edurank.org/uni/radford-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#396',
#   'rank_world': '#8359',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/radford-university-college-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': None,
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Mountcrest University College',
#   'university_url': 'https://edurank.org/uni/mountcrest-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#408',
#   'rank_world': '#8834',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/mountcrest-university-college-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2008',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Evangelical Presbyterian University College',
#   'university_url': 'https://edurank.org/uni/evangelical-presbyterian-university-college/',
#   'location': 'Ho',
#   'rank_africa': '#422',
#   'rank_world': '#9001',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/evangelical-presbyterian-university-college-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2008',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'University College of Agriculture and Environmental Studies',
#   'university_url': 'https://edurank.org/uni/university-college-of-agriculture-and-environmental-studies/',
#   'location': 'Bunso',
#   'rank_africa': '#433',
#   'rank_world': '#9223',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/university-college-of-agriculture-and-environmental-studies-logo.jpg',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2006',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Regional Maritime University',
#   'university_url': 'https://edurank.org/uni/regional-maritime-university/',
#   'location': 'Accra',
#   'rank_africa': '#443',
#   'rank_world': '#9422',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/regional-maritime-university-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1983',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Valley View University',
#   'university_url': 'https://edurank.org/uni/valley-view-university/',
#   'location': 'Accra',
#   'rank_africa': '#449',
#   'rank_world': '#9499',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/valley-view-university-logo.png',
#   'acceptance_rate': '67%',
#   'enrollment': '8,473',
#   'male_female_ratio': '65:35',
#   'founded': '1979',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Ghana Institute of Journalism',
#   'university_url': 'https://edurank.org/uni/ghana-institute-of-journalism/',
#   'location': 'Accra',
#   'rank_africa': '#456',
#   'rank_world': '#9623',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/ghana-institute-of-journalism-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1959',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Regent University College of Science and Technology',
#   'university_url': 'https://edurank.org/uni/regent-university-college-of-science-and-technology/',
#   'location': 'Accra',
#   'rank_africa': '#468',
#   'rank_world': '#9845',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/regent-university-college-of-science-and-technology-logo.png',
#   'acceptance_rate': '60%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2003',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Accra Institute of Technology',
#   'university_url': 'https://edurank.org/uni/accra-institute-of-technology/',
#   'location': 'Accra',
#   'rank_africa': '#505',
#   'rank_world': '#10449',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/accra-institute-of-technology-logo.png',
#   'acceptance_rate': '84%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2009',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Zenith University College',
#   'university_url': 'https://edurank.org/uni/zenith-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#515',
#   'rank_world': '#10548',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/zenith-university-college-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2001',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Sunyani Technical University',
#   'university_url': 'https://edurank.org/uni/sunyani-technical-university/',
#   'location': 'Sunyani',
#   'rank_africa': '#527',
#   'rank_world': '#10652',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/sunyani-technical-university-logo.png',
#   'acceptance_rate': '70%',
#   'enrollment': '12,000',
#   'male_female_ratio': None,
#   'founded': '1983',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Lancaster University, Ghana',
#   'university_url': 'https://edurank.org/uni/lancaster-university-ghana/',
#   'location': 'Accra',
#   'rank_africa': '#550',
#   'rank_world': '#10847',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/lancaster-university-ghana-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2013',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Academic City University College',
#   'university_url': 'https://edurank.org/uni/academic-city-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#570',
#   'rank_world': '#11081',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/academic-city-university-college-logo.png',
#   'acceptance_rate': '69%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2009',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Koforidua Technical University',
#   'university_url': 'https://edurank.org/uni/koforidua-technical-university/',
#   'location': 'Koforidua',
#   'rank_africa': '#595',
#   'rank_world': '#11326',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/koforidua-technical-university-logo.png',
#   'acceptance_rate': '100%',
#   'enrollment': '6,895',
#   'male_female_ratio': None,
#   'founded': '1997',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Jayee University College',
#   'university_url': 'https://edurank.org/uni/jayee-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#604',
#   'rank_world': '#11439',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/jayee-university-college-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1988',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Knutsford University College',
#   'university_url': 'https://edurank.org/uni/knutsford-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#605',
#   'rank_world': '#11445',
#   'logo_url': None,
#   'acceptance_rate': '47%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2005',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'BlueCrest College',
#   'university_url': 'https://edurank.org/uni/bluecrest-college/',
#   'location': 'Accra',
#   'rank_africa': '#623',
#   'rank_world': '#11540',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/bluecrest-college-logo.png',
#   'acceptance_rate': '82%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2000',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Webster University Ghana',
#   'university_url': 'https://edurank.org/uni/webster-university-ghana/',
#   'location': 'Accra',
#   'rank_africa': '#651',
#   'rank_world': '#11768',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/webster-university-ghana-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2013',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Wisconsin International University College',
#   'university_url': 'https://edurank.org/uni/wisconsin-international-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#652',
#   'rank_world': '#11770',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/wisconsin-international-university-college-logo.png',
#   'acceptance_rate': '50%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2000',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Ghana Institute of Languages',
#   'university_url': 'https://edurank.org/uni/ghana-institute-of-languages/',
#   'location': 'Accra',
#   'rank_africa': '#684',
#   'rank_world': '#12028',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/ghana-institute-of-languages-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1961',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'University College of Management Studies',
#   'university_url': 'https://edurank.org/uni/university-college-of-management-studies/',
#   'location': 'Accra',
#   'rank_africa': '#714',
#   'rank_world': '#12202',
#   'logo_url': None,
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1974',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'KAAF University College',
#   'university_url': 'https://edurank.org/uni/kaaf-university-college/',
#   'location': 'Kasoa',
#   'rank_africa': '#758',
#   'rank_world': '#12450',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/kaaf-university-college-logo.png',
#   'acceptance_rate': '24%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2007',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Dominion University College',
#   'university_url': 'https://edurank.org/uni/dominion-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#775',
#   'rank_world': '#12510',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/dominion-university-college-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2009',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Tamale Technical University',
#   'university_url': 'https://edurank.org/uni/tamale-technical-university/',
#   'location': 'Tamale',
#   'rank_africa': '#784',
#   'rank_world': '#12557',
#   'logo_url': None,
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1950',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Anglican University College of Technology',
#   'university_url': 'https://edurank.org/uni/anglican-university-college-of-technology/',
#   'location': 'Teshie',
#   'rank_africa': '#788',
#   'rank_world': '#12583',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/anglican-university-college-of-technology-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': None,
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Ghana Christian University College',
#   'university_url': 'https://edurank.org/uni/ghana-christian-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#804',
#   'rank_world': '#12673',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/ghana-christian-university-college-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1966',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Ghana Baptist University College',
#   'university_url': 'https://edurank.org/uni/ghana-baptist-university-college/',
#   'location': 'Abuakwa-Kumasi',
#   'rank_africa': '#829',
#   'rank_world': '#12821',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/ghana-baptist-university-college-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2006',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Marshalls University College',
#   'university_url': 'https://edurank.org/uni/marshalls-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#874',
#   'rank_world': '#13073',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/marshalls-university-college-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2012',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Catholic Institute of Business and Technology',
#   'university_url': 'https://edurank.org/uni/catholic-institute-of-business-and-technology/',
#   'location': 'Accra',
#   'rank_africa': '#883',
#   'rank_world': '#13115',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/catholic-institute-of-business-and-technology-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': None,
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Kings University College',
#   'university_url': 'https://edurank.org/uni/kings-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#888',
#   'rank_world': '#13140',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/kings-university-college-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2009',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'West End University College',
#   'university_url': 'https://edurank.org/uni/west-end-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#912',
#   'rank_world': '#13266',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/west-end-university-college-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2010',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Bolgatanga Polytechnic',
#   'university_url': 'https://edurank.org/uni/bolgatanga-polytechnic/',
#   'location': 'Bolgatanga',
#   'rank_africa': '#918',
#   'rank_world': '#13284',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/bolgatanga-polytechnic-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2003',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Christ Apostolic University College',
#   'university_url': 'https://edurank.org/uni/christ-apostolic-university-college/',
#   'location': 'Kumasi',
#   'rank_africa': '#920',
#   'rank_world': '#13291',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/christ-apostolic-university-college-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2010',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Kessben College',
#   'university_url': 'https://edurank.org/uni/kessben-college/',
#   'location': 'Kuntenase',
#   'rank_africa': '#926',
#   'rank_world': '#13319',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/kessben-college-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': None,
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Perez University College',
#   'university_url': 'https://edurank.org/uni/perez-university-college/',
#   'location': 'Winneba',
#   'rank_africa': '#963',
#   'rank_world': '#13512',
#   'logo_url': None,
#   'acceptance_rate': None,
#   'enrollment': '151',
#   'male_female_ratio': '50:50',
#   'founded': '2001',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Spiritan University College',
#   'university_url': 'https://edurank.org/uni/spiritan-university-college/',
#   'location': 'Ejisu',
#   'rank_africa': '#983',
#   'rank_world': '#13605',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/spiritan-university-college-logo.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1990',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Wa Polytechnic',
#   'university_url': 'https://edurank.org/uni/wa-polytechnic/',
#   'location': 'Wa',
#   'rank_africa': '#988',
#   'rank_world': '#13631',
#   'logo_url': 'https://edurank.org/assets/img/uni-logos/wa-polytechnic-logo.png',
#   'acceptance_rate': None,
#   'enrollment': '3,000',
#   'male_female_ratio': None,
#   'founded': '1999',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Maranatha University College',
#   'university_url': 'https://edurank.org/uni/maranatha-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#1056',
#   'rank_world': '#13981',
#   'logo_url': None,
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1972',
#   'statistics_link': None,
#   'rankings_link': None}]

# %%
# 
for school in all_schools:
    logo_path = f"{school['university_name'].replace(' ', '_')}.png"
    school['logo_url'] = logo_path

# %%
all_schools
# Out:
# [{'university_name': 'University of Ghana',
#   'university_url': 'https://edurank.org/uni/university-of-ghana/',
#   'location': 'Legon',
#   'rank_africa': '#11inAfrica',
#   'rank_world': '#932inthe World',
#   'logo_url': 'University_of_Ghana.png',
#   'acceptance_rate': '18%',
#   'enrollment': '67,914',
#   'male_female_ratio': '51:49',
#   'founded': '1948',
#   'statistics_link': 'https://edurank.org/uni/university-of-ghana/',
#   'rankings_link': 'https://edurank.org/uni/university-of-ghana/rankings/'},
#  {'university_name': 'Kwame Nkrumah University of Science and Technology',
#   'university_url': 'https://edurank.org/uni/kwame-nkrumah-university-of-science-and-technology/',
#   'location': 'Kumasi',
#   'rank_africa': '#20inAfrica',
#   'rank_world': '#1302inthe World',
#   'logo_url': 'Kwame_Nkrumah_University_of_Science_and_Technology.png',
#   'acceptance_rate': '54%',
#   'enrollment': '85,000',
#   'male_female_ratio': None,
#   'founded': '1951',
#   'statistics_link': 'https://edurank.org/uni/kwame-nkrumah-university-of-science-and-technology/',
#   'rankings_link': 'https://edurank.org/uni/kwame-nkrumah-university-of-science-and-technology/rankings/'},
#  {'university_name': 'University of Cape Coast',
#   'university_url': 'https://edurank.org/uni/university-of-cape-coast/',
#   'location': 'Cape Coast',
#   'rank_africa': '#45inAfrica',
#   'rank_world': '#2505inthe World',
#   'logo_url': 'University_of_Cape_Coast.png',
#   'acceptance_rate': '60%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1962',
#   'statistics_link': 'https://edurank.org/uni/university-of-cape-coast/',
#   'rankings_link': 'https://edurank.org/uni/university-of-cape-coast/rankings/'},
#  {'university_name': 'University of Education, Winneba',
#   'university_url': 'https://edurank.org/uni/university-of-education-winneba/',
#   'location': 'Winneba',
#   'rank_africa': '#97inAfrica',
#   'rank_world': '#3697inthe World',
#   'logo_url': 'University_of_Education,_Winneba.png',
#   'acceptance_rate': '79%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1992',
#   'statistics_link': 'https://edurank.org/uni/university-of-education-winneba/',
#   'rankings_link': 'https://edurank.org/uni/university-of-education-winneba/rankings/'},
#  {'university_name': 'University for Development Studies',
#   'university_url': 'https://edurank.org/uni/university-for-development-studies/',
#   'location': 'Tamale',
#   'rank_africa': '#120inAfrica',
#   'rank_world': '#4002inthe World',
#   'logo_url': 'University_for_Development_Studies.png',
#   'acceptance_rate': '16%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1992',
#   'statistics_link': 'https://edurank.org/uni/university-for-development-studies/',
#   'rankings_link': 'https://edurank.org/uni/university-for-development-studies/rankings/'},
#  {'university_name': 'Ghana Technology University College',
#   'university_url': 'https://edurank.org/uni/ghana-technology-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#173inAfrica',
#   'rank_world': '#5077inthe World',
#   'logo_url': 'Ghana_Technology_University_College.png',
#   'acceptance_rate': '77%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2006',
#   'statistics_link': 'https://edurank.org/uni/ghana-technology-university-college/',
#   'rankings_link': 'https://edurank.org/uni/ghana-technology-university-college/rankings/'},
#  {'university_name': 'Ghana Institute of Management and Public Administration',
#   'university_url': 'https://edurank.org/uni/ghana-institute-of-management-and-public-administration/',
#   'location': 'Accra',
#   'rank_africa': '#183inAfrica',
#   'rank_world': '#5241inthe World',
#   'logo_url': 'Ghana_Institute_of_Management_and_Public_Administration.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1961',
#   'statistics_link': 'https://edurank.org/uni/ghana-institute-of-management-and-public-administration/',
#   'rankings_link': 'https://edurank.org/uni/ghana-institute-of-management-and-public-administration/rankings/'},
#  {'university_name': 'University of Health and Allied Sciences',
#   'university_url': 'https://edurank.org/uni/university-of-health-and-allied-sciences/',
#   'location': 'Ho',
#   'rank_africa': '#208inAfrica',
#   'rank_world': '#5715inthe World',
#   'logo_url': 'University_of_Health_and_Allied_Sciences.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2011',
#   'statistics_link': 'https://edurank.org/uni/university-of-health-and-allied-sciences/',
#   'rankings_link': 'https://edurank.org/uni/university-of-health-and-allied-sciences/rankings/'},
#  {'university_name': 'Ho Technical University',
#   'university_url': 'https://edurank.org/uni/ho-technical-university/',
#   'location': 'Ho',
#   'rank_africa': '#221inAfrica',
#   'rank_world': '#5908inthe World',
#   'logo_url': 'Ho_Technical_University.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1968',
#   'statistics_link': 'https://edurank.org/uni/ho-technical-university/',
#   'rankings_link': 'https://edurank.org/uni/ho-technical-university/rankings/'},
#  {'university_name': 'University of Mines and Technology',
#   'university_url': 'https://edurank.org/uni/university-of-mines-and-technology/',
#   'location': 'Tarkwa',
#   'rank_africa': '#225inAfrica',
#   'rank_world': '#5991inthe World',
#   'logo_url': 'University_of_Mines_and_Technology.png',
#   'acceptance_rate': '19%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2004',
#   'statistics_link': 'https://edurank.org/uni/university-of-mines-and-technology/',
#   'rankings_link': 'https://edurank.org/uni/university-of-mines-and-technology/rankings/'},
#  {'university_name': 'University of Professional Studies, Accra',
#   'university_url': 'https://edurank.org/uni/university-of-professional-studies-accra/',
#   'location': 'Accra',
#   'rank_africa': '#226inAfrica',
#   'rank_world': '#6006inthe World',
#   'logo_url': 'University_of_Professional_Studies,_Accra.png',
#   'acceptance_rate': '60%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1965',
#   'statistics_link': 'https://edurank.org/uni/university-of-professional-studies-accra/',
#   'rankings_link': 'https://edurank.org/uni/university-of-professional-studies-accra/rankings/'},
#  {'university_name': 'Central University',
#   'university_url': 'https://edurank.org/uni/central-university/',
#   'location': 'Tema',
#   'rank_africa': '#250inAfrica',
#   'rank_world': '#6288inthe World',
#   'logo_url': 'Central_University.png',
#   'acceptance_rate': '45%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1997',
#   'statistics_link': 'https://edurank.org/uni/central-university/',
#   'rankings_link': 'https://edurank.org/uni/central-university/rankings/'},
#  {'university_name': 'Kumasi Technical University',
#   'university_url': 'https://edurank.org/uni/kumasi-technical-university/',
#   'location': 'Kumasi',
#   'rank_africa': '#257inAfrica',
#   'rank_world': '#6381inthe World',
#   'logo_url': 'Kumasi_Technical_University.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1954',
#   'statistics_link': 'https://edurank.org/uni/kumasi-technical-university/',
#   'rankings_link': 'https://edurank.org/uni/kumasi-technical-university/rankings/'},
#  {'university_name': 'University of Energy and Natural Resources',
#   'university_url': 'https://edurank.org/uni/university-of-energy-and-natural-resources/',
#   'location': 'Sunyani',
#   'rank_africa': '#260inAfrica',
#   'rank_world': '#6452inthe World',
#   'logo_url': 'University_of_Energy_and_Natural_Resources.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2011',
#   'statistics_link': 'https://edurank.org/uni/university-of-energy-and-natural-resources/',
#   'rankings_link': 'https://edurank.org/uni/university-of-energy-and-natural-resources/rankings/'},
#  {'university_name': 'Ashesi University',
#   'university_url': 'https://edurank.org/uni/ashesi-university/',
#   'location': 'Berekuso',
#   'rank_africa': '#263inAfrica',
#   'rank_world': '#6494inthe World',
#   'logo_url': 'Ashesi_University.png',
#   'acceptance_rate': '16%',
#   'enrollment': '1,505',
#   'male_female_ratio': None,
#   'founded': '2002',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Accra Technical University',
#   'university_url': 'https://edurank.org/uni/accra-technical-university/',
#   'location': 'Accra',
#   'rank_africa': '#283inAfrica',
#   'rank_world': '#6766inthe World',
#   'logo_url': 'Accra_Technical_University.png',
#   'acceptance_rate': '100%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1949',
#   'statistics_link': 'https://edurank.org/uni/accra-technical-university/',
#   'rankings_link': 'https://edurank.org/uni/accra-technical-university/rankings/'},
#  {'university_name': 'Pentecost University College',
#   'university_url': 'https://edurank.org/uni/pentecost-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#289inAfrica',
#   'rank_world': '#6910inthe World',
#   'logo_url': 'Pentecost_University_College.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2003',
#   'statistics_link': 'https://edurank.org/uni/pentecost-university-college/',
#   'rankings_link': 'https://edurank.org/uni/pentecost-university-college/rankings/'},
#  {'university_name': 'Methodist University College',
#   'university_url': 'https://edurank.org/uni/methodist-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#317inAfrica',
#   'rank_world': '#7148inthe World',
#   'logo_url': 'Methodist_University_College.png',
#   'acceptance_rate': None,
#   'enrollment': '4,000',
#   'male_female_ratio': None,
#   'founded': '2000',
#   'statistics_link': 'https://edurank.org/uni/methodist-university-college/',
#   'rankings_link': 'https://edurank.org/uni/methodist-university-college/rankings/'},
#  {'university_name': 'Catholic University College of Ghana',
#   'university_url': 'https://edurank.org/uni/catholic-university-college-of-ghana/',
#   'location': 'Sunyani',
#   'rank_africa': '#325inAfrica',
#   'rank_world': '#7182inthe World',
#   'logo_url': 'Catholic_University_College_of_Ghana.png',
#   'acceptance_rate': '50%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2003',
#   'statistics_link': 'https://edurank.org/uni/catholic-university-college-of-ghana/',
#   'rankings_link': 'https://edurank.org/uni/catholic-university-college-of-ghana/rankings/'},
#  {'university_name': 'Advanced Business College',
#   'university_url': 'https://edurank.org/uni/advanced-business-college/',
#   'location': 'Accra',
#   'rank_africa': '#332inAfrica',
#   'rank_world': '#7242inthe World',
#   'logo_url': 'Advanced_Business_College.png',
#   'acceptance_rate': '94%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2005',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Takoradi Technical University',
#   'university_url': 'https://edurank.org/uni/takoradi-technical-university/',
#   'location': 'Takoradi',
#   'rank_africa': '#335inAfrica',
#   'rank_world': '#7273inthe World',
#   'logo_url': 'Takoradi_Technical_University.png',
#   'acceptance_rate': '60%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1954',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Islamic University College, Ghana',
#   'university_url': 'https://edurank.org/uni/islamic-university-college-ghana/',
#   'location': 'Accra',
#   'rank_africa': '#341inAfrica',
#   'rank_world': '#7329inthe World',
#   'logo_url': 'Islamic_University_College,_Ghana.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1988',
#   'statistics_link': 'https://edurank.org/uni/islamic-university-college-ghana/',
#   'rankings_link': 'https://edurank.org/uni/islamic-university-college-ghana/rankings/'},
#  {'university_name': 'Presbyterian University College',
#   'university_url': 'https://edurank.org/uni/presbyterian-university-college/',
#   'location': 'Abetifi',
#   'rank_africa': '#343inAfrica',
#   'rank_world': '#7352inthe World',
#   'logo_url': 'Presbyterian_University_College.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2003',
#   'statistics_link': 'https://edurank.org/uni/presbyterian-university-college/',
#   'rankings_link': 'https://edurank.org/uni/presbyterian-university-college/rankings/'},
#  {'university_name': 'Cape Coast Technical University',
#   'university_url': 'https://edurank.org/uni/cape-coast-technical-university/',
#   'location': 'Cape Coast',
#   'rank_africa': '#344inAfrica',
#   'rank_world': '#7353inthe World',
#   'logo_url': 'Cape_Coast_Technical_University.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1986',
#   'statistics_link': 'https://edurank.org/uni/cape-coast-technical-university/',
#   'rankings_link': 'https://edurank.org/uni/cape-coast-technical-university/rankings/'},
#  {'university_name': 'Christian Service University College',
#   'university_url': 'https://edurank.org/uni/christian-service-university-college/',
#   'location': 'Santasi-Kumasi',
#   'rank_africa': '#346inAfrica',
#   'rank_world': '#7380inthe World',
#   'logo_url': 'Christian_Service_University_College.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1974',
#   'statistics_link': 'https://edurank.org/uni/christian-service-university-college/',
#   'rankings_link': 'https://edurank.org/uni/christian-service-university-college/rankings/'},
#  {'university_name': 'Garden City University College',
#   'university_url': 'https://edurank.org/uni/garden-city-university-college/',
#   'location': 'Kumasi',
#   'rank_africa': '#362inAfrica',
#   'rank_world': '#7612inthe World',
#   'logo_url': 'Garden_City_University_College.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2001',
#   'statistics_link': 'https://edurank.org/uni/garden-city-university-college/',
#   'rankings_link': 'https://edurank.org/uni/garden-city-university-college/rankings/'},
#  {'university_name': 'All Nations University College',
#   'university_url': 'https://edurank.org/uni/all-nations-university-college/',
#   'location': 'Koforidua',
#   'rank_africa': '#368inAfrica',
#   'rank_world': '#7768inthe World',
#   'logo_url': 'All_Nations_University_College.png',
#   'acceptance_rate': '84%',
#   'enrollment': '3,291',
#   'male_female_ratio': '66:34',
#   'founded': '1996',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'African University College of Communications',
#   'university_url': 'https://edurank.org/uni/african-university-college-of-communications/',
#   'location': 'Accra',
#   'rank_africa': '#370inAfrica',
#   'rank_world': '#7816inthe World',
#   'logo_url': 'African_University_College_of_Communications.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2001',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Data Link Institute',
#   'university_url': 'https://edurank.org/uni/data-link-institute/',
#   'location': 'Tema',
#   'rank_africa': '#391inAfrica',
#   'rank_world': '#8253inthe World',
#   'logo_url': 'Data_Link_Institute.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1993',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Radford University College',
#   'university_url': 'https://edurank.org/uni/radford-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#396inAfrica',
#   'rank_world': '#8359inthe World',
#   'logo_url': 'Radford_University_College.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': None,
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Mountcrest University College',
#   'university_url': 'https://edurank.org/uni/mountcrest-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#408inAfrica',
#   'rank_world': '#8834inthe World',
#   'logo_url': 'Mountcrest_University_College.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2008',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Evangelical Presbyterian University College',
#   'university_url': 'https://edurank.org/uni/evangelical-presbyterian-university-college/',
#   'location': 'Ho',
#   'rank_africa': '#422inAfrica',
#   'rank_world': '#9001inthe World',
#   'logo_url': 'Evangelical_Presbyterian_University_College.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2008',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'University College of Agriculture and Environmental Studies',
#   'university_url': 'https://edurank.org/uni/university-college-of-agriculture-and-environmental-studies/',
#   'location': 'Bunso',
#   'rank_africa': '#433inAfrica',
#   'rank_world': '#9223inthe World',
#   'logo_url': 'University_College_of_Agriculture_and_Environmental_Studies.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2006',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Regional Maritime University',
#   'university_url': 'https://edurank.org/uni/regional-maritime-university/',
#   'location': 'Accra',
#   'rank_africa': '#443inAfrica',
#   'rank_world': '#9422inthe World',
#   'logo_url': 'Regional_Maritime_University.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1983',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Valley View University',
#   'university_url': 'https://edurank.org/uni/valley-view-university/',
#   'location': 'Accra',
#   'rank_africa': '#449inAfrica',
#   'rank_world': '#9499inthe World',
#   'logo_url': 'Valley_View_University.png',
#   'acceptance_rate': '67%',
#   'enrollment': '8,473',
#   'male_female_ratio': '65:35',
#   'founded': '1979',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Ghana Institute of Journalism',
#   'university_url': 'https://edurank.org/uni/ghana-institute-of-journalism/',
#   'location': 'Accra',
#   'rank_africa': '#456inAfrica',
#   'rank_world': '#9623inthe World',
#   'logo_url': 'Ghana_Institute_of_Journalism.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1959',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Regent University College of Science and Technology',
#   'university_url': 'https://edurank.org/uni/regent-university-college-of-science-and-technology/',
#   'location': 'Accra',
#   'rank_africa': '#468inAfrica',
#   'rank_world': '#9845inthe World',
#   'logo_url': 'Regent_University_College_of_Science_and_Technology.png',
#   'acceptance_rate': '60%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2003',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Accra Institute of Technology',
#   'university_url': 'https://edurank.org/uni/accra-institute-of-technology/',
#   'location': 'Accra',
#   'rank_africa': '#505inAfrica',
#   'rank_world': '#10449inthe World',
#   'logo_url': 'Accra_Institute_of_Technology.png',
#   'acceptance_rate': '84%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2009',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Zenith University College',
#   'university_url': 'https://edurank.org/uni/zenith-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#515inAfrica',
#   'rank_world': '#10548inthe World',
#   'logo_url': 'Zenith_University_College.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2001',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Sunyani Technical University',
#   'university_url': 'https://edurank.org/uni/sunyani-technical-university/',
#   'location': 'Sunyani',
#   'rank_africa': '#527inAfrica',
#   'rank_world': '#10652inthe World',
#   'logo_url': 'Sunyani_Technical_University.png',
#   'acceptance_rate': '70%',
#   'enrollment': '12,000',
#   'male_female_ratio': None,
#   'founded': '1983',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Lancaster University, Ghana',
#   'university_url': 'https://edurank.org/uni/lancaster-university-ghana/',
#   'location': 'Accra',
#   'rank_africa': '#550inAfrica',
#   'rank_world': '#10847inthe World',
#   'logo_url': 'Lancaster_University,_Ghana.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2013',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Academic City University College',
#   'university_url': 'https://edurank.org/uni/academic-city-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#570inAfrica',
#   'rank_world': '#11081inthe World',
#   'logo_url': 'Academic_City_University_College.png',
#   'acceptance_rate': '69%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2009',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Koforidua Technical University',
#   'university_url': 'https://edurank.org/uni/koforidua-technical-university/',
#   'location': 'Koforidua',
#   'rank_africa': '#595inAfrica',
#   'rank_world': '#11326inthe World',
#   'logo_url': 'Koforidua_Technical_University.png',
#   'acceptance_rate': '100%',
#   'enrollment': '6,895',
#   'male_female_ratio': None,
#   'founded': '1997',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Jayee University College',
#   'university_url': 'https://edurank.org/uni/jayee-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#604inAfrica',
#   'rank_world': '#11439inthe World',
#   'logo_url': 'Jayee_University_College.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1988',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Knutsford University College',
#   'university_url': 'https://edurank.org/uni/knutsford-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#605inAfrica',
#   'rank_world': '#11445inthe World',
#   'logo_url': 'Knutsford_University_College.png',
#   'acceptance_rate': '47%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2005',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'BlueCrest College',
#   'university_url': 'https://edurank.org/uni/bluecrest-college/',
#   'location': 'Accra',
#   'rank_africa': '#623inAfrica',
#   'rank_world': '#11540inthe World',
#   'logo_url': 'BlueCrest_College.png',
#   'acceptance_rate': '82%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2000',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Webster University Ghana',
#   'university_url': 'https://edurank.org/uni/webster-university-ghana/',
#   'location': 'Accra',
#   'rank_africa': '#651inAfrica',
#   'rank_world': '#11768inthe World',
#   'logo_url': 'Webster_University_Ghana.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2013',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Wisconsin International University College',
#   'university_url': 'https://edurank.org/uni/wisconsin-international-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#652inAfrica',
#   'rank_world': '#11770inthe World',
#   'logo_url': 'Wisconsin_International_University_College.png',
#   'acceptance_rate': '50%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2000',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Ghana Institute of Languages',
#   'university_url': 'https://edurank.org/uni/ghana-institute-of-languages/',
#   'location': 'Accra',
#   'rank_africa': '#684inAfrica',
#   'rank_world': '#12028inthe World',
#   'logo_url': 'Ghana_Institute_of_Languages.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1961',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'University College of Management Studies',
#   'university_url': 'https://edurank.org/uni/university-college-of-management-studies/',
#   'location': 'Accra',
#   'rank_africa': '#714inAfrica',
#   'rank_world': '#12202inthe World',
#   'logo_url': 'University_College_of_Management_Studies.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1974',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'KAAF University College',
#   'university_url': 'https://edurank.org/uni/kaaf-university-college/',
#   'location': 'Kasoa',
#   'rank_africa': '#758inAfrica',
#   'rank_world': '#12450inthe World',
#   'logo_url': 'KAAF_University_College.png',
#   'acceptance_rate': '24%',
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2007',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Dominion University College',
#   'university_url': 'https://edurank.org/uni/dominion-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#775inAfrica',
#   'rank_world': '#12510inthe World',
#   'logo_url': 'Dominion_University_College.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2009',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Tamale Technical University',
#   'university_url': 'https://edurank.org/uni/tamale-technical-university/',
#   'location': 'Tamale',
#   'rank_africa': '#784inAfrica',
#   'rank_world': '#12557inthe World',
#   'logo_url': 'Tamale_Technical_University.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1950',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Anglican University College of Technology',
#   'university_url': 'https://edurank.org/uni/anglican-university-college-of-technology/',
#   'location': 'Teshie',
#   'rank_africa': '#788inAfrica',
#   'rank_world': '#12583inthe World',
#   'logo_url': 'Anglican_University_College_of_Technology.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': None,
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Ghana Christian University College',
#   'university_url': 'https://edurank.org/uni/ghana-christian-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#804inAfrica',
#   'rank_world': '#12673inthe World',
#   'logo_url': 'Ghana_Christian_University_College.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1966',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Ghana Baptist University College',
#   'university_url': 'https://edurank.org/uni/ghana-baptist-university-college/',
#   'location': 'Abuakwa-Kumasi',
#   'rank_africa': '#829inAfrica',
#   'rank_world': '#12821inthe World',
#   'logo_url': 'Ghana_Baptist_University_College.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2006',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Marshalls University College',
#   'university_url': 'https://edurank.org/uni/marshalls-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#874inAfrica',
#   'rank_world': '#13073inthe World',
#   'logo_url': 'Marshalls_University_College.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2012',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Catholic Institute of Business and Technology',
#   'university_url': 'https://edurank.org/uni/catholic-institute-of-business-and-technology/',
#   'location': 'Accra',
#   'rank_africa': '#883inAfrica',
#   'rank_world': '#13115inthe World',
#   'logo_url': 'Catholic_Institute_of_Business_and_Technology.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': None,
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Kings University College',
#   'university_url': 'https://edurank.org/uni/kings-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#888inAfrica',
#   'rank_world': '#13140inthe World',
#   'logo_url': 'Kings_University_College.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2009',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'West End University College',
#   'university_url': 'https://edurank.org/uni/west-end-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#912inAfrica',
#   'rank_world': '#13266inthe World',
#   'logo_url': 'West_End_University_College.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2010',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Bolgatanga Polytechnic',
#   'university_url': 'https://edurank.org/uni/bolgatanga-polytechnic/',
#   'location': 'Bolgatanga',
#   'rank_africa': '#918inAfrica',
#   'rank_world': '#13284inthe World',
#   'logo_url': 'Bolgatanga_Polytechnic.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2003',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Christ Apostolic University College',
#   'university_url': 'https://edurank.org/uni/christ-apostolic-university-college/',
#   'location': 'Kumasi',
#   'rank_africa': '#920inAfrica',
#   'rank_world': '#13291inthe World',
#   'logo_url': 'Christ_Apostolic_University_College.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '2010',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Kessben College',
#   'university_url': 'https://edurank.org/uni/kessben-college/',
#   'location': 'Kuntenase',
#   'rank_africa': '#926inAfrica',
#   'rank_world': '#13319inthe World',
#   'logo_url': 'Kessben_College.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': None,
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Perez University College',
#   'university_url': 'https://edurank.org/uni/perez-university-college/',
#   'location': 'Winneba',
#   'rank_africa': '#963inAfrica',
#   'rank_world': '#13512inthe World',
#   'logo_url': 'Perez_University_College.png',
#   'acceptance_rate': None,
#   'enrollment': '151',
#   'male_female_ratio': '50:50',
#   'founded': '2001',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Spiritan University College',
#   'university_url': 'https://edurank.org/uni/spiritan-university-college/',
#   'location': 'Ejisu',
#   'rank_africa': '#983inAfrica',
#   'rank_world': '#13605inthe World',
#   'logo_url': 'Spiritan_University_College.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1990',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Wa Polytechnic',
#   'university_url': 'https://edurank.org/uni/wa-polytechnic/',
#   'location': 'Wa',
#   'rank_africa': '#988inAfrica',
#   'rank_world': '#13631inthe World',
#   'logo_url': 'Wa_Polytechnic.png',
#   'acceptance_rate': None,
#   'enrollment': '3,000',
#   'male_female_ratio': None,
#   'founded': '1999',
#   'statistics_link': None,
#   'rankings_link': None},
#  {'university_name': 'Maranatha University College',
#   'university_url': 'https://edurank.org/uni/maranatha-university-college/',
#   'location': 'Accra',
#   'rank_africa': '#1056inAfrica',
#   'rank_world': '#13981inthe World',
#   'logo_url': 'Maranatha_University_College.png',
#   'acceptance_rate': None,
#   'enrollment': None,
#   'male_female_ratio': None,
#   'founded': '1972',
#   'statistics_link': None,
#   'rankings_link': None}]

# %%
# Save soup as json file
with open('edurank_gh.json', 'w') as f:
    json.dump(soup.prettify(), f, indent=4)
